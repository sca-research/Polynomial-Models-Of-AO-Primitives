# %% [markdown]
# # MiMC Solving Degree For Attack With Two Plain Texts
# Empirical solving degree for increasing round numbers of MiMC with two plain/ciphertext samples.
#
# Prime: $p = 10007$.
#
# Round numbers: $r \in \{ 2, 3, 4 \}$.

# %%
from lazard_gb_algorithm import *
load("MiMC.sage")
load("utilities.sage")

# %% [markdown]
# ## p = 10007, r = 2

# %%
p = 10007
field = GF(p, "a")

rounds = 2

mimc = MiMC(field=field, rounds=rounds)

print("")

key = field.random_element()
print("Key:", key)

plain_1 = field.random_element()
cipher_1 = mimc.encryption(plain_1, key)

print("Plain 1:", plain_1)
print("Cipher 1:", cipher_1)

plain_2 = field.random_element()
cipher_2 = mimc.encryption(plain_2, key)

print("Plain 2:", plain_2)
print("Cipher 2:", cipher_2)

print("")

polys = mimc.generate_two_plain_text_polynomials(plain_1, 
                                                 cipher_1, 
                                                 plain_2, 
                                                 cipher_2,
                                                 info_level=0)
polys_h = [poly.homogenize() for poly in polys]

for i in range(0, 2 * rounds):
    print(polys[i])
    if i == rounds - 1:
        print("\n")
# Out:
# MiMC Parameters
# Field: Finite Field of size 10007
# r: 2
# Constants: [6482, 5078]
#
# Key: 774
# Plain 1: 1042
# Cipher 1: 3170
# Plain 2: 2945
# Cipher 2: 5379
#
# y^3 + 2558*y^2 - u_1 + 2931*y - 4197
# u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + y^3 - 4780*u_1^2 + 447*u_1*y - 4780*y^2 + 4142*u_1 + 4143*y - 3716
#
#
# y^3 - 1740*y^2 - v_1 - 1507*y + 4486
# v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + y^3 - 4780*v_1^2 + 447*v_1*y - 4780*y^2 + 4142*v_1 + 4143*y + 4082

# %%
lazard_gb_algorithm(polys)
# Out:
# Ring: Multivariate Polynomial Ring in u_1, v_1, y over Finite Field of size 10007
# Input polynomials:
# [y^3 + 2558*y^2 - u_1 + 2931*y - 4197, u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + y^3 - 4780*u_1^2 + 447*u_1*y - 4780*y^2 + 4142*u_1 + 4143*y - 3716, y^3 - 1740*y^2 - v_1 - 1507*y + 4486, v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + y^3 - 4780*v_1^2 + 447*v_1*y - 4780*y^2 + 4142*v_1 + 4143*y + 4082]
#
# --- Degree 0 ---
# Computing all monomials up to degree: 0
# Time needed: 0.08044672012329102
# Computing Macaulay matrix.
# Time needed: 1.9073486328125e-06
# Performing Gaussian Elimination.
# Time needed: 0.0001747608184814453
# Is Groebner Basis: False
#
# --- Degree 1 ---
# Computing all monomials up to degree: 1
# Time needed: 0.014487743377685547
# Computing Macaulay matrix.
# Time needed: 1.1920928955078125e-06
# Performing Gaussian Elimination.
# Time needed: 0.00012731552124023438
# Is Groebner Basis: False
#
# --- Degree 2 ---
# Computing all monomials up to degree: 2
# Time needed: 0.0010318756103515625
# Computing Macaulay matrix.
# Time needed: 7.152557373046875e-07
# Performing Gaussian Elimination.
# Time needed: 0.0001690387725830078
# Is Groebner Basis: False
#
# --- Degree 3 ---
# Computing all monomials up to degree: 3
# Time needed: 0.001262664794921875
# Computing Macaulay matrix.
# Time needed: 9.5367431640625e-07
# Performing Gaussian Elimination.
# Time needed: 0.00018644332885742188
# Is Groebner Basis: False
#
# --- Degree 4 ---
# Computing all monomials up to degree: 4
# Time needed: 0.0016024112701416016
# Computing Macaulay matrix.
# Time needed: 1.430511474609375e-06
# Performing Gaussian Elimination.
# Time needed: 0.00027871131896972656
# Is Groebner Basis: False
#
# --- Degree 5 ---
# Computing all monomials up to degree: 5
# Time needed: 0.0022313594818115234
# Computing Macaulay matrix.
# Time needed: 1.9073486328125e-06
# Performing Gaussian Elimination.
# Time needed: 0.0004980564117431641
# Is Groebner Basis: False
#
# --- Degree 6 ---
# Computing all monomials up to degree: 6
# Time needed: 0.002393007278442383
# Computing Macaulay matrix.
# Time needed: 2.1457672119140625e-06
# Performing Gaussian Elimination.
# Time needed: 0.0013158321380615234
# Is Groebner Basis: False
#
# --- Degree 7 ---
# Computing all monomials up to degree: 7
# Time needed: 0.004211902618408203
# Computing Macaulay matrix.
# Time needed: 3.0994415283203125e-06
# Performing Gaussian Elimination.
# Time needed: 0.004603385925292969
# Is Groebner Basis: False
#
# --- Degree 8 ---
# Computing all monomials up to degree: 8
# Time needed: 0.00661778450012207
# Computing Macaulay matrix.
# Time needed: 1.430511474609375e-06
# Performing Gaussian Elimination.
# Time needed: 0.005131244659423828
# Is Groebner Basis: True
# Total time needed: 0.20096778869628906
# [u_1 + 2264, v_1 + 3726, y - 774]

# %%
lazard_gb_algorithm(polys_h)
# Out:
# Ring: Multivariate Polynomial Ring in u_1, v_1, y, h over Finite Field of size 10007
# Input polynomials:
# [y^3 + 2558*y^2*h - u_1*h^2 + 2931*y*h^2 - 4197*h^3, u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + y^3 - 4780*u_1^2*h + 447*u_1*y*h - 4780*y^2*h + 4142*u_1*h^2 + 4143*y*h^2 - 3716*h^3, y^3 - 1740*y^2*h - v_1*h^2 - 1507*y*h^2 + 4486*h^3, v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + y^3 - 4780*v_1^2*h + 447*v_1*y*h - 4780*y^2*h + 4142*v_1*h^2 + 4143*y*h^2 + 4082*h^3]
#
# --- Degree 0 ---
# Computing all monomials up to degree: 0
# Time needed: 0.00040221214294433594
# Computing Macaulay matrix.
# Time needed: 9.5367431640625e-07
# Performing Gaussian Elimination.
# Time needed: 6.4849853515625e-05
# Is Groebner Basis: False
#
# --- Degree 1 ---
# Computing all monomials up to degree: 1
# Time needed: 0.0008211135864257812
# Computing Macaulay matrix.
# Time needed: 1.1920928955078125e-06
# Performing Gaussian Elimination.
# Time needed: 0.00010228157043457031
# Is Groebner Basis: False
#
# --- Degree 2 ---
# Computing all monomials up to degree: 2
# Time needed: 0.0010290145874023438
# Computing Macaulay matrix.
# Time needed: 9.5367431640625e-07
# Performing Gaussian Elimination.
# Time needed: 0.00011014938354492188
# Is Groebner Basis: False
#
# --- Degree 3 ---
# Computing all monomials up to degree: 3
# Time needed: 0.0012793540954589844
# Computing Macaulay matrix.
# Time needed: 9.5367431640625e-07
# Performing Gaussian Elimination.
# Time needed: 0.00031256675720214844
# Is Groebner Basis: False
#
# --- Degree 4 ---
# Computing all monomials up to degree: 4
# Time needed: 0.0022962093353271484
# Computing Macaulay matrix.
# Time needed: 1.430511474609375e-06
# Performing Gaussian Elimination.
# Time needed: 0.0003218650817871094
# Is Groebner Basis: False
#
# --- Degree 5 ---
# Computing all monomials up to degree: 5
# Time needed: 0.0034127235412597656
# Computing Macaulay matrix.
# Time needed: 2.1457672119140625e-06
# Performing Gaussian Elimination.
# Time needed: 0.0009751319885253906
# Is Groebner Basis: False
#
# --- Degree 6 ---
# Computing all monomials up to degree: 6
# Time needed: 0.0042171478271484375
# Computing Macaulay matrix.
# Time needed: 2.6226043701171875e-06
# Performing Gaussian Elimination.
# Time needed: 0.0021789073944091797
# Is Groebner Basis: False
#
# --- Degree 7 ---
# Computing all monomials up to degree: 7
# Time needed: 0.007501363754272461
# Computing Macaulay matrix.
# Time needed: 5.0067901611328125e-06
# Performing Gaussian Elimination.
# Time needed: 0.007565975189208984
# Is Groebner Basis: False
#
# --- Degree 8 ---
# Computing all monomials up to degree: 8
# Time needed: 0.013586044311523438
# Computing Macaulay matrix.
# Time needed: 3.0994415283203125e-06
# Performing Gaussian Elimination.
# Time needed: 0.015041351318359375
# Is Groebner Basis: True
# Total time needed: 0.2285003662109375
# [u_1*h^7 + 2264*h^8,
#  v_1*h^7 + 3726*h^8,
#  y*h^7 - 774*h^8,
#  u_1*v_1*h^5 + 1208*u_1*h^6 + 257*v_1*h^6 + 4348*y*h^6 - 2852*h^7,
#  v_1^2*h^5 + 1559*u_1*h^6 + 1285*v_1*h^6 - 1234*y*h^6 + 2753*h^7,
#  v_1*y*h^5 + 1684*u_1*h^6 - 4450*v_1*h^6 + 1231*y*h^6 + 587*h^7,
#  u_1*v_1^2*h^3 - 4925*u_1*v_1*h^4 + 773*v_1^2*h^4 + 4740*v_1*y*h^4 - 1303*u_1*h^5 + 3155*v_1*h^5 + 601*y*h^5 + 2402*h^6,
#  v_1^2*y*h^3 + 95*u_1*v_1*h^4 - 4877*v_1^2*h^4 - 2949*v_1*y*h^4 - 1008*u_1*h^5 - 2427*v_1*h^5 + 3900*y*h^5 + 1201*h^6,
#  u_1^2*h^3 - 2*u_1*v_1*h^3 + v_1^2*h^3 + 118*v_1*y*h^3 + 3115*u_1*h^4 - 299*v_1*h^4 + 3465*y*h^4 + 3138*h^5,
#  u_1*y*h^2 - v_1*y*h^2 + 1323*u_1*h^3 + 4386*v_1*h^3 - 1246*y*h^3 - 3088*h^4,
#  u_1^3 + 3*u_1^2*y + 3*u_1*y^2 - 4780*u_1^2*h + 447*u_1*y*h - 804*u_1*h^2 + 4947*v_1*h^2 + 640*y*h^2 - 4276*h^3,
#  v_1^3 + 3*v_1^2*y + 3*v_1*y^2 - 4780*v_1^2*h + 447*v_1*y*h - 4946*u_1*h^2 - 918*v_1*h^2 + 640*y*h^2 + 3522*h^3,
#  y^3 - 4806*u_1*h^2 + 4805*v_1*h^2 + 2604*y*h^2 + 3178*h^3,
#  y^2*h - 3695*u_1*h^2 + 3695*v_1*h^2 - 3063*y*h^2 - 1243*h^3]

# %%
res = ideal(polys_h).graded_free_resolution(algorithm="minimal")
res
# Out:
# S(0) <-- S(-3)⊕S(-3)⊕S(-3)⊕S(-3) <-- S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-9) <-- S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-10)⊕S(-10)⊕S(-10) <-- S(-11)⊕S(-11)⊕S(-11) <-- 0

# %%
cm_regularity(res)
# Out:
# 8

# %% [markdown]
# ## p = 10007, r = 3

# %%
p = 10007
field = GF(p, "a")

rounds = 3

mimc = MiMC(field=field, rounds=rounds)

print("")

key = field.random_element()
print("Key:", key)

plain_1 = field.random_element()
cipher_1 = mimc.encryption(plain_1, key)

print("Plain 1:", plain_1)
print("Cipher 1:", cipher_1)

plain_2 = field.random_element()
cipher_2 = mimc.encryption(plain_2, key)

print("Plain 2:", plain_2)
print("Cipher 2:", cipher_2)

print("")

polys = mimc.generate_two_plain_text_polynomials(plain_1, 
                                                 cipher_1, 
                                                 plain_2, 
                                                 cipher_2,
                                                 info_level=0)
polys_h = [poly.homogenize() for poly in polys]

for i in range(0, 2 * rounds):
    print(polys[i])
    if i == rounds - 1:
        print("\n")
# Out:
# MiMC Parameters
# Field: Finite Field of size 10007
# r: 3
# Constants: [4013, 3566, 9529]
#
# Key: 5084
# Plain 1: 6441
# Cipher 1: 8458
# Plain 2: 816
# Cipher 2: 5147
#
# y^3 + 1341*y^2 - u_1 - 993*y + 2148
# u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + y^3 + 691*u_1^2 + 1382*u_1*y + 691*y^2 + 2384*u_1 - u_2 + 2384*y - 4871
# u_2^3 + 3*u_2^2*y + 3*u_2*y^2 + y^3 - 1434*u_2^2 - 2868*u_2*y - 1434*y^2 + 4976*u_2 + 4977*y + 2595
#
#
# y^3 + 4480*y^2 - v_1 - 1214*y + 3901
# v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + y^3 + 691*v_1^2 + 1382*v_1*y + 691*y^2 + 2384*v_1 - v_2 + 2384*y - 4871
# v_2^3 + 3*v_2^2*y + 3*v_2*y^2 + y^3 - 1434*v_2^2 - 2868*v_2*y - 1434*y^2 + 4976*v_2 + 4977*y - 4101

# %%
lazard_gb_algorithm(polys)
# Out:
# Ring: Multivariate Polynomial Ring in u_1, u_2, v_1, v_2, y over Finite Field of size 10007
# Input polynomials:
# [y^3 + 1341*y^2 - u_1 - 993*y + 2148, u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + y^3 + 691*u_1^2 + 1382*u_1*y + 691*y^2 + 2384*u_1 - u_2 + 2384*y - 4871, u_2^3 + 3*u_2^2*y + 3*u_2*y^2 + y^3 - 1434*u_2^2 - 2868*u_2*y - 1434*y^2 + 4976*u_2 + 4977*y + 2595, y^3 + 4480*y^2 - v_1 - 1214*y + 3901, v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + y^3 + 691*v_1^2 + 1382*v_1*y + 691*y^2 + 2384*v_1 - v_2 + 2384*y - 4871, v_2^3 + 3*v_2^2*y + 3*v_2*y^2 + y^3 - 1434*v_2^2 - 2868*v_2*y - 1434*y^2 + 4976*v_2 + 4977*y - 4101]
#
# --- Degree 0 ---
# Computing all monomials up to degree: 0
# Time needed: 0.0006477832794189453
# Computing Macaulay matrix.
# Time needed: 9.5367431640625e-07
# Performing Gaussian Elimination.
# Time needed: 7.009506225585938e-05
# Is Groebner Basis: False
#
# --- Degree 1 ---
# Computing all monomials up to degree: 1
# Time needed: 0.0014731884002685547
# Computing Macaulay matrix.
# Time needed: 3.814697265625e-06
# Performing Gaussian Elimination.
# Time needed: 0.00021696090698242188
# Is Groebner Basis: False
#
# --- Degree 2 ---
# Computing all monomials up to degree: 2
# Time needed: 0.0032646656036376953
# Computing Macaulay matrix.
# Time needed: 2.1457672119140625e-06
# Performing Gaussian Elimination.
# Time needed: 0.00021696090698242188
# Is Groebner Basis: False
#
# --- Degree 3 ---
# Computing all monomials up to degree: 3
# Time needed: 0.003834962844848633
# Computing Macaulay matrix.
# Time needed: 2.6226043701171875e-06
# Performing Gaussian Elimination.
# Time needed: 0.000568389892578125
# Is Groebner Basis: False
#
# --- Degree 4 ---
# Computing all monomials up to degree: 4
# Time needed: 0.002841949462890625
# Computing Macaulay matrix.
# Time needed: 1.6689300537109375e-06
# Performing Gaussian Elimination.
# Time needed: 0.0006349086761474609
# Is Groebner Basis: False
#
# --- Degree 5 ---
# Computing all monomials up to degree: 5
# Time needed: 0.0049419403076171875
# Computing Macaulay matrix.
# Time needed: 2.1457672119140625e-06
# Performing Gaussian Elimination.
# Time needed: 0.0020940303802490234
# Is Groebner Basis: False
#
# --- Degree 6 ---
# Computing all monomials up to degree: 6
# Time needed: 0.012160539627075195
# Computing Macaulay matrix.
# Time needed: 2.384185791015625e-06
# Performing Gaussian Elimination.
# Time needed: 0.006129264831542969
# Is Groebner Basis: False
#
# --- Degree 7 ---
# Computing all monomials up to degree: 7
# Time needed: 0.01598072052001953
# Computing Macaulay matrix.
# Time needed: 3.814697265625e-06
# Performing Gaussian Elimination.
# Time needed: 0.02540421485900879
# Is Groebner Basis: False
#
# --- Degree 8 ---
# Computing all monomials up to degree: 8
# Time needed: 0.031479835510253906
# Computing Macaulay matrix.
# Time needed: 2.86102294921875e-06
# Performing Gaussian Elimination.
# Time needed: 0.0692141056060791
# Is Groebner Basis: False
#
# --- Degree 9 ---
# Computing all monomials up to degree: 9
# Time needed: 0.02781534194946289
# Computing Macaulay matrix.
# Time needed: 4.0531158447265625e-06
# Performing Gaussian Elimination.
# Time needed: 0.3482205867767334
# Is Groebner Basis: False
#
# --- Degree 10 ---
# Computing all monomials up to degree: 10
# Time needed: 0.04510140419006348
# Computing Macaulay matrix.
# Time needed: 4.291534423828125e-06
# Performing Gaussian Elimination.
# Time needed: 0.7939369678497314
# Is Groebner Basis: False
#
# --- Degree 11 ---
# Computing all monomials up to degree: 11
# Time needed: 0.09146547317504883
# Computing Macaulay matrix.
# Time needed: 5.7220458984375e-06
# Performing Gaussian Elimination.
# Time needed: 2.9558894634246826
# Is Groebner Basis: False
#
# --- Degree 12 ---
# Computing all monomials up to degree: 12
# Time needed: 0.08743476867675781
# Computing Macaulay matrix.
# Time needed: 5.245208740234375e-06
# Performing Gaussian Elimination.
# Time needed: 6.520818710327148
# Is Groebner Basis: True
# Total time needed: 14.294774770736694
# [u_1 + 3755, u_2 - 2356, v_1 + 3, v_2 - 3590, y + 4923]

# %%
lazard_gb_algorithm(polys_h)
# Out:
# Ring: Multivariate Polynomial Ring in u_1, u_2, v_1, v_2, y, h over Finite Field of size 10007
# Input polynomials:
# [y^3 + 1341*y^2*h - u_1*h^2 - 993*y*h^2 + 2148*h^3, u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + y^3 + 691*u_1^2*h + 1382*u_1*y*h + 691*y^2*h + 2384*u_1*h^2 - u_2*h^2 + 2384*y*h^2 - 4871*h^3, u_2^3 + 3*u_2^2*y + 3*u_2*y^2 + y^3 - 1434*u_2^2*h - 2868*u_2*y*h - 1434*y^2*h + 4976*u_2*h^2 + 4977*y*h^2 + 2595*h^3, y^3 + 4480*y^2*h - v_1*h^2 - 1214*y*h^2 + 3901*h^3, v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + y^3 + 691*v_1^2*h + 1382*v_1*y*h + 691*y^2*h + 2384*v_1*h^2 - v_2*h^2 + 2384*y*h^2 - 4871*h^3, v_2^3 + 3*v_2^2*y + 3*v_2*y^2 + y^3 - 1434*v_2^2*h - 2868*v_2*y*h - 1434*y^2*h + 4976*v_2*h^2 + 4977*y*h^2 - 4101*h^3]
#
# --- Degree 0 ---
# Computing all monomials up to degree: 0
# Time needed: 0.0005614757537841797
# Computing Macaulay matrix.
# Time needed: 1.1920928955078125e-06
# Performing Gaussian Elimination.
# Time needed: 0.0001308917999267578
# Is Groebner Basis: False
#
# --- Degree 1 ---
# Computing all monomials up to degree: 1
# Time needed: 0.0034863948822021484
# Computing Macaulay matrix.
# Time needed: 1.9073486328125e-06
# Performing Gaussian Elimination.
# Time needed: 0.00014972686767578125
# Is Groebner Basis: False
#
# --- Degree 2 ---
# Computing all monomials up to degree: 2
# Time needed: 0.0015861988067626953
# Computing Macaulay matrix.
# Time needed: 1.6689300537109375e-06
# Performing Gaussian Elimination.
# Time needed: 0.00018143653869628906
# Is Groebner Basis: False
#
# --- Degree 3 ---
# Computing all monomials up to degree: 3
# Time needed: 0.0028235912322998047
# Computing Macaulay matrix.
# Time needed: 2.1457672119140625e-06
# Performing Gaussian Elimination.
# Time needed: 0.00046133995056152344
# Is Groebner Basis: False
#
# --- Degree 4 ---
# Computing all monomials up to degree: 4
# Time needed: 0.009532451629638672
# Computing Macaulay matrix.
# Time needed: 3.0994415283203125e-06
# Performing Gaussian Elimination.
# Time needed: 0.0009174346923828125
# Is Groebner Basis: False
#
# --- Degree 5 ---
# Computing all monomials up to degree: 5
# Time needed: 0.010103702545166016
# Computing Macaulay matrix.
# Time needed: 4.5299530029296875e-06
# Performing Gaussian Elimination.
# Time needed: 0.004631996154785156
# Is Groebner Basis: False
#
# --- Degree 6 ---
# Computing all monomials up to degree: 6
# Time needed: 0.030379056930541992
# Computing Macaulay matrix.
# Time needed: 3.814697265625e-06
# Performing Gaussian Elimination.
# Time needed: 0.01754021644592285
# Is Groebner Basis: False
#
# --- Degree 7 ---
# Computing all monomials up to degree: 7
# Time needed: 0.04984259605407715
# Computing Macaulay matrix.
# Time needed: 3.814697265625e-06
# Performing Gaussian Elimination.
# Time needed: 0.06250882148742676
# Is Groebner Basis: False
#
# --- Degree 8 ---
# Computing all monomials up to degree: 8
# Time needed: 0.046011924743652344
# Computing Macaulay matrix.
# Time needed: 2.6226043701171875e-06
# Performing Gaussian Elimination.
# Time needed: 0.2230844497680664
# Is Groebner Basis: False
#
# --- Degree 9 ---
# Computing all monomials up to degree: 9
# Time needed: 0.10003423690795898
# Computing Macaulay matrix.
# Time needed: 6.9141387939453125e-06
# Performing Gaussian Elimination.
# Time needed: 0.7450227737426758
# Is Groebner Basis: False
#
# --- Degree 10 ---
# Computing all monomials up to degree: 10
# Time needed: 0.1599571704864502
# Computing Macaulay matrix.
# Time needed: 6.9141387939453125e-06
# Performing Gaussian Elimination.
# Time needed: 2.574547052383423
# Is Groebner Basis: False
#
# --- Degree 11 ---
# Computing all monomials up to degree: 11
# Time needed: 0.21628618240356445
# Computing Macaulay matrix.
# Time needed: 5.4836273193359375e-06
# Performing Gaussian Elimination.
# Time needed: 11.07909870147705
# Is Groebner Basis: False
#
# --- Degree 12 ---
# Computing all monomials up to degree: 12
# Time needed: 0.3251512050628662
# Computing Macaulay matrix.
# Time needed: 7.867813110351562e-06
# Performing Gaussian Elimination.
# Time needed: 29.94371724128723
# Is Groebner Basis: True
# Total time needed: 60.24548888206482
# [u_1*h^11 + 3755*h^12,
#  u_2*h^11 - 2356*h^12,
#  v_1*h^11 + 3*h^12,
#  v_2*h^11 - 3590*h^12,
#  y*h^11 + 4923*h^12,
#  u_2^2*h^9 - 2483*u_1*h^10 + 1546*u_2*h^10 + 3557*v_1*h^10 - 4166*v_2*h^10 - 4945*y*h^10 - 4892*h^11,
#  u_2*v_1*h^9 - 2304*u_1*h^10 - 4516*u_2*h^10 - 4681*v_1*h^10 - 441*v_2*h^10 + 2170*y*h^10 - 2667*h^11,
#  v_1^2*h^9 - 3740*u_1*h^10 + 3360*u_2*h^10 + 4067*v_1*h^10 + 2703*v_2*h^10 - 1979*y*h^10 + 4904*h^11,
#  u_1*v_2*h^9 + 3594*u_1*h^10 + 4357*u_2*h^10 + 2549*v_1*h^10 + 1981*v_2*h^10 + 531*y*h^10 + 2251*h^11,
#  u_2*v_2*h^9 + 4468*u_1*h^10 - 4165*u_2*h^10 + 3954*v_1*h^10 - 3767*v_2*h^10 + 1496*y*h^10 + 4940*h^11,
#  v_1*v_2*h^9 + 2635*u_1*h^10 + 1813*u_2*h^10 - 3043*v_1*h^10 + 1621*v_2*h^10 - 3283*y*h^10 + 4484*h^11,
#  v_2^2*h^9 + 4780*u_1*h^10 + 3534*u_2*h^10 - 3838*v_1*h^10 + 1172*v_2*h^10 - 4224*y*h^10 + 732*h^11,
#  u_2*y*h^9 - 280*u_1*h^10 + 34*u_2*h^10 - 441*v_1*h^10 + 3617*v_2*h^10 + 4352*y*h^10 + 2404*h^11,
#  v_1*y*h^9 + 3665*u_1*h^10 - 3470*u_2*h^10 + 4661*v_1*h^10 - 3345*v_2*h^10 - 3332*y*h^10 - 548*h^11,
#  v_2*y*h^9 - 298*u_1*h^10 - 3569*u_2*h^10 + 2307*v_1*h^10 - 2829*v_2*h^10 + 1395*y*h^10 + 4388*h^11,
#  u_2^2*v_2^2*h^6 + 4100*u_2^2*h^8 + 1856*u_2*v_1*h^8 + 943*v_1^2*h^8 - 3472*u_1*v_2*h^8 + 1767*u_2*v_2*h^8 - 1036*v_1*v_2*h^8 + 4449*v_2^2*h^8 + 2631*u_2*y*h^8 + 4177*v_1*y*h^8 + 4288*v_2*y*h^8 - 2735*u_1*h^9 - 1761*u_2*h^9 - 1451*v_1*h^9 - 1785*v_2*h^9 + 1456*y*h^9 + 1427*h^10,
#  u_2^2*v_2*h^7 - 1627*u_2^2*h^8 + 1976*u_2*v_1*h^8 + 3237*v_1^2*h^8 - 3546*u_1*v_2*h^8 - 3295*u_2*v_2*h^8 - 261*v_1*v_2*h^8 + 2111*v_2^2*h^8 + 745*u_2*y*h^8 - 1661*v_1*y*h^8 - 160*v_2*y*h^8 - 2046*u_1*h^9 + 2531*u_2*h^9 + 2644*v_1*h^9 + 3356*v_2*h^9 - 2736*y*h^9 + 3834*h^10,
#  u_1*v_2^2*h^7 + 4066*u_2^2*h^8 + 4399*u_2*v_1*h^8 + 2451*v_1^2*h^8 + 1315*u_1*v_2*h^8 - 1978*u_2*v_2*h^8 + 4971*v_1*v_2*h^8 - 1166*v_2^2*h^8 + 2363*u_2*y*h^8 - 1130*v_1*y*h^8 - 2410*v_2*y*h^8 - 481*u_1*h^9 - 2298*u_2*h^9 - 1662*v_1*h^9 - 3406*v_2*h^9 - 281*y*h^9 - 2352*h^10,
#  u_2*v_2^2*h^7 + 1053*u_2^2*h^8 - 3513*u_2*v_1*h^8 + 2412*v_1^2*h^8 - 2257*u_1*v_2*h^8 + 2277*u_2*v_2*h^8 - 756*v_1*v_2*h^8 - 991*v_2^2*h^8 - 4364*u_2*y*h^8 - 2591*v_1*y*h^8 - 3428*v_2*y*h^8 - 4341*u_1*h^9 - 4089*u_2*h^9 + 2141*v_1*h^9 - 1403*v_2*h^9 + 1896*y*h^9 - 445*h^10,
#  v_1*v_2^2*h^7 - 4132*u_2^2*h^8 - 4455*u_2*v_1*h^8 - 2635*v_1^2*h^8 - 2541*u_1*v_2*h^8 + 4741*u_2*v_2*h^8 - 4400*v_1*v_2*h^8 + 3668*v_2^2*h^8 + 3472*u_2*y*h^8 + 3000*v_1*y*h^8 + 2373*v_2*y*h^8 + 2703*u_1*h^9 - 4836*u_2*h^9 + 4343*v_1*h^9 - 3565*v_2*h^9 + 4354*y*h^9 + 2131*h^10,
#  u_2^2*y*h^7 + 1016*u_2^2*h^8 + 2000*u_2*v_1*h^8 + 545*v_1^2*h^8 + 3304*u_1*v_2*h^8 - 2148*u_2*v_2*h^8 + 2655*v_1*v_2*h^8 - 1872*v_2^2*h^8 + 144*u_2*y*h^8 + 356*v_1*y*h^8 + 1633*v_2*y*h^8 + 3545*u_1*h^9 + 1449*u_2*h^9 + 4704*v_1*h^9 - 3600*v_2*h^9 - 3119*y*h^9 + 1024*h^10,
#  u_2*v_2*y*h^7 + 4898*u_2^2*h^8 - 2342*u_2*v_1*h^8 - 251*v_1^2*h^8 - 3304*u_1*v_2*h^8 - 3022*u_2*v_2*h^8 + 3809*v_1*v_2*h^8 - 2229*v_2^2*h^8 - 4103*u_2*y*h^8 + 1296*v_1*y*h^8 + 3772*v_2*y*h^8 - 422*u_1*h^9 - 2271*u_2*h^9 - 998*v_1*h^9 - 2000*v_2*h^9 - 2861*y*h^9 - 3261*h^10,
#  v_1*v_2*y*h^7 - 2762*u_2^2*h^8 - 3475*u_2*v_1*h^8 + 4515*v_1^2*h^8 + 788*u_1*v_2*h^8 + 870*u_2*v_2*h^8 - 4610*v_1*v_2*h^8 + 2343*v_2^2*h^8 + 3231*u_2*y*h^8 - 125*v_1*y*h^8 + 780*v_2*y*h^8 + 2009*u_1*h^9 - 3051*u_2*h^9 + 258*v_1*h^9 + 156*v_2*h^9 + 3764*y*h^9 - 3511*h^10,
#  v_2^2*y*h^7 + 3751*u_2^2*h^8 + 2999*u_2*v_1*h^8 + 54*v_1^2*h^8 + 3639*u_1*v_2*h^8 + 4517*u_2*v_2*h^8 - 879*v_1*v_2*h^8 + 1557*v_2^2*h^8 + 1904*u_2*y*h^8 + 3208*v_1*y*h^8 + 3945*v_2*y*h^8 - 893*u_1*h^9 - 139*u_2*h^9 - 81*v_1*h^9 + 3208*v_2*h^9 - 1498*y*h^9 + 3027*h^10,
#  v_1^2*v_2^2*h^5 + 4532*u_2^2*v_2*h^6 - 1734*u_1*v_2^2*h^6 + 867*u_2*v_2^2*h^6 - 1056*v_1*v_2^2*h^6 - 4717*u_2^2*y*h^6 + 1317*u_2*v_2*y*h^6 - 1203*v_1*v_2*y*h^6 - 610*v_2^2*y*h^6 - 3978*u_2^2*h^7 + 4245*u_2*v_1*h^7 + 288*v_1^2*h^7 - 1311*u_1*v_2*h^7 + 165*u_2*v_2*h^7 + 4509*v_1*v_2*h^7 - 3476*v_2^2*h^7 - 3709*u_2*y*h^7 - 4823*v_1*y*h^7 + 2844*v_2*y*h^7 - 2375*u_1*h^8 + 494*u_2*h^8 + 1433*v_1*h^8 - 2153*v_2*h^8 - 4553*y*h^8 - 789*h^9,
#  u_2^2*v_2*y*h^5 + 3541*u_2^2*v_2*h^6 - 739*u_1*v_2^2*h^6 - 725*u_2*v_2^2*h^6 + 4091*v_1*v_2^2*h^6 - 1348*u_2^2*y*h^6 + 3280*u_2*v_2*y*h^6 + 3872*v_1*v_2*y*h^6 - 1799*v_2^2*y*h^6 - 140*u_2^2*h^7 - 1434*u_2*v_1*h^7 - 1052*v_1^2*h^7 - 1041*u_1*v_2*h^7 - 2560*u_2*v_2*h^7 + 1658*v_1*v_2*h^7 - 4669*v_2^2*h^7 - 4142*u_2*y*h^7 + 441*v_1*y*h^7 + 382*v_2*y*h^7 - 405*u_1*h^8 + 1463*u_2*h^8 - 4170*v_1*h^8 + 1925*v_2*h^8 - 2827*y*h^8 - 1643*h^9,
#  u_2*v_2^2*y*h^5 - 1900*u_2^2*v_2*h^6 + 3539*u_1*v_2^2*h^6 + 2315*u_2*v_2^2*h^6 - 460*v_1*v_2^2*h^6 - 1371*u_2^2*y*h^6 - 1178*u_2*v_2*y*h^6 - 4564*v_1*v_2*y*h^6 + 884*v_2^2*y*h^6 - 4080*u_2^2*h^7 + 2134*u_2*v_1*h^7 - 3598*v_1^2*h^7 - 3568*u_1*v_2*h^7 - 1784*u_2*v_2*h^7 - 650*v_1*v_2*h^7 + 1651*v_2^2*h^7 - 3578*u_2*y*h^7 + 3249*v_1*y*h^7 + 737*v_2*y*h^7 - 2114*u_1*h^8 - 1430*u_2*h^8 - 2765*v_1*h^8 - 822*v_2*h^8 + 1059*y*h^8 + 2824*h^9,
#  v_1*v_2^2*y*h^5 - 1848*u_2^2*v_2*h^6 - 830*u_1*v_2^2*h^6 - 2856*u_2*v_2^2*h^6 + 3511*v_1*v_2^2*h^6 - 3710*u_2^2*y*h^6 - 4437*u_2*v_2*y*h^6 - 3768*v_1*v_2*y*h^6 - 3655*v_2^2*y*h^6 - 2710*u_2^2*h^7 - 794*u_2*v_1*h^7 - 2997*v_1^2*h^7 + 4935*u_1*v_2*h^7 + 4851*u_2*v_2*h^7 + 4528*v_1*v_2*h^7 + 2490*v_2^2*h^7 + 973*u_2*y*h^7 - 3368*v_1*y*h^7 + 916*v_2*y*h^7 + 3473*u_1*h^8 - 552*u_2*h^8 + 86*v_1*h^8 - 1748*v_2*h^8 - 3401*y*h^8 - 2397*h^9,
#  v_1^2*v_2*h^6 - 179*u_2^2*y*h^6 + 4463*u_2*v_2*y*h^6 - 4810*v_1*v_2*y*h^6 - 4284*v_2^2*y*h^6 - 2857*u_2^2*h^7 + 990*u_2*v_1*h^7 - 3236*v_1^2*h^7 - 4893*u_1*v_2*h^7 + 2535*u_2*v_2*h^7 + 379*v_1*v_2*h^7 + 66*v_2^2*h^7 + 1409*u_2*y*h^7 - 1735*v_1*y*h^7 + 3040*v_2*y*h^7 - 3168*u_1*h^8 - 2515*u_2*h^8 + 2327*v_1*h^8 + 98*v_2*h^8 + 3589*y*h^8 - 1966*h^9,
#  u_2^2*v_1*h^5 + 3070*v_1^2*v_2*h^5 - 6*u_1*v_2^2*h^5 + 5*v_1*v_2^2*h^5 - 224*u_2^2*y*h^5 - 1386*u_2*v_2*y*h^5 + 439*v_1*v_2*y*h^5 - 4822*v_2^2*y*h^5 + 4248*u_2^2*h^6 + 739*u_2*v_1*h^6 + 1878*v_1^2*h^6 - 2185*u_1*v_2*h^6 + 611*u_2*v_2*h^6 + 1646*v_1*v_2*h^6 + 1076*v_2^2*h^6 - 1353*u_2*y*h^6 + 3374*v_1*y*h^6 + 4822*v_2*y*h^6 + 2965*u_1*h^7 + 4095*u_2*h^7 + 4901*v_1*h^7 + 227*v_2*h^7 + 3695*y*h^7 + 4746*h^8,
#  u_2*v_1^2*h^5 - 4938*v_1^2*v_2*h^5 - 3184*u_2^2*y*h^5 - 3639*u_2*v_2*y*h^5 + 665*v_1*v_2*y*h^5 - 3184*v_2^2*y*h^5 - 4897*u_2^2*h^6 + 4975*u_2*v_1*h^6 - 1141*v_1^2*h^6 + 2288*u_1*v_2*h^6 - 2969*u_2*v_2*h^6 - 2775*v_1*v_2*h^6 - 2141*v_2^2*h^6 - 1883*u_2*y*h^6 + 2101*v_1*y*h^6 - 3468*v_2*y*h^6 + 3321*u_1*h^7 + 3014*u_2*h^7 + 4040*v_1*h^7 - 4346*v_2*h^7 + 2503*y*h^7 - 726*h^8,
#  u_2*v_1*v_2*h^5 + 1810*v_1^2*v_2*h^5 - 3*u_1*v_2^2*h^5 + 2*v_1*v_2^2*h^5 + 3719*u_2^2*y*h^5 + 2614*u_2*v_2*y*h^5 - 946*v_1*v_2*y*h^5 + 4389*v_2^2*y*h^5 - 2480*u_2^2*h^6 - 2869*u_2*v_1*h^6 + 2454*v_1^2*h^6 - 2115*u_1*v_2*h^6 - 3650*u_2*v_2*h^6 - 3953*v_1*v_2*h^6 - 2313*v_2^2*h^6 + 2152*u_2*y*h^6 + 2205*v_1*y*h^6 - 1724*v_2*y*h^6 + 1311*u_1*h^7 - 3603*u_2*h^7 + 639*v_1*h^7 + 4987*v_2*h^7 + 4554*y*h^7 + 786*h^8,
#  u_2*v_1*y*h^4 - v_1*v_2*y*h^4 + 1555*u_2*v_1*h^5 - 666*v_1^2*h^5 + 2364*u_1*v_2*h^5 - 4509*v_1*v_2*h^5 - 3463*u_2*y*h^5 + 2714*v_1*y*h^5 - 224*v_2*y*h^5 + 4793*u_1*h^6 + 802*u_2*h^6 - 2601*v_1*h^6 - 331*v_2*h^6 - 4807*y*h^6 + 4322*h^7,
#  u_1*u_2*h^5 - 2*u_2*v_1*h^5 - 2418*v_1^2*h^5 + 2*u_1*v_2*h^5 - v_1*v_2*h^5 + 2411*u_2*y*h^5 + 1864*v_1*y*h^5 - 2411*v_2*y*h^5 + 4257*u_1*h^6 + 2863*u_2*h^6 + 3436*v_1*h^6 + 3180*v_2*h^6 - 96*y*h^6 - 3545*h^7,
#  u_1*v_1*h^5 - 1842*u_2*v_1*h^5 - 4481*u_1*v_2*h^5 - 3684*v_1*v_2*h^5 - 2834*u_2*y*h^5 + 4633*v_1*y*h^5 - 3279*v_2*y*h^5 - 201*u_1*h^6 + 942*u_2*h^6 - 564*v_1*h^6 + 186*v_2*h^6 - 1100*y*h^6 + 4886*h^7,
#  u_1*v_1^2*h^3 - 1722*u_1*v_1*h^4 + 3417*v_1^2*h^4 - 3088*u_2*y*h^4 + 2613*v_1*y*h^4 + 3088*v_2*y*h^4 - 2694*u_1*h^5 - 3459*u_2*h^5 - 3646*v_1*h^5 + 4104*v_2*h^5 - 37*y*h^5 + 4124*h^6,
#  v_1^2*y*h^3 - 4444*u_1*v_1*h^4 - 2233*v_1^2*h^4 - 410*u_2*y*h^4 + 4041*v_1*y*h^4 + 410*v_2*y*h^4 - 1180*u_1*h^5 + 42*u_2*h^5 - 1530*v_1*h^5 + 1690*v_2*h^5 + 1683*y*h^5 - 2976*h^6,
#  u_1^2*h^3 - 2*u_1*v_1*h^3 + v_1^2*h^3 + 3574*v_1*y*h^3 + 938*u_1*h^4 - 4793*v_1*h^4 - 1988*y*h^4 + 140*h^5,
#  u_1*y*h^2 - v_1*y*h^2 - 796*u_1*h^3 + 3935*v_1*h^3 - 4378*y*h^3 - 1086*h^4,
#  u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + 691*u_1^2*h + 1382*u_1*y*h - 2537*u_1*h^2 - u_2*h^2 + 4922*v_1*h^2 + 376*y*h^2 + 756*h^3,
#  u_2^3 + 3*u_2^2*y + 3*u_2*y^2 - 1434*u_2^2*h - 2868*u_2*y*h - 4847*u_1*h^2 + 4976*u_2*h^2 + 4848*v_1*h^2 - 3378*y*h^2 - 2154*h^3,
#  v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + 691*v_1^2*h + 1382*v_1*y*h - 4921*u_1*h^2 - 2701*v_1*h^2 - v_2*h^2 + 376*y*h^2 + 756*h^3,
#  v_2^3 + 3*v_2^2*y + 3*v_2*y^2 - 1434*v_2^2*h - 2868*v_2*y*h - 4847*u_1*h^2 + 4848*v_1*h^2 + 4976*v_2*h^2 - 3378*y*h^2 + 1157*h^3,
#  y^3 + 362*u_1*h^2 - 363*v_1*h^2 - 1160*y*h^2 - 1961*h^3,
#  y^2*h - 3918*u_1*h^2 + 3918*v_1*h^2 - 4731*y*h^2 - 3452*h^3]

# %%
res = ideal(polys_h).graded_free_resolution(algorithm="minimal")
res
# Out:
# S(0) <-- S(-3)⊕S(-3)⊕S(-3)⊕S(-3)⊕S(-3)⊕S(-3) <-- S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-13) <-- S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-14)⊕S(-14)⊕S(-14)⊕S(-14)⊕S(-14) <-- S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15) <-- S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-16)⊕S(-16)⊕S(-16)⊕S(-16)⊕S(-16)⊕S(-16)⊕S(-16)⊕S(-16)⊕S(-16)⊕S(-16) <-- S(-17)⊕S(-17)⊕S(-17)⊕S(-17)⊕S(-17) <-- 0

# %%
cm_regularity(res)
# Out:
# 12

# %% [markdown]
# ## p = 10007, r = 4

# %%
p = 10007
field = GF(p, "a")

rounds = 4

mimc = MiMC(field=field, rounds=rounds)

print("")

key = field.random_element()
print("Key:", key)

plain_1 = field.random_element()
cipher_1 = mimc.encryption(plain_1, key)

print("Plain 1:", plain_1)
print("Cipher 1:", cipher_1)

plain_2 = field.random_element()
cipher_2 = mimc.encryption(plain_2, key)

print("Plain 2:", plain_2)
print("Cipher 2:", cipher_2)

print("")

polys = mimc.generate_two_plain_text_polynomials(plain_1, 
                                                 cipher_1, 
                                                 plain_2, 
                                                 cipher_2,
                                                 info_level=0)
polys_h = [poly.homogenize() for poly in polys]

for i in range(0, 2 * rounds):
    print(polys[i])
    if i == rounds - 1:
        print("\n")
# Out:
# MiMC Parameters
# Field: Finite Field of size 10007
# r: 4
# Constants: [1730, 6902, 2767, 5640]
#
# Key: 3958
# Plain 1: 9759
# Cipher 1: 1090
# Plain 2: 2771
# Cipher 2: 4748
#
# y^3 + 4446*y^2 - u_1 + 4366*y - 4708
# u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + y^3 + 692*u_1^2 + 1384*u_1*y + 692*y^2 + 2845*u_1 - u_2 + 2845*y - 2517
# u_2^3 + 3*u_2^2*y + 3*u_2*y^2 + y^3 - 1706*u_2^2 - 3412*u_2*y - 1706*y^2 + 2802*u_2 - u_3 + 2802*y + 2572
# u_3^3 + 3*u_3^2*y + 3*u_3*y^2 + y^3 - 3094*u_3^2 + 3819*u_3*y - 3094*y^2 + 2048*u_3 + 2049*y - 3545
#
#
# y^3 + 3496*y^2 - v_1 + 4492*y - 1885
# v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + y^3 + 692*v_1^2 + 1384*v_1*y + 692*y^2 + 2845*v_1 - v_2 + 2845*y - 2517
# v_2^3 + 3*v_2^2*y + 3*v_2*y^2 + y^3 - 1706*v_2^2 - 3412*v_2*y - 1706*y^2 + 2802*v_2 - v_3 + 2802*y + 2572
# v_3^3 + 3*v_3^2*y + 3*v_3*y^2 + y^3 - 3094*v_3^2 + 3819*v_3*y - 3094*y^2 + 2048*v_3 + 2049*y + 2804

# %%
lazard_gb_algorithm(polys)
# Out:
# Ring: Multivariate Polynomial Ring in u_1, u_2, u_3, v_1, v_2, v_3, y over Finite Field of size 10007
# Input polynomials:
# [y^3 + 4446*y^2 - u_1 + 4366*y - 4708, u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + y^3 + 692*u_1^2 + 1384*u_1*y + 692*y^2 + 2845*u_1 - u_2 + 2845*y - 2517, u_2^3 + 3*u_2^2*y + 3*u_2*y^2 + y^3 - 1706*u_2^2 - 3412*u_2*y - 1706*y^2 + 2802*u_2 - u_3 + 2802*y + 2572, u_3^3 + 3*u_3^2*y + 3*u_3*y^2 + y^3 - 3094*u_3^2 + 3819*u_3*y - 3094*y^2 + 2048*u_3 + 2049*y - 3545, y^3 + 3496*y^2 - v_1 + 4492*y - 1885, v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + y^3 + 692*v_1^2 + 1384*v_1*y + 692*y^2 + 2845*v_1 - v_2 + 2845*y - 2517, v_2^3 + 3*v_2^2*y + 3*v_2*y^2 + y^3 - 1706*v_2^2 - 3412*v_2*y - 1706*y^2 + 2802*v_2 - v_3 + 2802*y + 2572, v_3^3 + 3*v_3^2*y + 3*v_3*y^2 + y^3 - 3094*v_3^2 + 3819*v_3*y - 3094*y^2 + 2048*v_3 + 2049*y + 2804]
#
# --- Degree 0 ---
# Computing all monomials up to degree: 0
# Time needed: 0.0005679130554199219
# Computing Macaulay matrix.
# Time needed: 1.6689300537109375e-06
# Performing Gaussian Elimination.
# Time needed: 7.939338684082031e-05
# Is Groebner Basis: False
#
# --- Degree 1 ---
# Computing all monomials up to degree: 1
# Time needed: 0.0017766952514648438
# Computing Macaulay matrix.
# Time needed: 1.430511474609375e-06
# Performing Gaussian Elimination.
# Time needed: 0.00017333030700683594
# Is Groebner Basis: False
#
# --- Degree 2 ---
# Computing all monomials up to degree: 2
# Time needed: 0.0016219615936279297
# Computing Macaulay matrix.
# Time needed: 2.1457672119140625e-06
# Performing Gaussian Elimination.
# Time needed: 0.00023794174194335938
# Is Groebner Basis: False
#
# --- Degree 3 ---
# Computing all monomials up to degree: 3
# Time needed: 0.004863739013671875
# Computing Macaulay matrix.
# Time needed: 1.430511474609375e-06
# Performing Gaussian Elimination.
# Time needed: 0.0003190040588378906
# Is Groebner Basis: False
#
# --- Degree 4 ---
# Computing all monomials up to degree: 4
# Time needed: 0.010020256042480469
# Computing Macaulay matrix.
# Time needed: 2.1457672119140625e-06
# Performing Gaussian Elimination.
# Time needed: 0.0018947124481201172
# Is Groebner Basis: False
#
# --- Degree 5 ---
# Computing all monomials up to degree: 5
# Time needed: 0.03158402442932129
# Computing Macaulay matrix.
# Time needed: 3.0994415283203125e-06
# Performing Gaussian Elimination.
# Time needed: 0.00795745849609375
# Is Groebner Basis: False
#
# --- Degree 6 ---
# Computing all monomials up to degree: 6
# Time needed: 0.03597235679626465
# Computing Macaulay matrix.
# Time needed: 4.0531158447265625e-06
# Performing Gaussian Elimination.
# Time needed: 0.03759193420410156
# Is Groebner Basis: False
#
# --- Degree 7 ---
# Computing all monomials up to degree: 7
# Time needed: 0.07935643196105957
# Computing Macaulay matrix.
# Time needed: 6.9141387939453125e-06
# Performing Gaussian Elimination.
# Time needed: 0.20697927474975586
# Is Groebner Basis: False
#
# --- Degree 8 ---
# Computing all monomials up to degree: 8
# Time needed: 0.1273798942565918
# Computing Macaulay matrix.
# Time needed: 5.245208740234375e-06
# Performing Gaussian Elimination.
# Time needed: 1.2195327281951904
# Is Groebner Basis: False
#
# --- Degree 9 ---
# Computing all monomials up to degree: 9
# Time needed: 0.30092954635620117
# Computing Macaulay matrix.
# Time needed: 5.245208740234375e-06
# Performing Gaussian Elimination.
# Time needed: 8.199689626693726
# Is Groebner Basis: False
#
# --- Degree 10 ---
# Computing all monomials up to degree: 10
# Time needed: 0.3982250690460205
# Computing Macaulay matrix.
# Time needed: 6.198883056640625e-06
# Performing Gaussian Elimination.
# Time needed: 47.77085304260254
# Is Groebner Basis: False
#
# --- Degree 11 ---
# Computing all monomials up to degree: 11
# Time needed: 0.7441534996032715
# Computing Macaulay matrix.
# Time needed: 5.4836273193359375e-06
# Performing Gaussian Elimination.
# Time needed: 178.75297904014587
# Is Groebner Basis: False
#
# --- Degree 12 ---
# Computing all monomials up to degree: 12
# Time needed: 1.0489583015441895
# Computing Macaulay matrix.
# Time needed: 5.7220458984375e-06
# Performing Gaussian Elimination.
# Time needed: 540.6488676071167
# Is Groebner Basis: False
#
# --- Degree 13 ---
# Computing all monomials up to degree: 13
# Time needed: 1.426307201385498
# Computing Macaulay matrix.
# Time needed: 5.9604644775390625e-06
# Performing Gaussian Elimination.
# Time needed: 1561.4826402664185
# Is Groebner Basis: False
#
# --- Degree 14 ---
# Computing all monomials up to degree: 14
# Time needed: 2.2791473865509033
# Computing Macaulay matrix.
# Time needed: 5.4836273193359375e-06
# Performing Gaussian Elimination.
# Time needed: 3062.9032983779907
# Is Groebner Basis: False
#
# --- Degree 15 ---
# Computing all monomials up to degree: 15
# Time needed: 4.3147337436676025
# Computing Macaulay matrix.
# Time needed: 6.198883056640625e-06
# Performing Gaussian Elimination.
# Time needed: 6344.5993757247925
# Is Groebner Basis: False
#
# --- Degree 16 ---
# Computing all monomials up to degree: 16
# Time needed: 4.35209584236145
# Computing Macaulay matrix.
# Time needed: 5.7220458984375e-06
# Performing Gaussian Elimination.
# Time needed: 12907.664721250534
# Is Groebner Basis: True
# Total time needed: 24965.61847949028
# [u_1 - 401,
#  u_2 + 4328,
#  u_3 - 960,
#  v_1 + 3776,
#  v_2 + 4966,
#  v_3 - 1403,
#  y - 3958]

# %%
lazard_gb_algorithm(polys_h)
# Out:
# Ring: Multivariate Polynomial Ring in u_1, u_2, u_3, v_1, v_2, v_3, y, h over Finite Field of size 10007
# Input polynomials:
# [y^3 + 4446*y^2*h - u_1*h^2 + 4366*y*h^2 - 4708*h^3, u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + y^3 + 692*u_1^2*h + 1384*u_1*y*h + 692*y^2*h + 2845*u_1*h^2 - u_2*h^2 + 2845*y*h^2 - 2517*h^3, u_2^3 + 3*u_2^2*y + 3*u_2*y^2 + y^3 - 1706*u_2^2*h - 3412*u_2*y*h - 1706*y^2*h + 2802*u_2*h^2 - u_3*h^2 + 2802*y*h^2 + 2572*h^3, u_3^3 + 3*u_3^2*y + 3*u_3*y^2 + y^3 - 3094*u_3^2*h + 3819*u_3*y*h - 3094*y^2*h + 2048*u_3*h^2 + 2049*y*h^2 - 3545*h^3, y^3 + 3496*y^2*h - v_1*h^2 + 4492*y*h^2 - 1885*h^3, v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + y^3 + 692*v_1^2*h + 1384*v_1*y*h + 692*y^2*h + 2845*v_1*h^2 - v_2*h^2 + 2845*y*h^2 - 2517*h^3, v_2^3 + 3*v_2^2*y + 3*v_2*y^2 + y^3 - 1706*v_2^2*h - 3412*v_2*y*h - 1706*y^2*h + 2802*v_2*h^2 - v_3*h^2 + 2802*y*h^2 + 2572*h^3, v_3^3 + 3*v_3^2*y + 3*v_3*y^2 + y^3 - 3094*v_3^2*h + 3819*v_3*y*h - 3094*y^2*h + 2048*v_3*h^2 + 2049*y*h^2 + 2804*h^3]
#
# --- Degree 0 ---
# Computing all monomials up to degree: 0
# Time needed: 0.000545501708984375
# Computing Macaulay matrix.
# Time needed: 1.6689300537109375e-06
# Performing Gaussian Elimination.
# Time needed: 7.963180541992188e-05
# Is Groebner Basis: False
#
# --- Degree 1 ---
# Computing all monomials up to degree: 1
# Time needed: 0.0010557174682617188
# Computing Macaulay matrix.
# Time needed: 2.6226043701171875e-06
# Performing Gaussian Elimination.
# Time needed: 0.0001513957977294922
# Is Groebner Basis: False
#
# --- Degree 2 ---
# Computing all monomials up to degree: 2
# Time needed: 0.0017895698547363281
# Computing Macaulay matrix.
# Time needed: 1.1920928955078125e-06
# Performing Gaussian Elimination.
# Time needed: 0.00018906593322753906
# Is Groebner Basis: False
#
# --- Degree 3 ---
# Computing all monomials up to degree: 3
# Time needed: 0.005198478698730469
# Computing Macaulay matrix.
# Time needed: 2.1457672119140625e-06
# Performing Gaussian Elimination.
# Time needed: 0.0004036426544189453
# Is Groebner Basis: False
#
# --- Degree 4 ---
# Computing all monomials up to degree: 4
# Time needed: 0.012363910675048828
# Computing Macaulay matrix.
# Time needed: 2.384185791015625e-06
# Performing Gaussian Elimination.
# Time needed: 0.0016608238220214844
# Is Groebner Basis: False
#
# --- Degree 5 ---
# Computing all monomials up to degree: 5
# Time needed: 0.04360556602478027
# Computing Macaulay matrix.
# Time needed: 3.5762786865234375e-06
# Performing Gaussian Elimination.
# Time needed: 0.014524698257446289
# Is Groebner Basis: False
#
# --- Degree 6 ---
# Computing all monomials up to degree: 6
# Time needed: 0.05945920944213867
# Computing Macaulay matrix.
# Time needed: 3.0994415283203125e-06
# Performing Gaussian Elimination.
# Time needed: 0.051851749420166016
# Is Groebner Basis: False
#
# --- Degree 7 ---
# Computing all monomials up to degree: 7
# Time needed: 0.10723137855529785
# Computing Macaulay matrix.
# Time needed: 2.86102294921875e-06
# Performing Gaussian Elimination.
# Time needed: 0.34252476692199707
# Is Groebner Basis: False
#
# --- Degree 8 ---
# Computing all monomials up to degree: 8
# Time needed: 0.20312881469726562
# Computing Macaulay matrix.
# Time needed: 4.76837158203125e-06
# Performing Gaussian Elimination.
# Time needed: 2.052032470703125
# Is Groebner Basis: False
#
# --- Degree 9 ---
# Computing all monomials up to degree: 9
# Time needed: 0.5438859462738037
# Computing Macaulay matrix.
# Time needed: 4.5299530029296875e-06
# Performing Gaussian Elimination.
# Time needed: 13.06114935874939
# Is Groebner Basis: False
#
# --- Degree 10 ---
# Computing all monomials up to degree: 10
# Time needed: 0.7913811206817627
# Computing Macaulay matrix.
# Time needed: 4.76837158203125e-06
# Performing Gaussian Elimination.
# Time needed: 105.78958678245544
# Is Groebner Basis: False
#
# --- Degree 11 ---
# Computing all monomials up to degree: 11
# Time needed: 1.6545910835266113
# Computing Macaulay matrix.
# Time needed: 5.4836273193359375e-06
# Performing Gaussian Elimination.
# Time needed: 551.1751639842987
# Is Groebner Basis: False
#
# --- Degree 12 ---
# Computing all monomials up to degree: 12
# Time needed: 2.5353705883026123
# Computing Macaulay matrix.
# Time needed: 4.76837158203125e-06
# Performing Gaussian Elimination.
# Time needed: 1745.3144903182983
# Is Groebner Basis: False
#
# --- Degree 13 ---
# Computing all monomials up to degree: 13
# Time needed: 4.1912431716918945
# Computing Macaulay matrix.
# Time needed: 5.0067901611328125e-06
# Performing Gaussian Elimination.
# Time needed: 4985.18900513649
# Is Groebner Basis: False
#
# --- Degree 14 ---
# Computing all monomials up to degree: 14
# Time needed: 6.476820945739746
# Computing Macaulay matrix.
# Time needed: 4.76837158203125e-06
# Performing Gaussian Elimination.
# Time needed: 13735.894701957703
# Is Groebner Basis: False
#
# --- Degree 15 ---
# Computing all monomials up to degree: 15
# Time needed: 9.579392671585083
# Computing Macaulay matrix.
# Time needed: 5.4836273193359375e-06
# Performing Gaussian Elimination.
# Time needed: 28967.3906185627
# Is Groebner Basis: False
#
# --- Degree 16 ---
# Computing all monomials up to degree: 16
# Time needed: 13.401554822921753
# Computing Macaulay matrix.
# Time needed: 4.76837158203125e-06
# Performing Gaussian Elimination.
# Time needed: 58349.65413427353
# Is Groebner Basis: True
# Total time needed: 109996.67405414581
# [u_1*h^15 - 401*h^16,
#  u_2*h^15 + 4328*h^16,
#  u_3*h^15 - 960*h^16,
#  v_1*h^15 + 3776*h^16,
#  v_2*h^15 + 4966*h^16,
#  v_3*h^15 - 1403*h^16,
#  y*h^15 - 3958*h^16,
#  u_2^2*h^13 - 2816*u_1*h^14 - 76*u_2*h^14 + 28*u_3*h^14 + 1199*v_1*h^14 + 850*v_2*h^14 + 4456*v_3*h^14 - 4746*y*h^14 + 924*h^15,
#  u_1*u_3*h^13 + 1749*u_1*h^14 + 624*u_2*h^14 - 1194*u_3*h^14 - 1481*v_1*h^14 - 2753*v_2*h^14 - 4339*v_3*h^14 - 3937*y*h^14 + 3600*h^15,
#  u_2*u_3*h^13 - 1353*u_1*h^14 - 987*u_2*h^14 - 1400*u_3*h^14 + 1515*v_1*h^14 + 3923*v_2*h^14 - 4684*v_3*h^14 - 1261*y*h^14 - 2312*h^15,
#  u_3^2*h^13 - 1270*u_1*h^14 - 4301*u_2*h^14 - 3506*u_3*h^14 - 951*v_1*h^14 - 690*v_2*h^14 - 2831*v_3*h^14 + 4037*y*h^14 - 1105*h^15,
#  u_2*v_1*h^13 - 2241*u_1*h^14 - 1018*u_2*h^14 + 4815*u_3*h^14 - 1976*v_1*h^14 - 4280*v_2*h^14 + 3083*v_3*h^14 - 3001*y*h^14 - 3618*h^15,
#  u_3*v_1*h^13 + 2653*u_1*h^14 + 2384*u_2*h^14 - 1636*u_3*h^14 + 4065*v_1*h^14 - 3585*v_2*h^14 - 2487*v_3*h^14 - 3414*y*h^14 - 2464*h^15,
#  v_1^2*h^13 + 2816*u_1*h^14 + 1204*u_2*h^14 - 1378*u_3*h^14 - 83*v_1*h^14 + 3021*v_2*h^14 - 844*v_3*h^14 - 2334*y*h^14 - 3993*h^15,
#  u_1*v_2*h^13 + 3629*u_1*h^14 + 1130*u_2*h^14 - 4825*u_3*h^14 + 266*v_1*h^14 + 2787*v_2*h^14 - 725*v_3*h^14 + 3370*y*h^14 + 3351*h^15,
#  u_2*v_2*h^13 - 261*u_1*h^14 + 1998*u_2*h^14 + 4098*u_3*h^14 + 3398*v_1*h^14 + 2305*v_2*h^14 + 4663*v_3*h^14 - 3467*y*h^14 + 2413*h^15,
#  u_3*v_2*h^13 - 2087*u_1*h^14 - 803*u_2*h^14 + 2870*u_3*h^14 + 4346*v_1*h^14 - 1361*v_2*h^14 + 4950*v_3*h^14 - 4282*y*h^14 - 4575*h^15,
#  v_1*v_2*h^13 - 1039*u_1*h^14 - 4541*u_2*h^14 + 63*u_3*h^14 - 4466*v_1*h^14 + 146*v_2*h^14 - 3708*v_3*h^14 + 4756*y*h^14 - 1977*h^15,
#  v_2^2*h^13 - 3724*u_1*h^14 - 1460*u_2*h^14 + 3723*u_3*h^14 - 367*v_1*h^14 - 4009*v_2*h^14 + 1597*v_3*h^14 + 829*y*h^14 + 4837*h^15,
#  u_1*v_3*h^13 + 4245*u_1*h^14 + 4134*u_2*h^14 + 951*u_3*h^14 + 4389*v_1*h^14 + 2625*v_2*h^14 + 1458*v_3*h^14 - 422*y*h^14 - 3284*h^15,
#  u_2*v_3*h^13 + 2773*u_1*h^14 + 1991*u_2*h^14 - 3757*u_3*h^14 - 2252*v_1*h^14 + 1582*v_2*h^14 - 1885*v_3*h^14 - 1608*y*h^14 - 2113*h^15,
#  u_3*v_3*h^13 + 3212*u_1*h^14 + 3394*u_2*h^14 + 2853*u_3*h^14 - 1060*v_1*h^14 - 3937*v_2*h^14 + 31*v_3*h^14 - 3239*y*h^14 - 751*h^15,
#  v_1*v_3*h^13 + 1301*u_1*h^14 + 3793*u_2*h^14 - 3296*u_3*h^14 + 1544*v_1*h^14 - 4619*v_2*h^14 - 2850*v_3*h^14 + 4428*y*h^14 - 4604*h^15,
#  v_2*v_3*h^13 + 3025*u_1*h^14 + 435*u_2*h^14 - 2615*u_3*h^14 - 4126*v_1*h^14 + 3313*v_2*h^14 + 722*v_3*h^14 - 3889*y*h^14 + 1865*h^15,
#  v_3^2*h^13 - 1117*u_1*h^14 + 1513*u_2*h^14 + 3799*u_3*h^14 - 3410*v_1*h^14 + 2190*v_2*h^14 - 477*v_3*h^14 + 388*y*h^14 + 4682*h^15,
#  u_2*y*h^13 + 220*u_1*h^14 - 991*u_2*h^14 - 2869*u_3*h^14 - 4113*v_1*h^14 + 3690*v_2*h^14 - 1701*v_3*h^14 - 4354*y*h^14 + 4160*h^15,
#  u_3*y*h^13 - 2549*u_1*h^14 + 3096*u_2*h^14 - 4924*u_3*h^14 + 3153*v_1*h^14 + 3563*v_2*h^14 + 4751*v_3*h^14 + 3690*y*h^14 + 1348*h^15,
#  v_1*y*h^13 - 530*u_1*h^14 - 1198*u_2*h^14 + 3022*u_3*h^14 + 4663*v_1*h^14 - 4848*v_2*h^14 - 2788*v_3*h^14 + 2957*y*h^14 - 3022*h^15,
#  v_2*y*h^13 - 819*u_1*h^14 + 4865*u_2*h^14 - 2348*u_3*h^14 + 3114*v_1*h^14 + 3440*v_2*h^14 + 731*v_3*h^14 + 510*y*h^14 + 2650*h^15,
#  v_3*y*h^13 - 2557*u_1*h^14 - 4844*u_2*h^14 + 785*u_3*h^14 + 4809*v_1*h^14 + 4361*v_2*h^14 - 4859*v_3*h^14 + 4872*y*h^14 + 2392*h^15,
#  u_2^2*u_3*h^11 - 2284*u_2^2*h^12 - 4251*u_1*u_3*h^12 + 818*u_2*u_3*h^12 - 296*u_3^2*h^12 + 571*u_2*v_1*h^12 + 589*u_3*v_1*h^12 - 4588*v_1^2*h^12 + 1198*u_1*v_2*h^12 - 3612*u_2*v_2*h^12 + 3144*u_3*v_2*h^12 + 1463*v_1*v_2*h^12 + 3612*v_2^2*h^12 + 2584*u_1*v_3*h^12 + 4673*u_2*v_3*h^12 + 3508*u_3*v_3*h^12 - 1652*v_1*v_3*h^12 + 3061*v_2*v_3*h^12 + 3626*v_3^2*h^12 + 3063*u_2*y*h^12 - 387*u_3*y*h^12 + 3574*v_1*y*h^12 + 3304*v_2*y*h^12 + 1043*v_3*y*h^12 - 647*u_1*h^13 - 4401*u_2*h^13 - 4273*u_3*h^13 - 2127*v_1*h^13 - 564*v_2*h^13 + 884*v_3*h^13 - 3837*y*h^13 + 4126*h^14,
#  u_1*u_3^2*h^11 - 3946*u_2^2*h^12 - 1147*u_1*u_3*h^12 - 3929*u_2*u_3*h^12 - 3089*u_3^2*h^12 + 3030*u_2*v_1*h^12 - 1093*u_3*v_1*h^12 + 2137*v_1^2*h^12 + 3360*u_1*v_2*h^12 - 2090*u_2*v_2*h^12 + 1342*u_3*v_2*h^12 + 2703*v_1*v_2*h^12 - 320*v_2^2*h^12 + 4482*u_1*v_3*h^12 - 1449*u_2*v_3*h^12 - 77*u_3*v_3*h^12 - 2376*v_1*v_3*h^12 + 4346*v_2*v_3*h^12 - 2310*v_3^2*h^12 - 33*u_2*y*h^12 + 377*u_3*y*h^12 - 3117*v_1*y*h^12 + 1358*v_2*y*h^12 - 4751*v_3*y*h^12 + 3563*u_1*h^13 - 306*u_2*h^13 - 528*u_3*h^13 + 3609*v_1*h^13 + 2910*v_2*h^13 - 1084*v_3*h^13 + 4296*y*h^13 - 882*h^14,
#  u_2*u_3^2*h^11 - 3098*u_2^2*h^12 + 739*u_1*u_3*h^12 + 2507*u_2*u_3*h^12 + 2685*u_3^2*h^12 + 3392*u_2*v_1*h^12 + 1635*u_3*v_1*h^12 - 5002*v_1^2*h^12 - 1144*u_1*v_2*h^12 + 863*u_2*v_2*h^12 - 2317*u_3*v_2*h^12 - 4520*v_1*v_2*h^12 + 639*v_2^2*h^12 + 522*u_1*v_3*h^12 + 564*u_2*v_3*h^12 - 3632*u_3*v_3*h^12 + 1814*v_1*v_3*h^12 - 3984*v_2*v_3*h^12 + 2841*v_3^2*h^12 - 406*u_2*y*h^12 - 3922*u_3*y*h^12 + 285*v_1*y*h^12 - 1169*v_2*y*h^12 + 1459*v_3*y*h^12 - 4610*u_1*h^13 - 4239*u_2*h^13 + 1775*u_3*h^13 - 2762*v_1*h^13 - 969*v_2*h^13 - 4656*v_3*h^13 + 2327*y*h^13 - 655*h^14,
#  u_3^2*v_1*h^11 + 543*u_2^2*h^12 - 1019*u_1*u_3*h^12 - 389*u_2*u_3*h^12 + 4482*u_3^2*h^12 + 3350*u_2*v_1*h^12 - 3393*u_3*v_1*h^12 - 3355*v_1^2*h^12 + 18*u_1*v_2*h^12 + 2002*u_2*v_2*h^12 - 1548*u_3*v_2*h^12 + 1868*v_1*v_2*h^12 - 2372*v_2^2*h^12 - 1728*u_1*v_3*h^12 - 4856*u_2*v_3*h^12 - 2975*u_3*v_3*h^12 - 3503*v_1*v_3*h^12 - 4751*v_2*v_3*h^12 + 2801*v_3^2*h^12 - 4685*u_2*y*h^12 + 4336*u_3*y*h^12 - 2566*v_1*y*h^12 + 4415*v_2*y*h^12 + 154*v_3*y*h^12 + 1115*u_1*h^13 + 1183*u_2*h^13 + 160*u_3*h^13 - 549*v_1*h^13 - 1125*v_2*h^13 + 2984*v_3*h^13 - 3027*y*h^13 + 3812*h^14,
#  u_2*u_3*v_2*h^11 - 3570*u_2^2*h^12 - 1510*u_1*u_3*h^12 - 1281*u_2*u_3*h^12 - 4928*u_3^2*h^12 + 1720*u_2*v_1*h^12 + 3067*u_3*v_1*h^12 - 3834*v_1^2*h^12 + 3562*u_1*v_2*h^12 - 4761*u_2*v_2*h^12 + 27*u_3*v_2*h^12 - 3776*v_1*v_2*h^12 - 2911*v_2^2*h^12 + 181*u_1*v_3*h^12 - 3633*u_2*v_3*h^12 + 908*u_3*v_3*h^12 - 1071*v_1*v_3*h^12 - 3059*v_2*v_3*h^12 + 1310*v_3^2*h^12 - 4434*u_2*y*h^12 - 4398*u_3*y*h^12 - 3109*v_1*y*h^12 - 1702*v_2*y*h^12 - 2523*v_3*y*h^12 + 4204*u_1*h^13 - 2292*u_2*h^13 + 2889*u_3*h^13 + 941*v_1*h^13 - 702*v_2*h^13 - 1836*v_3*h^13 - 2590*y*h^13 + 4598*h^14,
#  u_3^2*v_2*h^11 + 4005*u_2^2*h^12 - 3346*u_1*u_3*h^12 - 3170*u_2*u_3*h^12 - 1923*u_3^2*h^12 + 1500*u_2*v_1*h^12 + 531*u_3*v_1*h^12 + 439*v_1^2*h^12 + 986*u_1*v_2*h^12 + 4424*u_2*v_2*h^12 - 2325*u_3*v_2*h^12 + 2070*v_1*v_2*h^12 - 1045*v_2^2*h^12 - 2470*u_1*v_3*h^12 - 1968*u_2*v_3*h^12 + 1662*u_3*v_3*h^12 - 750*v_1*v_3*h^12 + 43*v_2*v_3*h^12 - 1521*v_3^2*h^12 + 971*u_2*y*h^12 + 1004*u_3*y*h^12 + 866*v_1*y*h^12 - 1314*v_2*y*h^12 - 3310*v_3*y*h^12 + 3854*u_1*h^13 + 4073*u_2*h^13 + 1883*u_3*h^13 - 3743*v_1*h^13 + 1872*v_2*h^13 + 3274*v_3*h^13 - 4384*y*h^13 - 1735*h^14,
#  u_3*v_2^2*h^11 + 4176*u_2^2*h^12 + 1114*u_1*u_3*h^12 + 3570*u_2*u_3*h^12 - 1150*u_3^2*h^12 - 1948*u_2*v_1*h^12 + 2237*u_3*v_1*h^12 - 638*v_1^2*h^12 - 1072*u_1*v_2*h^12 + 540*u_2*v_2*h^12 - 3068*u_3*v_2*h^12 + 2493*v_1*v_2*h^12 - 1955*v_2^2*h^12 + 2533*u_1*v_3*h^12 - 1244*u_2*v_3*h^12 - 3717*u_3*v_3*h^12 - 599*v_1*v_3*h^12 - 1928*v_2*v_3*h^12 + 2322*v_3^2*h^12 - 815*u_2*y*h^12 - 472*u_3*y*h^12 + 1600*v_1*y*h^12 + 4871*v_2*y*h^12 + 633*v_3*y*h^12 - 3478*u_1*h^13 - 3535*u_2*h^13 - 1294*u_3*h^13 - 4290*v_1*h^13 + 1244*v_2*h^13 - 4027*v_3*h^13 + 1337*y*h^13 - 4861*h^14,
#  u_2^2*v_3*h^11 - 1233*u_2^2*h^12 - 2520*u_1*u_3*h^12 - 745*u_2*u_3*h^12 - 1860*u_3^2*h^12 - 1475*u_2*v_1*h^12 + 2485*u_3*v_1*h^12 - 1805*v_1^2*h^12 - 3413*u_1*v_2*h^12 + 2317*u_2*v_2*h^12 + 3079*u_3*v_2*h^12 - 4079*v_1*v_2*h^12 + 4164*v_2^2*h^12 + 1917*u_1*v_3*h^12 + 3968*u_2*v_3*h^12 - 2463*u_3*v_3*h^12 + 1822*v_1*v_3*h^12 + 2617*v_2*v_3*h^12 - 3410*v_3^2*h^12 - 1952*u_2*y*h^12 + 4443*u_3*y*h^12 + 1889*v_1*y*h^12 - 2835*v_2*y*h^12 + 3660*v_3*y*h^12 + 1083*u_1*h^13 + 659*u_2*h^13 + 3108*u_3*h^13 + 1897*v_1*h^13 + 2692*v_2*h^13 + 325*v_3*h^13 - 1322*y*h^13 - 4160*h^14,
#  u_1*u_3*v_3*h^11 + 1189*u_2^2*h^12 - 831*u_1*u_3*h^12 - 3402*u_2*u_3*h^12 - 2978*u_3^2*h^12 - 2282*u_2*v_1*h^12 + 3762*u_3*v_1*h^12 - 2016*v_1^2*h^12 - 614*u_1*v_2*h^12 + 1369*u_2*v_2*h^12 + 4137*u_3*v_2*h^12 + 4435*v_1*v_2*h^12 - 3630*v_2^2*h^12 + 2198*u_1*v_3*h^12 - 981*u_2*v_3*h^12 + 2710*u_3*v_3*h^12 - 1442*v_1*v_3*h^12 + 1816*v_2*v_3*h^12 + 1063*v_3^2*h^12 + 2888*u_2*y*h^12 + 2460*u_3*y*h^12 + 2000*v_1*y*h^12 - 3975*v_2*y*h^12 + 3814*v_3*y*h^12 + 2359*u_1*h^13 + 1127*u_2*h^13 + 4511*u_3*h^13 - 3258*v_1*h^13 - 1622*v_2*h^13 - 62*v_3*h^13 + 2978*y*h^13 - 2140*h^14,
#  u_2*u_3*v_3*h^11 - 1638*u_2^2*h^12 - 2757*u_1*u_3*h^12 + 2558*u_2*u_3*h^12 - 4313*u_3^2*h^12 - 2579*u_2*v_1*h^12 + 3216*u_3*v_1*h^12 + 2071*v_1^2*h^12 + 4714*u_1*v_2*h^12 - 1258*u_2*v_2*h^12 - 3674*u_3*v_2*h^12 + 1142*v_1*v_2*h^12 + 4614*v_2^2*h^12 - 4952*u_1*v_3*h^12 - 1778*u_2*v_3*h^12 + 1431*u_3*v_3*h^12 - 1095*v_1*v_3*h^12 - 4177*v_2*v_3*h^12 - 469*v_3^2*h^12 + 1776*u_2*y*h^12 - 3645*u_3*y*h^12 + 3495*v_1*y*h^12 + 4300*v_2*y*h^12 - 1909*v_3*y*h^12 + 4375*u_1*h^13 - 4335*u_2*h^13 + 4462*u_3*h^13 - 3664*v_1*h^13 - 881*v_2*h^13 + 148*v_3*h^13 - 109*y*h^13 - 1531*h^14,
#  u_3^2*v_3*h^11 + 574*u_2^2*h^12 + 3957*u_1*u_3*h^12 - 3484*u_2*u_3*h^12 + 3456*u_3^2*h^12 + 30*u_2*v_1*h^12 + 1569*u_3*v_1*h^12 + 1305*v_1^2*h^12 + 2925*u_1*v_2*h^12 + 79*u_2*v_2*h^12 - 476*u_3*v_2*h^12 + 2716*v_1*v_2*h^12 - 3081*v_2^2*h^12 - 4480*u_1*v_3*h^12 + 3998*u_2*v_3*h^12 + 2375*u_3*v_3*h^12 - 1129*v_1*v_3*h^12 - 3888*v_2*v_3*h^12 + 580*v_3^2*h^12 - 1328*u_2*y*h^12 + 1592*u_3*y*h^12 + 3517*v_1*y*h^12 - 3628*v_2*y*h^12 - 181*v_3*y*h^12 + 2099*u_1*h^13 + 270*u_2*h^13 - 1254*u_3*h^13 + 1255*v_1*h^13 - 644*v_2*h^13 - 4161*v_3*h^13 - 208*y*h^13 + 3039*h^14,
#  u_3*v_1*v_3*h^11 - 3317*u_2^2*h^12 - 209*u_1*u_3*h^12 + 516*u_2*u_3*h^12 - 2430*u_3^2*h^12 - 929*u_2*v_1*h^12 + 4799*u_3*v_1*h^12 - 1184*v_1^2*h^12 + 2529*u_1*v_2*h^12 + 3842*u_2*v_2*h^12 + 1801*u_3*v_2*h^12 + 130*v_1*v_2*h^12 + 3422*v_2^2*h^12 - 593*u_1*v_3*h^12 + 798*u_2*v_3*h^12 - 2394*u_3*v_3*h^12 - 3096*v_1*v_3*h^12 + 3503*v_2*v_3*h^12 + 592*v_3^2*h^12 - 1914*u_2*y*h^12 - 488*u_3*y*h^12 + 424*v_1*y*h^12 - 3425*v_2*y*h^12 + 701*v_3*y*h^12 + 709*u_1*h^13 - 1975*u_2*h^13 + 4672*u_3*h^13 - 1166*v_1*h^13 + 644*v_2*h^13 + 4180*v_3*h^13 + 4398*y*h^13 - 359*h^14,
#  u_1*v_2*v_3*h^11 + 1354*u_2^2*h^12 - 4033*u_1*u_3*h^12 + 2032*u_2*u_3*h^12 - 2235*u_3^2*h^12 + 3358*u_2*v_1*h^12 + 1700*u_3*v_1*h^12 - 673*v_1^2*h^12 - 362*u_1*v_2*h^12 - 4894*u_2*v_2*h^12 + 4750*u_3*v_2*h^12 + 1509*v_1*v_2*h^12 + 4235*v_2^2*h^12 + 3390*u_1*v_3*h^12 + 236*u_2*v_3*h^12 + 3679*u_3*v_3*h^12 + 3731*v_1*v_3*h^12 + 3308*v_2*v_3*h^12 + 951*v_3^2*h^12 + 3683*u_2*y*h^12 - 3115*u_3*y*h^12 + 2936*v_1*y*h^12 - 230*v_2*y*h^12 + 2612*v_3*y*h^12 + 3296*u_1*h^13 - 2293*u_2*h^13 - 2696*u_3*h^13 + 392*v_1*h^13 - 4599*v_2*h^13 - 1151*v_3*h^13 + 1342*y*h^13 + 4968*h^14,
#  u_2*v_2*v_3*h^11 + 2758*u_2^2*h^12 - 2579*u_1*u_3*h^12 - 501*u_2*u_3*h^12 + 4934*u_3^2*h^12 - 287*u_2*v_1*h^12 - 907*u_3*v_1*h^12 - 4435*v_1^2*h^12 - 1298*u_1*v_2*h^12 + 4574*u_2*v_2*h^12 + 246*u_3*v_2*h^12 - 494*v_1*v_2*h^12 + 2859*v_2^2*h^12 - 1593*u_1*v_3*h^12 - 4472*u_2*v_3*h^12 - 3523*u_3*v_3*h^12 - 2555*v_1*v_3*h^12 + 2108*v_2*v_3*h^12 - 3224*v_3^2*h^12 + 4144*u_2*y*h^12 - 515*u_3*y*h^12 + 184*v_1*y*h^12 - 1680*v_2*y*h^12 - 2381*v_3*y*h^12 + 1650*u_1*h^13 - 496*u_2*h^13 + 3480*u_3*h^13 + 3542*v_1*h^13 - 1553*v_2*h^13 + 1917*v_3*h^13 + 1041*y*h^13 + 4132*h^14,
#  u_3*v_2*v_3*h^11 - 2662*u_2^2*h^12 + 752*u_1*u_3*h^12 + 206*u_2*u_3*h^12 + 821*u_3^2*h^12 + 2746*u_2*v_1*h^12 - 832*u_3*v_1*h^12 + 2780*v_1^2*h^12 - 3526*u_1*v_2*h^12 - 1400*u_2*v_2*h^12 - 646*u_3*v_2*h^12 + 1953*v_1*v_2*h^12 - 3060*v_2^2*h^12 + 543*u_1*v_3*h^12 - 4920*u_2*v_3*h^12 + 3905*u_3*v_3*h^12 + 519*v_1*v_3*h^12 + 82*v_2*v_3*h^12 - 3127*v_3^2*h^12 - 4840*u_2*y*h^12 + 2877*u_3*y*h^12 + 2263*v_1*y*h^12 + 887*v_2*y*h^12 + 1185*v_3*y*h^12 + 3126*u_1*h^13 - 1231*u_2*h^13 - 2916*u_3*h^13 + 110*v_1*h^13 + 3474*v_2*h^13 - 3712*v_3*h^13 - 1680*y*h^13 - 332*h^14,
#  v_1*v_2*v_3*h^11 - 4854*u_2^2*h^12 - 3850*u_1*u_3*h^12 - 2733*u_2*u_3*h^12 - 1246*u_3^2*h^12 - 2692*u_2*v_1*h^12 + 2892*u_3*v_1*h^12 - 237*v_1^2*h^12 - 788*u_1*v_2*h^12 - 1933*u_2*v_2*h^12 + 3132*u_3*v_2*h^12 + 4898*v_1*v_2*h^12 - 3372*v_2^2*h^12 + 4955*u_1*v_3*h^12 - 639*u_2*v_3*h^12 - 1907*u_3*v_3*h^12 + 1855*v_1*v_3*h^12 + 3788*v_2*v_3*h^12 - 2948*v_3^2*h^12 + 1982*u_2*y*h^12 - 3597*u_3*y*h^12 - 43*v_1*y*h^12 + 390*v_2*y*h^12 - 753*v_3*y*h^12 - 109*u_1*h^13 + 4652*u_2*h^13 - 3080*u_3*h^13 + 2682*v_1*h^13 - 3776*v_2*h^13 - 2293*v_3*h^13 - 1847*y*h^13 - 184*h^14,
#  v_2^2*v_3*h^11 + 4488*u_2^2*h^12 - 3551*u_1*u_3*h^12 + 4672*u_2*u_3*h^12 + 1108*u_3^2*h^12 - 3634*u_2*v_1*h^12 + 3773*u_3*v_1*h^12 + 1879*v_1^2*h^12 - 3343*u_1*v_2*h^12 + 1806*u_2*v_2*h^12 - 2677*u_3*v_2*h^12 + 1522*v_1*v_2*h^12 + 3766*v_2^2*h^12 - 4152*u_1*v_3*h^12 - 4108*u_2*v_3*h^12 + 1438*u_3*v_3*h^12 + 1896*v_1*v_3*h^12 + 1326*v_2*v_3*h^12 + 3146*v_3^2*h^12 + 2155*u_2*y*h^12 - 1830*u_3*y*h^12 - 2969*v_1*y*h^12 - 3091*v_2*y*h^12 - 1499*v_3*y*h^12 + 3284*u_1*h^13 + 257*u_2*h^13 - 20*u_3*h^13 + 445*v_1*h^13 + 1318*v_2*h^13 - 1477*v_3*h^13 + 2257*y*h^13 + 3549*h^14,
#  u_1*v_3^2*h^11 + 2994*u_2^2*h^12 - 3134*u_1*u_3*h^12 + 3917*u_2*u_3*h^12 - 2298*u_3^2*h^12 + 4755*u_2*v_1*h^12 + 4800*u_3*v_1*h^12 - 2880*v_1^2*h^12 + 1662*u_1*v_2*h^12 + 4903*u_2*v_2*h^12 - 477*u_3*v_2*h^12 - 4894*v_1*v_2*h^12 + 3482*v_2^2*h^12 - 4677*u_1*v_3*h^12 - 3919*u_2*v_3*h^12 + 4281*u_3*v_3*h^12 - 4631*v_1*v_3*h^12 - 3579*v_2*v_3*h^12 + 4029*v_3^2*h^12 - 1941*u_2*y*h^12 - 4818*u_3*y*h^12 + 369*v_1*y*h^12 - 1897*v_2*y*h^12 + 1575*v_3*y*h^12 + 1373*u_1*h^13 - 2901*u_2*h^13 + 2201*u_3*h^13 - 3729*v_1*h^13 + 873*v_2*h^13 - 330*v_3*h^13 - 1576*y*h^13 + 2827*h^14,
#  u_2*v_3^2*h^11 + 1450*u_2^2*h^12 - 3052*u_1*u_3*h^12 + 1315*u_2*u_3*h^12 + 3257*u_3^2*h^12 + 2796*u_2*v_1*h^12 + 3856*u_3*v_1*h^12 - 3113*v_1^2*h^12 + 51*u_1*v_2*h^12 + 1312*u_2*v_2*h^12 - 2080*u_3*v_2*h^12 + 3405*v_1*v_2*h^12 + 3046*v_2^2*h^12 + 1583*u_1*v_3*h^12 - 944*u_2*v_3*h^12 + 2466*u_3*v_3*h^12 - 4421*v_1*v_3*h^12 - 263*v_2*v_3*h^12 + 1086*v_3^2*h^12 - 3703*u_2*y*h^12 - 3518*u_3*y*h^12 + 3007*v_1*y*h^12 + 1898*v_2*y*h^12 + 4034*v_3*y*h^12 + 3217*u_1*h^13 + 4855*u_2*h^13 - 4456*u_3*h^13 + 2119*v_1*h^13 + 2630*v_2*h^13 + 1209*v_3*h^13 - 142*y*h^13 - 215*h^14,
#  u_3*v_3^2*h^11 + 88*u_2^2*h^12 - 2452*u_1*u_3*h^12 - 4390*u_2*u_3*h^12 - 2581*u_3^2*h^12 - 1145*u_2*v_1*h^12 - 3308*u_3*v_1*h^12 - 1142*v_1^2*h^12 + 3485*u_1*v_2*h^12 + 582*u_2*v_2*h^12 - 1666*u_3*v_2*h^12 - 1656*v_1*v_2*h^12 + 2355*v_2^2*h^12 + 851*u_1*v_3*h^12 - 2092*u_2*v_3*h^12 + u_3*v_3*h^12 - 389*v_1*v_3*h^12 - 1551*v_2*v_3*h^12 - 855*v_3^2*h^12 - 441*u_2*y*h^12 + 82*u_3*y*h^12 + 2483*v_1*y*h^12 - 929*v_2*y*h^12 + 2834*v_3*y*h^12 - 763*u_1*h^13 - 1049*u_2*h^13 - 3687*u_3*h^13 + 2895*v_1*h^13 + 4614*v_2*h^13 + 2512*v_3*h^13 + 198*y*h^13 - 4427*h^14,
#  v_1*v_3^2*h^11 + 3809*u_2^2*h^12 + 2583*u_1*u_3*h^12 + 4719*u_2*u_3*h^12 + 808*u_3^2*h^12 + 3281*u_2*v_1*h^12 - 877*u_3*v_1*h^12 + 485*v_1^2*h^12 + 892*u_1*v_2*h^12 - 29*u_2*v_2*h^12 - 4139*u_3*v_2*h^12 + 3878*v_1*v_2*h^12 + 2936*v_2^2*h^12 - 3753*u_1*v_3*h^12 - 1649*u_2*v_3*h^12 + 4524*u_3*v_3*h^12 + 1710*v_1*v_3*h^12 - 2085*v_2*v_3*h^12 - 4094*v_3^2*h^12 - 2069*u_2*y*h^12 + 146*u_3*y*h^12 - 1105*v_1*y*h^12 + 1368*v_2*y*h^12 + 4819*v_3*y*h^12 - 4315*u_1*h^13 - 1587*u_2*h^13 - 3361*u_3*h^13 - 1688*v_1*h^13 + 3515*v_2*h^13 - 3498*v_3*h^13 - 4758*y*h^13 + 3969*h^14,
#  v_2*v_3^2*h^11 + 4581*u_2^2*h^12 + 1916*u_1*u_3*h^12 - 915*u_2*u_3*h^12 + 2666*u_3^2*h^12 - 1327*u_2*v_1*h^12 - 2920*u_3*v_1*h^12 - 4379*v_1^2*h^12 - 4898*u_1*v_2*h^12 - 4185*u_2*v_2*h^12 + 2647*u_3*v_2*h^12 + 1346*v_1*v_2*h^12 + 258*v_2^2*h^12 - 3988*u_1*v_3*h^12 - 4622*u_2*v_3*h^12 + 901*u_3*v_3*h^12 + 2654*v_1*v_3*h^12 - 1722*v_2*v_3*h^12 + 2201*v_3^2*h^12 + 538*u_2*y*h^12 - 1358*u_3*y*h^12 + 3294*v_1*y*h^12 + 526*v_2*y*h^12 - 3440*v_3*y*h^12 + 2408*u_1*h^13 - 2399*u_2*h^13 + 670*u_3*h^13 + 2426*v_1*h^13 + 4061*v_2*h^13 - 3836*v_3*h^13 + 3956*y*h^13 + 449*h^14,
#  u_2^2*y*h^11 - 1156*u_2^2*h^12 - 713*u_1*u_3*h^12 + 706*u_2*u_3*h^12 + 3483*u_3^2*h^12 + 3882*u_2*v_1*h^12 + 3334*u_3*v_1*h^12 + 2*v_1^2*h^12 - 3431*u_1*v_2*h^12 + 2974*u_2*v_2*h^12 - 190*u_3*v_2*h^12 - 864*v_1*v_2*h^12 - 2524*v_2^2*h^12 + 4634*u_1*v_3*h^12 - 3975*u_2*v_3*h^12 + 1345*u_3*v_3*h^12 + 2836*v_1*v_3*h^12 - 167*v_2*v_3*h^12 + 2415*v_3^2*h^12 + 4345*u_2*y*h^12 + 3794*u_3*y*h^12 + 2721*v_1*y*h^12 - 4496*v_2*y*h^12 - 2285*v_3*y*h^12 - 754*u_1*h^13 - 2592*u_2*h^13 + 4918*u_3*h^13 - 1457*v_1*h^13 - 891*v_2*h^13 - 2269*v_3*h^13 - 4157*y*h^13 - 2616*h^14,
#  u_2*u_3*y*h^11 + 3008*u_2^2*h^12 + 2467*u_1*u_3*h^12 - 909*u_2*u_3*h^12 - 838*u_3^2*h^12 + 1583*u_2*v_1*h^12 + 1581*u_3*v_1*h^12 + 3188*v_1^2*h^12 - 3249*u_1*v_2*h^12 - 261*u_2*v_2*h^12 - 2458*u_3*v_2*h^12 - 4835*v_1*v_2*h^12 - 877*v_2^2*h^12 - 440*u_1*v_3*h^12 - 3552*u_2*v_3*h^12 + 4451*u_3*v_3*h^12 + 1203*v_1*v_3*h^12 + 346*v_2*v_3*h^12 - 4332*v_3^2*h^12 - 794*u_2*y*h^12 - 1687*u_3*y*h^12 + 3657*v_1*y*h^12 + 2241*v_2*y*h^12 - 2135*v_3*y*h^12 + 4348*u_1*h^13 + 4172*u_2*h^13 - 1861*u_3*h^13 - 1421*v_1*h^13 + 412*v_2*h^13 - 2718*v_3*h^13 + 3628*y*h^13 - 2020*h^14,
#  u_3^2*y*h^11 - 4383*u_2^2*h^12 + 4824*u_1*u_3*h^12 - 2513*u_2*u_3*h^12 + 1329*u_3^2*h^12 - 1828*u_2*v_1*h^12 + 1532*u_3*v_1*h^12 - 2132*v_1^2*h^12 - 979*u_1*v_2*h^12 - 4242*u_2*v_2*h^12 - 4137*u_3*v_2*h^12 + 4634*v_1*v_2*h^12 + 4047*v_2^2*h^12 - 1040*u_1*v_3*h^12 - 3178*u_2*v_3*h^12 - 2926*u_3*v_3*h^12 - 1633*v_1*v_3*h^12 - 2459*v_2*v_3*h^12 - 977*v_3^2*h^12 + 4960*u_2*y*h^12 - 3859*u_3*y*h^12 - 2653*v_1*y*h^12 + 4791*v_2*y*h^12 + 4981*v_3*y*h^12 - 2678*u_1*h^13 - 1487*u_2*h^13 - 1985*u_3*h^13 + 4813*v_1*h^13 - 2355*v_2*h^13 + 2422*v_3*h^13 + 1263*y*h^13 + 2280*h^14,
#  u_3*v_1*y*h^11 + 2797*u_2^2*h^12 + 2215*u_1*u_3*h^12 + 523*u_2*u_3*h^12 - 4353*u_3^2*h^12 - 2390*u_2*v_1*h^12 + 1234*u_3*v_1*h^12 - 2314*v_1^2*h^12 - 2668*u_1*v_2*h^12 - 2609*u_2*v_2*h^12 + 527*u_3*v_2*h^12 + 2662*v_1*v_2*h^12 - 4822*v_2^2*h^12 + 4965*u_1*v_3*h^12 - 4618*u_2*v_3*h^12 - 3167*u_3*v_3*h^12 + 3410*v_1*v_3*h^12 - 1674*v_2*v_3*h^12 + 2036*v_3^2*h^12 + 4569*u_2*y*h^12 + 3981*u_3*y*h^12 - 1924*v_1*y*h^12 + 1749*v_2*y*h^12 - 1464*v_3*y*h^12 + 4880*u_1*h^13 + 3467*u_2*h^13 - 1462*u_3*h^13 - 4103*v_1*h^13 + 269*v_2*h^13 - 116*v_3*h^13 + 3828*y*h^13 + 1547*h^14,
#  u_2*v_2*y*h^11 - 763*u_2^2*h^12 - 3438*u_1*u_3*h^12 - 2232*u_2*u_3*h^12 + 4725*u_3^2*h^12 + 2075*u_2*v_1*h^12 + 2343*u_3*v_1*h^12 + 3382*v_1^2*h^12 - 3153*u_1*v_2*h^12 + 3473*u_2*v_2*h^12 - 36*u_3*v_2*h^12 - 4191*v_1*v_2*h^12 - 1494*v_2^2*h^12 + 2079*u_1*v_3*h^12 + 4140*u_2*v_3*h^12 - 1624*u_3*v_3*h^12 - 4589*v_1*v_3*h^12 + 3570*v_2*v_3*h^12 + 2120*v_3^2*h^12 + 1077*u_2*y*h^12 + 3381*u_3*y*h^12 - 2111*v_1*y*h^12 - 82*v_2*y*h^12 - 2793*v_3*y*h^12 + 4349*u_1*h^13 + 1350*u_2*h^13 - 4094*u_3*h^13 - 1252*v_1*h^13 - 2425*v_2*h^13 + 1820*v_3*h^13 - 2579*y*h^13 + 1346*h^14,
#  u_3*v_2*y*h^11 + 4210*u_2^2*h^12 - 1891*u_1*u_3*h^12 - 757*u_2*u_3*h^12 - 3688*u_3^2*h^12 + 1494*u_2*v_1*h^12 + 4782*u_3*v_1*h^12 - 3941*v_1^2*h^12 - 3864*u_1*v_2*h^12 - 991*u_2*v_2*h^12 + 4504*u_3*v_2*h^12 - 2484*v_1*v_2*h^12 - 2194*v_2^2*h^12 + 3801*u_1*v_3*h^12 - 214*u_2*v_3*h^12 + 1248*u_3*v_3*h^12 - 1735*v_1*v_3*h^12 - 665*v_2*v_3*h^12 + 3435*v_3^2*h^12 - 1292*u_2*y*h^12 + 2291*u_3*y*h^12 + 1149*v_1*y*h^12 + 3255*v_2*y*h^12 + 1073*v_3*y*h^12 - 3969*u_1*h^13 - 3534*u_2*h^13 + 4800*u_3*h^13 - 1312*v_1*h^13 + 166*v_2*h^13 - 4759*v_3*h^13 + 4295*y*h^13 - 640*h^14,
#  v_1*v_2*y*h^11 + 3558*u_2^2*h^12 + 1572*u_1*u_3*h^12 - 2408*u_2*u_3*h^12 + 1710*u_3^2*h^12 - 1464*u_2*v_1*h^12 - 2850*u_3*v_1*h^12 - 3100*v_1^2*h^12 + 3686*u_1*v_2*h^12 - 268*u_2*v_2*h^12 - 3367*u_3*v_2*h^12 + 1710*v_1*v_2*h^12 - 3882*v_2^2*h^12 + 2827*u_1*v_3*h^12 - 3949*u_2*v_3*h^12 + 3366*u_3*v_3*h^12 + 4801*v_1*v_3*h^12 - 10*v_2*v_3*h^12 - 3020*v_3^2*h^12 - 1849*u_2*y*h^12 + 1247*u_3*y*h^12 - 2746*v_1*y*h^12 - 4918*v_2*y*h^12 - 1743*v_3*y*h^12 + 2331*u_1*h^13 + 2736*u_2*h^13 - 3049*u_3*h^13 - 664*v_1*h^13 + 1888*v_2*h^13 - 3511*v_3*h^13 + 3886*y*h^13 - 57*h^14,
#  v_2^2*y*h^11 - 1566*u_2^2*h^12 + 3906*u_1*u_3*h^12 + 4093*u_2*u_3*h^12 - 2851*u_3^2*h^12 - 4316*u_2*v_1*h^12 - 3614*u_3*v_1*h^12 - 394*v_1^2*h^12 + 2720*u_1*v_2*h^12 + 2001*u_2*v_2*h^12 + 3102*u_3*v_2*h^12 - 3200*v_1*v_2*h^12 + 3991*v_2^2*h^12 + 3703*u_1*v_3*h^12 + 1170*u_2*v_3*h^12 - 142*u_3*v_3*h^12 + 71*v_1*v_3*h^12 - 3825*v_2*v_3*h^12 - 4942*v_3^2*h^12 - 3098*u_2*y*h^12 - 1287*u_3*y*h^12 + 3207*v_1*y*h^12 - 4075*v_2*y*h^12 - 3119*v_3*y*h^12 - 230*u_1*h^13 - 479*u_2*h^13 + 4950*u_3*h^13 - 583*v_1*h^13 + 669*v_2*h^13 - 4292*v_3*h^13 - 525*y*h^13 - 4157*h^14,
#  u_2*v_3*y*h^11 + 997*u_2^2*h^12 + 2359*u_1*u_3*h^12 + 3576*u_2*u_3*h^12 + 2262*u_3^2*h^12 + 2025*u_2*v_1*h^12 - 499*u_3*v_1*h^12 + 4427*v_1^2*h^12 + 4223*u_1*v_2*h^12 - 3894*u_2*v_2*h^12 - 2487*u_3*v_2*h^12 - 390*v_1*v_2*h^12 + 2918*v_2^2*h^12 + 2446*u_1*v_3*h^12 + 3596*u_2*v_3*h^12 - 285*u_3*v_3*h^12 + 2860*v_1*v_3*h^12 + 178*v_2*v_3*h^12 - 1835*v_3^2*h^12 + 4788*u_2*y*h^12 - 2561*u_3*y*h^12 + 449*v_1*y*h^12 + 2666*v_2*y*h^12 - 423*v_3*y*h^12 + 2161*u_1*h^13 + 647*u_2*h^13 + 2658*u_3*h^13 + 1434*v_1*h^13 + 2536*v_2*h^13 - 1796*v_3*h^13 + 4834*y*h^13 + 215*h^14,
#  u_3*v_3*y*h^11 - 2339*u_2^2*h^12 - 4597*u_1*u_3*h^12 + 3521*u_2*u_3*h^12 - 4049*u_3^2*h^12 + 3852*u_2*v_1*h^12 - 929*u_3*v_1*h^12 - 4373*v_1^2*h^12 + 2272*u_1*v_2*h^12 + 4183*u_2*v_2*h^12 + 3895*u_3*v_2*h^12 + 150*v_1*v_2*h^12 + 2835*v_2^2*h^12 - 492*u_1*v_3*h^12 + 4963*u_2*v_3*h^12 + 3278*u_3*v_3*h^12 - 3951*v_1*v_3*h^12 - 1670*v_2*v_3*h^12 + 2841*v_3^2*h^12 - 3816*u_2*y*h^12 - 1835*u_3*y*h^12 - 2675*v_1*y*h^12 + 1208*v_2*y*h^12 - 47*v_3*y*h^12 + 3684*u_1*h^13 + 12*u_2*h^13 + 3031*u_3*h^13 - 4263*v_1*h^13 - 26*v_2*h^13 + 112*v_3*h^13 + 177*y*h^13 + 994*h^14,
#  v_1*v_3*y*h^11 - 103*u_2^2*h^12 - 4279*u_1*u_3*h^12 + 4375*u_2*u_3*h^12 - 2661*u_3^2*h^12 + 4251*u_2*v_1*h^12 - 1278*u_3*v_1*h^12 - 4516*v_1^2*h^12 + 4772*u_1*v_2*h^12 + 4466*u_2*v_2*h^12 - 541*u_3*v_2*h^12 + 1166*v_1*v_2*h^12 + 1788*v_2^2*h^12 - 1413*u_1*v_3*h^12 - 4645*u_2*v_3*h^12 - 557*u_3*v_3*h^12 + 3960*v_1*v_3*h^12 - 4777*v_2*v_3*h^12 + 1309*v_3^2*h^12 + 4750*u_2*y*h^12 + 1785*u_3*y*h^12 + 4231*v_1*y*h^12 - 4407*v_2*y*h^12 - 1815*v_3*y*h^12 + 2658*u_1*h^13 + 3925*u_2*h^13 - 2081*u_3*h^13 + 649*v_1*h^13 + 2202*v_2*h^13 + 2058*v_3*h^13 + 2852*y*h^13 + 4903*h^14,
#  v_2*v_3*y*h^11 + 194*u_2^2*h^12 - 81*u_1*u_3*h^12 + 514*u_2*u_3*h^12 + 1922*u_3^2*h^12 - 1377*u_2*v_1*h^12 - 3745*u_3*v_1*h^12 - 4825*v_1^2*h^12 - 187*u_1*v_2*h^12 + 4708*u_2*v_2*h^12 - 4534*u_3*v_2*h^12 + 4488*v_1*v_2*h^12 - 4057*v_2^2*h^12 + 545*u_1*v_3*h^12 - 4142*u_2*v_3*h^12 + 1969*u_3*v_3*h^12 - 1811*v_1*v_3*h^12 + 1438*v_2*v_3*h^12 + 4158*v_3^2*h^12 - 2732*u_2*y*h^12 + 891*u_3*y*h^12 + 1250*v_1*y*h^12 - 2653*v_2*y*h^12 + 3431*v_3*y*h^12 - 423*u_1*h^13 - 3488*u_2*h^13 - 1439*u_3*h^13 - 957*v_1*h^13 - 2799*v_2*h^13 - 3262*v_3*h^13 - 1093*y*h^13 + 4049*h^14,
#  v_3^2*y*h^11 - 961*u_2^2*h^12 + 920*u_1*u_3*h^12 + 557*u_2*u_3*h^12 - 1897*u_3^2*h^12 - 3148*u_2*v_1*h^12 - 2151*u_3*v_1*h^12 - 347*v_1^2*h^12 + 1067*u_1*v_2*h^12 + 3350*u_2*v_2*h^12 - 4395*u_3*v_2*h^12 + 4747*v_1*v_2*h^12 - 2458*v_2^2*h^12 - 1227*u_1*v_3*h^12 - 1919*u_2*v_3*h^12 - 3813*u_3*v_3*h^12 - 2704*v_1*v_3*h^12 - 4662*v_2*v_3*h^12 - 131*v_3^2*h^12 + 2971*u_2*y*h^12 + 3424*u_3*y*h^12 - 4980*v_1*y*h^12 + 4394*v_2*y*h^12 - 681*v_3*y*h^12 - 691*u_1*h^13 + 3438*u_2*h^13 + 422*u_3*h^13 - 1339*v_1*h^13 + 2093*v_2*h^13 - 1523*v_3*h^13 + 2277*y*h^13 + 2240*h^14,
#  u_2^2*u_3^2*v_3*h^8 + 2222*u_2^2*u_3*h^10 - 1875*u_1*u_3^2*h^10 + 3752*u_2*u_3^2*h^10 + 4267*u_3^2*v_1*h^10 + 1770*u_2*u_3*v_2*h^10 - 4778*u_3^2*v_2*h^10 + 1159*u_3*v_2^2*h^10 + 3955*u_2^2*v_3*h^10 + 1148*u_1*u_3*v_3*h^10 + 3709*u_2*u_3*v_3*h^10 + 1524*u_3^2*v_3*h^10 + 3038*u_3*v_1*v_3*h^10 - 1461*u_1*v_2*v_3*h^10 - 3691*u_2*v_2*v_3*h^10 + 3916*u_3*v_2*v_3*h^10 + 382*v_1*v_2*v_3*h^10 + 3526*v_2^2*v_3*h^10 + 1162*u_1*v_3^2*h^10 - 56*u_2*v_3^2*h^10 - 4467*u_3*v_3^2*h^10 + 1855*v_1*v_3^2*h^10 - 3068*v_2*v_3^2*h^10 - 4374*u_2^2*y*h^10 + 2868*u_2*u_3*y*h^10 + 321*u_3^2*y*h^10 - 1145*u_3*v_1*y*h^10 - 1183*u_2*v_2*y*h^10 + 2575*u_3*v_2*y*h^10 + 2845*v_1*v_2*y*h^10 + 4155*v_2^2*y*h^10 + 4949*u_2*v_3*y*h^10 + 3191*u_3*v_3*y*h^10 + 761*v_1*v_3*y*h^10 - 4504*v_2*v_3*y*h^10 + 4531*v_3^2*y*h^10 - 261*u_2^2*h^11 + 1534*u_1*u_3*h^11 - 1177*u_2*u_3*h^11 - 9*u_3^2*h^11 - 4917*u_2*v_1*h^11 + 327*u_3*v_1*h^11 - 2631*v_1^2*h^11 - 4761*u_1*v_2*h^11 - 1085*u_2*v_2*h^11 + 2413*u_3*v_2*h^11 + 4906*v_1*v_2*h^11 + 1416*v_2^2*h^11 - 2376*u_1*v_3*h^11 - 1104*u_2*v_3*h^11 + 480*u_3*v_3*h^11 + 3937*v_1*v_3*h^11 + 4023*v_2*v_3*h^11 - 15*v_3^2*h^11 - 646*u_2*y*h^11 + 4650*u_3*y*h^11 + 2989*v_1*y*h^11 + 1799*v_2*y*h^11 - 470*v_3*y*h^11 + 3334*u_1*h^12 - 2242*u_2*h^12 - 3655*u_3*h^12 + 4169*v_1*h^12 + 3181*v_2*h^12 + 3963*v_3*h^12 + 483*y*h^12 - 2234*h^13,
#  u_2*u_3^2*v_2*v_3*h^8 - 1003*u_2^2*u_3*h^10 + 1661*u_1*u_3^2*h^10 + 3337*u_2*u_3^2*h^10 - 1628*u_3^2*v_1*h^10 - 3157*u_2*u_3*v_2*h^10 + 4647*u_3^2*v_2*h^10 + 2185*u_3*v_2^2*h^10 + 3661*u_2^2*v_3*h^10 + 3283*u_1*u_3*v_3*h^10 + 257*u_2*u_3*v_3*h^10 - 1844*u_3^2*v_3*h^10 - 3378*u_3*v_1*v_3*h^10 - 4405*u_1*v_2*v_3*h^10 + 1790*u_2*v_2*v_3*h^10 - 4506*u_3*v_2*v_3*h^10 + 2411*v_1*v_2*v_3*h^10 + 636*v_2^2*v_3*h^10 + 2649*u_1*v_3^2*h^10 + 1253*u_2*v_3^2*h^10 - 771*u_3*v_3^2*h^10 - 3619*v_1*v_3^2*h^10 - 1906*v_2*v_3^2*h^10 + 1024*u_2^2*y*h^10 + 3065*u_2*u_3*y*h^10 - 923*u_3^2*y*h^10 - 4587*u_3*v_1*y*h^10 + 3483*u_2*v_2*y*h^10 + 4522*u_3*v_2*y*h^10 + 4360*v_1*v_2*y*h^10 + 3141*v_2^2*y*h^10 + 2076*u_2*v_3*y*h^10 - 116*u_3*v_3*y*h^10 + 2782*v_1*v_3*y*h^10 + 1044*v_2*v_3*y*h^10 - 169*v_3^2*y*h^10 + 1856*u_2^2*h^11 - 4460*u_1*u_3*h^11 + 1242*u_2*u_3*h^11 + 150*u_3^2*h^11 + 2066*u_2*v_1*h^11 - 4457*u_3*v_1*h^11 - 2404*v_1^2*h^11 - 942*u_1*v_2*h^11 - 3946*u_2*v_2*h^11 - 1938*u_3*v_2*h^11 + 2261*v_1*v_2*h^11 - 167*v_2^2*h^11 - 2137*u_1*v_3*h^11 - 1708*u_2*v_3*h^11 + 104*u_3*v_3*h^11 + 1100*v_1*v_3*h^11 + 2593*v_2*v_3*h^11 - 4992*v_3^2*h^11 - 707*u_2*y*h^11 + 4947*u_3*y*h^11 - 2265*v_1*y*h^11 - 3499*v_2*y*h^11 - 667*v_3*y*h^11 - 2102*u_1*h^12 + 705*u_2*h^12 + 1919*u_3*h^12 - 2235*v_1*h^12 - 1009*v_2*h^12 + 4184*v_3*h^12 + 2175*y*h^12 + 4669*h^13,
#  u_3^2*v_2^2*v_3*h^8 - 2498*u_2^2*u_3*h^10 - 586*u_1*u_3^2*h^10 + 4408*u_2*u_3^2*h^10 + 2567*u_3^2*v_1*h^10 - 1424*u_2*u_3*v_2*h^10 - 3045*u_3^2*v_2*h^10 + 2888*u_3*v_2^2*h^10 - 1604*u_2^2*v_3*h^10 + 4708*u_1*u_3*v_3*h^10 + 4881*u_2*u_3*v_3*h^10 - 1836*u_3^2*v_3*h^10 - 1494*u_3*v_1*v_3*h^10 + 4745*u_1*v_2*v_3*h^10 + 4960*u_2*v_2*v_3*h^10 + 2554*u_3*v_2*v_3*h^10 - 3903*v_1*v_2*v_3*h^10 - 1787*v_2^2*v_3*h^10 + 4981*u_1*v_3^2*h^10 - 447*u_2*v_3^2*h^10 + 3320*u_3*v_3^2*h^10 + 3300*v_1*v_3^2*h^10 + 1612*v_2*v_3^2*h^10 + 3305*u_2^2*y*h^10 + 4635*u_2*u_3*y*h^10 + 2489*u_3^2*y*h^10 - 4486*u_3*v_1*y*h^10 + 2343*u_2*v_2*y*h^10 - 3818*u_3*v_2*y*h^10 + 3435*v_1*v_2*y*h^10 + 2801*v_2^2*y*h^10 - 2831*u_2*v_3*y*h^10 + 4170*u_3*v_3*y*h^10 - 4776*v_1*v_3*y*h^10 - 4776*v_2*v_3*y*h^10 + 243*v_3^2*y*h^10 - 17*u_2^2*h^11 - 1059*u_1*u_3*h^11 - 1748*u_2*u_3*h^11 + 1956*u_3^2*h^11 + 2142*u_2*v_1*h^11 + 2516*u_3*v_1*h^11 + 4788*v_1^2*h^11 - 1577*u_1*v_2*h^11 + 2895*u_2*v_2*h^11 + 2987*u_3*v_2*h^11 - 2150*v_1*v_2*h^11 - 2669*v_2^2*h^11 - 4530*u_1*v_3*h^11 + 2383*u_2*v_3*h^11 + 4055*u_3*v_3*h^11 - 1062*v_1*v_3*h^11 - 2784*v_2*v_3*h^11 + 1209*v_3^2*h^11 + 1400*u_2*y*h^11 - 1309*u_3*y*h^11 - 765*v_1*y*h^11 - 1451*v_2*y*h^11 + 4147*v_3*y*h^11 - 1103*u_1*h^12 + 2665*u_2*h^12 + 2297*u_3*h^12 + 524*v_1*h^12 - 4619*v_2*h^12 + 3851*v_3*h^12 - 586*y*h^12 + 4426*h^13,
#  u_2^2*u_3*v_3^2*h^8 + 302*u_2^2*u_3*h^10 - 3961*u_1*u_3^2*h^10 - 589*u_2*u_3^2*h^10 + 2104*u_3^2*v_1*h^10 - 1440*u_2*u_3*v_2*h^10 + 4006*u_3^2*v_2*h^10 - 3268*u_3*v_2^2*h^10 - 2725*u_2^2*v_3*h^10 + 2737*u_1*u_3*v_3*h^10 + 1041*u_2*u_3*v_3*h^10 - 216*u_3^2*v_3*h^10 - 4397*u_3*v_1*v_3*h^10 - 2838*u_1*v_2*v_3*h^10 - 1042*u_2*v_2*v_3*h^10 - 3143*u_3*v_2*v_3*h^10 + 3676*v_1*v_2*v_3*h^10 + 1622*v_2^2*v_3*h^10 + 402*u_1*v_3^2*h^10 - 1955*u_2*v_3^2*h^10 - 1411*u_3*v_3^2*h^10 + 4023*v_1*v_3^2*h^10 + 206*v_2*v_3^2*h^10 - 738*u_2^2*y*h^10 - 2143*u_2*u_3*y*h^10 - 3384*u_3^2*y*h^10 - 4898*u_3*v_1*y*h^10 - 263*u_2*v_2*y*h^10 + 1503*u_3*v_2*y*h^10 + 3869*v_1*v_2*y*h^10 - 2136*v_2^2*y*h^10 - 3957*u_2*v_3*y*h^10 - 4857*u_3*v_3*y*h^10 - 117*v_1*v_3*y*h^10 - 337*v_2*v_3*y*h^10 + 1641*v_3^2*y*h^10 + 1857*u_2^2*h^11 + 3852*u_1*u_3*h^11 + 2410*u_2*u_3*h^11 + 1501*u_3^2*h^11 - 228*u_2*v_1*h^11 - 3176*u_3*v_1*h^11 + 4046*v_1^2*h^11 - 871*u_1*v_2*h^11 + 2731*u_2*v_2*h^11 + 3120*u_3*v_2*h^11 - 3101*v_1*v_2*h^11 - 14*v_2^2*h^11 - 4848*u_1*v_3*h^11 + 532*u_2*v_3*h^11 + 1961*u_3*v_3*h^11 - 4516*v_1*v_3*h^11 - 4289*v_2*v_3*h^11 + 3151*v_3^2*h^11 + 860*u_2*y*h^11 - 2290*u_3*y*h^11 + 1916*v_1*y*h^11 + 833*v_2*y*h^11 + 362*v_3*y*h^11 - 3601*u_1*h^12 + 396*u_2*h^12 + 2524*u_3*h^12 - 3594*v_1*h^12 - 3976*v_2*h^12 - 1644*v_3*h^12 - 4304*y*h^12 - 3566*h^13,
#  u_1*u_3^2*v_3^2*h^8 + 2604*u_2^2*u_3*h^10 - 1772*u_1*u_3^2*h^10 - 3301*u_2*u_3^2*h^10 - 1135*u_3^2*v_1*h^10 + 1025*u_2*u_3*v_2*h^10 + 1362*u_3^2*v_2*h^10 + 2586*u_3*v_2^2*h^10 - 2936*u_2^2*v_3*h^10 - 1859*u_1*u_3*v_3*h^10 + 1955*u_2*u_3*v_3*h^10 + 3943*u_3^2*v_3*h^10 + 4004*u_3*v_1*v_3*h^10 - 1558*u_1*v_2*v_3*h^10 + 2475*u_2*v_2*v_3*h^10 - 13*u_3*v_2*v_3*h^10 + 1006*v_1*v_2*v_3*h^10 - 2784*v_2^2*v_3*h^10 - 3886*u_1*v_3^2*h^10 - 2258*u_2*v_3^2*h^10 - 2833*u_3*v_3^2*h^10 - 1526*v_1*v_3^2*h^10 + 4230*v_2*v_3^2*h^10 + 2922*u_2^2*y*h^10 - 4134*u_2*u_3*y*h^10 - 106*u_3^2*y*h^10 - 395*u_3*v_1*y*h^10 + 1524*u_2*v_2*y*h^10 + 3171*u_3*v_2*y*h^10 + 194*v_1*v_2*y*h^10 + 907*v_2^2*y*h^10 + 874*u_2*v_3*y*h^10 + 4804*u_3*v_3*y*h^10 - 2630*v_1*v_3*y*h^10 + 3743*v_2*v_3*y*h^10 + 4671*v_3^2*y*h^10 - 1077*u_2^2*h^11 + 3941*u_1*u_3*h^11 - 3421*u_2*u_3*h^11 - 2535*u_3^2*h^11 - 492*u_2*v_1*h^11 + 4379*u_3*v_1*h^11 + 3303*v_1^2*h^11 + 568*u_1*v_2*h^11 - 4408*u_2*v_2*h^11 - 2678*u_3*v_2*h^11 - 4267*v_1*v_2*h^11 - 1579*v_2^2*h^11 - 2735*u_1*v_3*h^11 + 996*u_2*v_3*h^11 - 3427*u_3*v_3*h^11 - 1455*v_1*v_3*h^11 - 2872*v_2*v_3*h^11 - v_3^2*h^11 - 1967*u_2*y*h^11 + 1330*u_3*y*h^11 + 1077*v_1*y*h^11 - 2573*v_2*y*h^11 + 3287*v_3*y*h^11 + 3225*u_1*h^12 - 3040*u_2*h^12 - 1025*u_3*h^12 - 2552*v_1*h^12 + 2903*v_2*h^12 + 1991*v_3*h^12 + 2886*y*h^12 - 4995*h^13,
#  u_2*u_3^2*v_3^2*h^8 + 1388*u_2^2*u_3*h^10 + 827*u_1*u_3^2*h^10 - 3473*u_2*u_3^2*h^10 - 4064*u_3^2*v_1*h^10 - 1851*u_2*u_3*v_2*h^10 + 2777*u_3^2*v_2*h^10 - 4140*u_3*v_2^2*h^10 + 3587*u_2^2*v_3*h^10 + 3237*u_1*u_3*v_3*h^10 + 3793*u_2*u_3*v_3*h^10 - 2761*u_3^2*v_3*h^10 - 3801*u_3*v_1*v_3*h^10 + 406*u_1*v_2*v_3*h^10 + 1057*u_2*v_2*v_3*h^10 + 3764*u_3*v_2*v_3*h^10 - 476*v_1*v_2*v_3*h^10 - 4609*v_2^2*v_3*h^10 + 1614*u_1*v_3^2*h^10 + 4629*u_2*v_3^2*h^10 + 2664*u_3*v_3^2*h^10 + 735*v_1*v_3^2*h^10 + 187*v_2*v_3^2*h^10 + 312*u_2^2*y*h^10 + 1090*u_2*u_3*y*h^10 - 3293*u_3^2*y*h^10 - 3805*u_3*v_1*y*h^10 + 633*u_2*v_2*y*h^10 + 858*u_3*v_2*y*h^10 + 3834*v_1*v_2*y*h^10 - 1584*v_2^2*y*h^10 + 1761*u_2*v_3*y*h^10 + 4243*u_3*v_3*y*h^10 - 194*v_1*v_3*y*h^10 + 3652*v_2*v_3*y*h^10 - 367*v_3^2*y*h^10 + 1111*u_2^2*h^11 + 1828*u_1*u_3*h^11 - 4275*u_2*u_3*h^11 + 2161*u_3^2*h^11 - 3495*u_2*v_1*h^11 + 4373*u_3*v_1*h^11 + 4873*v_1^2*h^11 + 4912*u_1*v_2*h^11 + 1864*u_2*v_2*h^11 + 62*u_3*v_2*h^11 - 3530*v_1*v_2*h^11 + 3271*v_2^2*h^11 + 1418*u_1*v_3*h^11 + 4027*u_2*v_3*h^11 - 1290*u_3*v_3*h^11 + 1785*v_1*v_3*h^11 - 2003*v_2*v_3*h^11 - 2003*v_3^2*h^11 + 4647*u_2*y*h^11 - 4305*u_3*y*h^11 - 3070*v_1*y*h^11 - 4438*v_2*y*h^11 + 1354*v_3*y*h^11 + 3528*u_1*h^12 - 3843*u_2*h^12 - 3082*u_3*h^12 - 4944*v_1*h^12 - 4193*v_2*h^12 - 2388*v_3*h^12 + 2773*y*h^12 - 3156*h^13,
#  u_3^2*v_1*v_3^2*h^8 + 24*u_2^2*u_3*h^10 + 3377*u_1*u_3^2*h^10 + 665*u_2*u_3^2*h^10 - 4877*u_3^2*v_1*h^10 + 1256*u_2*u_3*v_2*h^10 - 2003*u_3^2*v_2*h^10 - 4265*u_3*v_2^2*h^10 - 2876*u_2^2*v_3*h^10 - 248*u_1*u_3*v_3*h^10 - 518*u_2*u_3*v_3*h^10 + 2683*u_3^2*v_3*h^10 + 954*u_3*v_1*v_3*h^10 - 1778*u_1*v_2*v_3*h^10 + 96*u_2*v_2*v_3*h^10 + 472*u_3*v_2*v_3*h^10 - 4250*v_1*v_2*v_3*h^10 - 2951*v_2^2*v_3*h^10 - 3059*u_1*v_3^2*h^10 + 3952*u_2*v_3^2*h^10 + 248*u_3*v_3^2*h^10 + 1175*v_1*v_3^2*h^10 + 4002*v_2*v_3^2*h^10 + 4984*u_2^2*y*h^10 + 754*u_2*u_3*y*h^10 - 3814*u_3^2*y*h^10 + 1073*u_3*v_1*y*h^10 - 4613*u_2*v_2*y*h^10 + 3382*u_3*v_2*y*h^10 + 232*v_1*v_2*y*h^10 + 4562*v_2^2*y*h^10 + 4033*u_2*v_3*y*h^10 - 600*u_3*v_3*y*h^10 - 3176*v_1*v_3*y*h^10 - 1102*v_2*v_3*y*h^10 - 3980*v_3^2*y*h^10 + 128*u_2^2*h^11 - 4302*u_1*u_3*h^11 - 4441*u_2*u_3*h^11 + 1825*u_3^2*h^11 + 3732*u_2*v_1*h^11 + 2902*u_3*v_1*h^11 + 1965*v_1^2*h^11 - 844*u_1*v_2*h^11 + 1556*u_2*v_2*h^11 + 4554*u_3*v_2*h^11 - 1689*v_1*v_2*h^11 + 4284*v_2^2*h^11 - 4879*u_1*v_3*h^11 + 124*u_2*v_3*h^11 - 1230*u_3*v_3*h^11 + 203*v_1*v_3*h^11 - 4348*v_2*v_3*h^11 - 2567*v_3^2*h^11 + 4243*u_2*y*h^11 - 1879*u_3*y*h^11 + 1013*v_1*y*h^11 - 3975*v_2*y*h^11 + 4083*v_3*y*h^11 - 4476*u_1*h^12 - 2361*u_2*h^12 - 1135*u_3*h^12 + 1123*v_1*h^12 - 4307*v_2*h^12 + 4369*v_3*h^12 + 753*y*h^12 + 854*h^13,
#  u_2*u_3*v_2*v_3^2*h^8 - 161*u_2^2*u_3*h^10 - 1201*u_1*u_3^2*h^10 + 2683*u_2*u_3^2*h^10 + 93*u_3^2*v_1*h^10 + 745*u_2*u_3*v_2*h^10 + 4682*u_3^2*v_2*h^10 - 2237*u_3*v_2^2*h^10 - 1611*u_2^2*v_3*h^10 - 489*u_1*u_3*v_3*h^10 - 4142*u_2*u_3*v_3*h^10 + 32*u_3^2*v_3*h^10 + 1607*u_3*v_1*v_3*h^10 - 2922*u_1*v_2*v_3*h^10 + 2001*u_2*v_2*v_3*h^10 + 589*u_3*v_2*v_3*h^10 - 4468*v_1*v_2*v_3*h^10 + 3360*v_2^2*v_3*h^10 - 16*u_1*v_3^2*h^10 + 3677*u_2*v_3^2*h^10 + 4661*u_3*v_3^2*h^10 - 225*v_1*v_3^2*h^10 + 3896*v_2*v_3^2*h^10 + 3314*u_2^2*y*h^10 + 188*u_2*u_3*y*h^10 - 4557*u_3^2*y*h^10 + 977*u_3*v_1*y*h^10 - 2139*u_2*v_2*y*h^10 + 4916*u_3*v_2*y*h^10 - 1480*v_1*v_2*y*h^10 + 2888*v_2^2*y*h^10 + 3389*u_2*v_3*y*h^10 + 4477*u_3*v_3*y*h^10 + 1301*v_1*v_3*y*h^10 + 2861*v_2*v_3*y*h^10 + 4992*v_3^2*y*h^10 - 1036*u_2^2*h^11 + 1467*u_1*u_3*h^11 - 3361*u_2*u_3*h^11 - 1635*u_3^2*h^11 + 2424*u_2*v_1*h^11 - 4953*u_3*v_1*h^11 + 3101*v_1^2*h^11 + 2332*u_1*v_2*h^11 + 2205*u_2*v_2*h^11 - 2647*u_3*v_2*h^11 - 1920*v_1*v_2*h^11 + 2016*v_2^2*h^11 - 1604*u_1*v_3*h^11 + 4938*u_2*v_3*h^11 - 873*u_3*v_3*h^11 + 3598*v_1*v_3*h^11 + 453*v_2*v_3*h^11 + 3251*v_3^2*h^11 + 1063*u_2*y*h^11 + 2171*u_3*y*h^11 - 2202*v_1*y*h^11 - 3974*v_2*y*h^11 - 3976*v_3*y*h^11 - 554*u_1*h^12 + 854*u_2*h^12 - 3483*u_3*h^12 + 155*v_1*h^12 + 2913*v_2*h^12 - 793*v_3*h^12 + 4713*y*h^12 - 1918*h^13,
#  u_3^2*v_2*v_3^2*h^8 - 149*u_2^2*u_3*h^10 - 3801*u_1*u_3^2*h^10 + 4390*u_2*u_3^2*h^10 + 2787*u_3^2*v_1*h^10 - 4594*u_2*u_3*v_2*h^10 - 4775*u_3^2*v_2*h^10 + 3954*u_3*v_2^2*h^10 + 1400*u_2^2*v_3*h^10 - 540*u_1*u_3*v_3*h^10 - 4803*u_2*u_3*v_3*h^10 + 4991*u_3^2*v_3*h^10 + 1428*u_3*v_1*v_3*h^10 - 1247*u_1*v_2*v_3*h^10 - 3602*u_2*v_2*v_3*h^10 - 1618*u_3*v_2*v_3*h^10 - 1782*v_1*v_2*v_3*h^10 - 1007*v_2^2*v_3*h^10 - 582*u_1*v_3^2*h^10 + 2806*u_2*v_3^2*h^10 + 2444*u_3*v_3^2*h^10 - 754*v_1*v_3^2*h^10 + 505*v_2*v_3^2*h^10 - 265*u_2^2*y*h^10 + 4396*u_2*u_3*y*h^10 + 745*u_3^2*y*h^10 + 1506*u_3*v_1*y*h^10 - 1225*u_2*v_2*y*h^10 - 2934*u_3*v_2*y*h^10 - 4674*v_1*v_2*y*h^10 - 1408*v_2^2*y*h^10 + 121*u_2*v_3*y*h^10 + 1095*u_3*v_3*y*h^10 + 2228*v_1*v_3*y*h^10 + 4010*v_2*v_3*y*h^10 - 2117*v_3^2*y*h^10 - 4728*u_2^2*h^11 + 4183*u_1*u_3*h^11 - 2134*u_2*u_3*h^11 + 470*u_3^2*h^11 + 4466*u_2*v_1*h^11 + 1322*u_3*v_1*h^11 - 2367*v_1^2*h^11 + 1198*u_1*v_2*h^11 + 2820*u_2*v_2*h^11 - 1270*u_3*v_2*h^11 - 4636*v_1*v_2*h^11 + 2140*v_2^2*h^11 - 3136*u_1*v_3*h^11 + 2995*u_2*v_3*h^11 + 464*u_3*v_3*h^11 - 4105*v_1*v_3*h^11 + 644*v_2*v_3*h^11 - 3998*v_3^2*h^11 - 3507*u_2*y*h^11 - 4464*u_3*y*h^11 + 1871*v_1*y*h^11 + 2228*v_2*y*h^11 - 993*v_3*y*h^11 - 4134*u_1*h^12 + 2732*u_2*h^12 + 1349*u_3*h^12 + 2317*v_1*h^12 - 2373*v_2*h^12 - 4933*v_3*h^12 + 1159*y*h^12 + 966*h^13,
#  u_3*v_2^2*v_3^2*h^8 + 2799*u_2^2*u_3*h^10 - 3826*u_1*u_3^2*h^10 + 2589*u_2*u_3^2*h^10 + 2515*u_3^2*v_1*h^10 - 3578*u_2*u_3*v_2*h^10 - 3504*u_3^2*v_2*h^10 + 586*u_3*v_2^2*h^10 - 266*u_2^2*v_3*h^10 + 3397*u_1*u_3*v_3*h^10 - 209*u_2*u_3*v_3*h^10 + 588*u_3^2*v_3*h^10 + 2444*u_3*v_1*v_3*h^10 - 1071*u_1*v_2*v_3*h^10 + 2273*u_2*v_2*v_3*h^10 + 979*u_3*v_2*v_3*h^10 + 771*v_1*v_2*v_3*h^10 - 195*v_2^2*v_3*h^10 + 4266*u_1*v_3^2*h^10 - 3294*u_2*v_3^2*h^10 - 390*u_3*v_3^2*h^10 + 3344*v_1*v_3^2*h^10 + 4525*v_2*v_3^2*h^10 - 3102*u_2^2*y*h^10 - 1525*u_2*u_3*y*h^10 + 27*u_3^2*y*h^10 + 4074*u_3*v_1*y*h^10 + 3939*u_2*v_2*y*h^10 + 145*u_3*v_2*y*h^10 + 3168*v_1*v_2*y*h^10 - 3248*v_2^2*y*h^10 - 4179*u_2*v_3*y*h^10 - 1006*u_3*v_3*y*h^10 - 3102*v_1*v_3*y*h^10 - 1282*v_2*v_3*y*h^10 + 130*v_3^2*y*h^10 + 2596*u_2^2*h^11 + 1873*u_1*u_3*h^11 + 4288*u_2*u_3*h^11 + 1978*u_3^2*h^11 - 1876*u_2*v_1*h^11 + 2352*u_3*v_1*h^11 - 3344*v_1^2*h^11 + 3651*u_1*v_2*h^11 + 2973*u_2*v_2*h^11 - 4788*u_3*v_2*h^11 + 4977*v_1*v_2*h^11 - 2717*v_2^2*h^11 + 1708*u_1*v_3*h^11 + 3406*u_2*v_3*h^11 + 4902*u_3*v_3*h^11 - 710*v_1*v_3*h^11 - 2643*v_2*v_3*h^11 + 2764*v_3^2*h^11 + 1370*u_2*y*h^11 - 3265*u_3*y*h^11 - 3996*v_1*y*h^11 - 3097*v_2*y*h^11 - 67*v_3*y*h^11 - 4765*u_1*h^12 - 1118*u_2*h^12 + 4319*u_3*h^12 + 874*v_1*h^12 - 3836*v_2*h^12 + 1511*v_3*h^12 - 1958*y*h^12 - 2515*h^13,
#  u_3^2*v_3^2*y*h^8 - 1871*u_2^2*u_3*h^10 - 3749*u_1*u_3^2*h^10 + 541*u_2*u_3^2*h^10 + 4102*u_3^2*v_1*h^10 - 3334*u_2*u_3*v_2*h^10 + 4171*u_3^2*v_2*h^10 + 3281*u_3*v_2^2*h^10 + 618*u_2^2*v_3*h^10 - 3545*u_1*u_3*v_3*h^10 - 4239*u_2*u_3*v_3*h^10 + 502*u_3^2*v_3*h^10 - 485*u_3*v_1*v_3*h^10 + 4242*u_1*v_2*v_3*h^10 - 1427*u_2*v_2*v_3*h^10 - 78*u_3*v_2*v_3*h^10 + 4950*v_1*v_2*v_3*h^10 + 2294*v_2^2*v_3*h^10 + 2511*u_1*v_3^2*h^10 - 4908*u_2*v_3^2*h^10 - 682*u_3*v_3^2*h^10 + 1258*v_1*v_3^2*h^10 + 4214*v_2*v_3^2*h^10 + 3273*u_2^2*y*h^10 - 3099*u_2*u_3*y*h^10 - 4682*u_3^2*y*h^10 + 274*u_3*v_1*y*h^10 - 3051*u_2*v_2*y*h^10 + 857*u_3*v_2*y*h^10 - 3049*v_1*v_2*y*h^10 - 1440*v_2^2*y*h^10 + 2783*u_2*v_3*y*h^10 - 679*u_3*v_3*y*h^10 - 1249*v_1*v_3*y*h^10 + 4516*v_2*v_3*y*h^10 + 2556*v_3^2*y*h^10 + 1010*u_2^2*h^11 + 4356*u_1*u_3*h^11 + 3966*u_2*u_3*h^11 - 2832*u_3^2*h^11 - 384*u_2*v_1*h^11 - 144*u_3*v_1*h^11 + 729*v_1^2*h^11 + 3653*u_1*v_2*h^11 + 4741*u_2*v_2*h^11 - 1397*u_3*v_2*h^11 + 4937*v_1*v_2*h^11 - 3787*v_2^2*h^11 - 2573*u_1*v_3*h^11 + 3612*u_2*v_3*h^11 - 1725*u_3*v_3*h^11 + 3230*v_1*v_3*h^11 - 16*v_2*v_3*h^11 + 4577*v_3^2*h^11 - 132*u_2*y*h^11 + 3861*u_3*y*h^11 - 982*v_1*y*h^11 + 1975*v_2*y*h^11 - 1187*v_3*y*h^11 + 101*u_1*h^12 - 82*u_2*h^12 + 2303*u_3*h^12 + 1879*v_1*h^12 + 3201*v_2*h^12 + 1600*v_3*h^12 + 1129*y*h^12 - 3201*h^13,
#  u_2^2*u_3^2*h^9 + 3772*u_2^2*u_3*h^10 - 1415*u_1*u_3^2*h^10 + 1611*u_2*u_3^2*h^10 - 816*u_3^2*v_1*h^10 + 951*u_2*u_3*v_2*h^10 + 926*u_3^2*v_2*h^10 + 1970*u_3*v_2^2*h^10 - 1193*u_2^2*v_3*h^10 - 1406*u_1*u_3*v_3*h^10 + 2717*u_2*u_3*v_3*h^10 + 3276*u_3^2*v_3*h^10 + 630*u_3*v_1*v_3*h^10 + 3502*u_1*v_2*v_3*h^10 + 3089*u_2*v_2*v_3*h^10 + 3888*u_3*v_2*v_3*h^10 + 1447*v_1*v_2*v_3*h^10 - 1361*v_2^2*v_3*h^10 + 4710*u_1*v_3^2*h^10 - 447*u_2*v_3^2*h^10 + 2663*u_3*v_3^2*h^10 - 3219*v_1*v_3^2*h^10 - 2794*v_2*v_3^2*h^10 - 842*u_2^2*y*h^10 - 1428*u_2*u_3*y*h^10 - 2386*u_3^2*y*h^10 - 1513*u_3*v_1*y*h^10 + 2965*u_2*v_2*y*h^10 - 385*u_3*v_2*y*h^10 + 4537*v_1*v_2*y*h^10 + 3925*v_2^2*y*h^10 + 4185*u_2*v_3*y*h^10 - 3956*u_3*v_3*y*h^10 - 1215*v_1*v_3*y*h^10 - 4759*v_2*v_3*y*h^10 + 2307*v_3^2*y*h^10 - 3071*u_2^2*h^11 + 1038*u_1*u_3*h^11 + 4009*u_2*u_3*h^11 + 2427*u_3^2*h^11 + 4488*u_2*v_1*h^11 - 4480*u_3*v_1*h^11 - 1545*v_1^2*h^11 - 4721*u_1*v_2*h^11 - 4107*u_2*v_2*h^11 + 3397*u_3*v_2*h^11 + 1023*v_1*v_2*h^11 + 135*v_2^2*h^11 - 3187*u_1*v_3*h^11 + 2088*u_2*v_3*h^11 - 1869*u_3*v_3*h^11 - 4084*v_1*v_3*h^11 - 679*v_2*v_3*h^11 - 2191*v_3^2*h^11 - 1781*u_2*y*h^11 + 4069*u_3*y*h^11 + 2186*v_1*y*h^11 + 2792*v_2*y*h^11 + 1704*v_3*y*h^11 + 2928*u_1*h^12 - 4532*u_2*h^12 + 3963*u_3*h^12 - 2753*v_1*h^12 - 784*v_2*h^12 - 691*v_3*h^12 - 55*y*h^12 - 4116*h^13,
#  u_2*u_3^2*v_2*h^9 - 622*u_2^2*u_3*h^10 + 4303*u_1*u_3^2*h^10 - 257*u_2*u_3^2*h^10 - 2800*u_3^2*v_1*h^10 + 3512*u_2*u_3*v_2*h^10 + 3785*u_3^2*v_2*h^10 - 889*u_3*v_2^2*h^10 - 4525*u_2^2*v_3*h^10 - 1216*u_1*u_3*v_3*h^10 + 2140*u_2*u_3*v_3*h^10 - 2457*u_3^2*v_3*h^10 + 4253*u_3*v_1*v_3*h^10 + 563*u_1*v_2*v_3*h^10 - 3290*u_2*v_2*v_3*h^10 - 1668*u_3*v_2*v_3*h^10 + 4191*v_1*v_2*v_3*h^10 + 1705*v_2^2*v_3*h^10 + 4289*u_1*v_3^2*h^10 - 3081*u_2*v_3^2*h^10 + 3248*u_3*v_3^2*h^10 + 3852*v_1*v_3^2*h^10 - 449*v_2*v_3^2*h^10 - 904*u_2^2*y*h^10 + 2493*u_2*u_3*y*h^10 - 4600*u_3^2*y*h^10 - 2258*u_3*v_1*y*h^10 + 3891*u_2*v_2*y*h^10 - 2712*u_3*v_2*y*h^10 - 4390*v_1*v_2*y*h^10 + 4033*v_2^2*y*h^10 - 3967*u_2*v_3*y*h^10 + 4484*u_3*v_3*y*h^10 - 4930*v_1*v_3*y*h^10 - 734*v_2*v_3*y*h^10 - 2876*v_3^2*y*h^10 - 3820*u_2^2*h^11 + 3479*u_1*u_3*h^11 - 4780*u_2*u_3*h^11 + 3317*u_3^2*h^11 - 144*u_2*v_1*h^11 + 4004*u_3*v_1*h^11 - 2412*v_1^2*h^11 - 4225*u_1*v_2*h^11 - 1600*u_2*v_2*h^11 - 1063*u_3*v_2*h^11 - 805*v_1*v_2*h^11 + 1323*v_2^2*h^11 - 736*u_1*v_3*h^11 - 3520*u_2*v_3*h^11 + 3193*u_3*v_3*h^11 - 2435*v_1*v_3*h^11 - 3296*v_2*v_3*h^11 + 3502*v_3^2*h^11 - 351*u_2*y*h^11 + 3036*u_3*y*h^11 + 1947*v_1*y*h^11 + 2058*v_2*y*h^11 + 3107*v_3*y*h^11 + 2660*u_1*h^12 - 908*u_2*h^12 - 1688*u_3*h^12 + 3232*v_1*h^12 + 2352*v_2*h^12 - 2039*v_3*h^12 + 1271*y*h^12 - 2810*h^13,
#  u_3^2*v_2^2*h^9 - 1379*u_2^2*u_3*h^10 - 2690*u_1*u_3^2*h^10 - 2839*u_2*u_3^2*h^10 - 2813*u_3^2*v_1*h^10 - 2248*u_2*u_3*v_2*h^10 - 1646*u_3^2*v_2*h^10 + 282*u_3*v_2^2*h^10 - 1987*u_2^2*v_3*h^10 + 1935*u_1*u_3*v_3*h^10 - 3196*u_2*u_3*v_3*h^10 - 2025*u_3^2*v_3*h^10 + 792*u_3*v_1*v_3*h^10 - 846*u_1*v_2*v_3*h^10 - 4611*u_2*v_2*v_3*h^10 + 1465*u_3*v_2*v_3*h^10 - 3036*v_1*v_2*v_3*h^10 - 230*v_2^2*v_3*h^10 - 3491*u_1*v_3^2*h^10 - 382*u_2*v_3^2*h^10 + 617*u_3*v_3^2*h^10 + 1580*v_1*v_3^2*h^10 + 2506*v_2*v_3^2*h^10 + 1552*u_2^2*y*h^10 - 248*u_2*u_3*y*h^10 - 1750*u_3^2*y*h^10 - 1705*u_3*v_1*y*h^10 + 1216*u_2*v_2*y*h^10 + 1479*u_3*v_2*y*h^10 - 413*v_1*v_2*y*h^10 - 3731*v_2^2*y*h^10 - 3858*u_2*v_3*y*h^10 + 4563*u_3*v_3*y*h^10 + 1240*v_1*v_3*y*h^10 + 149*v_2*v_3*y*h^10 + 144*v_3^2*y*h^10 + 2213*u_2^2*h^11 - 167*u_1*u_3*h^11 + 2361*u_2*u_3*h^11 + 679*u_3^2*h^11 - 4851*u_2*v_1*h^11 - 4807*u_3*v_1*h^11 + 4428*v_1^2*h^11 - 4095*u_1*v_2*h^11 - 1341*u_2*v_2*h^11 - 1022*u_3*v_2*h^11 + 2193*v_1*v_2*h^11 - 3581*v_2^2*h^11 - 1068*u_1*v_3*h^11 - 1063*u_2*v_3*h^11 + 2974*u_3*v_3*h^11 - 1109*v_1*v_3*h^11 - 2466*v_2*v_3*h^11 + 4319*v_3^2*h^11 - 4465*u_2*y*h^11 + 2100*u_3*y*h^11 - 2407*v_1*y*h^11 + 3533*v_2*y*h^11 - 1863*v_3*y*h^11 - 4988*u_1*h^12 + 755*u_2*h^12 - 4309*u_3*h^12 - 1930*v_1*h^12 + 1499*v_2*h^12 - 2244*v_3*h^12 + 3442*y*h^12 - 2545*h^13,
# ...
#  v_1*v_2^2*h^8 - 1990*u_2^2*y*h^8 + 437*u_2*u_3*y*h^8 - 3525*u_3*v_1*y*h^8 - 1250*u_2*v_2*y*h^8 + 1366*u_3*v_2*y*h^8 + 592*v_1*v_2*y*h^8 + 1217*v_2^2*y*h^8 + 120*u_2*v_3*y*h^8 + 1663*v_1*v_3*y*h^8 - 1923*v_2*v_3*y*h^8 + 2276*u_2^2*h^9 - 3777*u_1*u_3*h^9 + 1902*u_2*u_3*h^9 + 1778*u_2*v_1*h^9 + 3978*u_3*v_1*h^9 - 3019*v_1^2*h^9 - 2890*u_1*v_2*h^9 - 588*u_2*v_2*h^9 - 53*u_3*v_2*h^9 - 1101*v_1*v_2*h^9 - 3079*v_2^2*h^9 + 285*u_1*v_3*h^9 + 3157*u_2*v_3*h^9 + 3700*v_1*v_3*h^9 + 3794*v_2*v_3*h^9 - 2923*u_2*y*h^9 + 846*u_3*y*h^9 + 608*v_1*y*h^9 - 641*v_2*y*h^9 + 922*v_3*y*h^9 - 1139*u_1*h^10 + 3988*u_2*h^10 - 3424*u_3*h^10 - 1417*v_1*h^10 - 469*v_2*h^10 - 3528*v_3*h^10 + 1067*y*h^10 + 972*h^11,
#  u_2*v_1*v_3*h^8 - 3*u_1*v_2*v_3*h^8 + 2*v_1*v_2*v_3*h^8 + 4888*u_2^2*y*h^8 + 2500*u_2*u_3*y*h^8 + 1459*u_3*v_1*y*h^8 - 3658*u_2*v_2*y*h^8 - 1089*u_3*v_2*y*h^8 + 2130*v_1*v_2*y*h^8 - 3409*v_2^2*y*h^8 - 3051*u_2*v_3*y*h^8 + 2500*v_1*v_3*y*h^8 - 3970*v_2*v_3*y*h^8 - 1792*u_2^2*h^9 - 28*u_1*u_3*h^9 + 4080*u_2*u_3*h^9 + 2774*u_2*v_1*h^9 + 4530*u_3*v_1*h^9 - 4707*v_1^2*h^9 + 525*u_1*v_2*h^9 + 3224*u_2*v_2*h^9 + 132*u_3*v_2*h^9 + 1590*v_1*v_2*h^9 + 3160*v_2^2*h^9 - u_1*v_3*h^9 + 4087*u_2*v_3*h^9 + 3382*v_1*v_3*h^9 - 524*v_2*v_3*h^9 - 2622*u_2*y*h^9 - 379*u_3*y*h^9 + 3543*v_1*y*h^9 - 4613*v_2*y*h^9 - 226*v_3*y*h^9 + 4267*u_1*h^10 - 696*u_2*h^10 + 1985*u_3*h^10 - 2347*v_1*h^10 + 4510*v_2*h^10 - 2585*v_3*h^10 + 2839*y*h^10 + 3838*h^11,
#  v_1^2*v_3*h^8 - 3744*u_2^2*y*h^8 - 1026*u_2*u_3*y*h^8 - 3360*u_3*v_1*y*h^8 + 1529*u_2*v_2*y*h^8 + 4357*u_3*v_2*y*h^8 - 4505*v_1*v_2*y*h^8 - 4381*v_2^2*y*h^8 + 2885*u_2*v_3*y*h^8 - 675*v_1*v_3*y*h^8 + 3791*v_2*v_3*y*h^8 - 292*u_2^2*h^9 - 3971*u_1*u_3*h^9 + 274*u_2*u_3*h^9 - 3062*u_2*v_1*h^9 + 2202*u_3*v_1*h^9 - 4157*v_1^2*h^9 - 137*u_1*v_2*h^9 - 3114*u_2*v_2*h^9 - 529*u_3*v_2*h^9 + 1057*v_1*v_2*h^9 + 973*v_2^2*h^9 + 2724*u_1*v_3*h^9 - 303*u_2*v_3*h^9 - 4585*v_1*v_3*h^9 - 4017*v_2*v_3*h^9 - 4812*u_2*y*h^9 + 2436*u_3*y*h^9 - 4527*v_1*y*h^9 - 232*v_2*y*h^9 + 3947*v_3*y*h^9 + 4091*u_1*h^10 - 3432*u_2*h^10 + 394*u_3*h^10 + 2350*v_1*h^10 - 4742*v_2*h^10 - 4901*v_3*h^10 - 3982*y*h^10 - 2053*h^11,
#  u_2^2*v_2^2*h^6 + 1726*v_1*v_2^2*h^7 + 3450*u_2*v_1*v_3*h^7 + 829*v_1^2*v_3*h^7 - 343*u_1*v_2*v_3*h^7 - 3107*v_1*v_2*v_3*h^7 + 3252*u_2^2*y*h^7 + 2914*u_2*u_3*y*h^7 - 3065*u_3*v_1*y*h^7 + 3889*u_2*v_2*y*h^7 + 4435*u_3*v_2*y*h^7 - 3976*v_1*v_2*y*h^7 + 2390*v_2^2*y*h^7 + 4474*u_2*v_3*y*h^7 - 2380*v_1*v_3*y*h^7 - 2778*v_2*v_3*y*h^7 + 4485*u_2^2*h^8 - 604*u_1*u_3*h^8 + 1589*u_2*u_3*h^8 - 1235*u_2*v_1*h^8 + 3036*u_3*v_1*h^8 + 774*v_1^2*h^8 - 140*u_1*v_2*h^8 - 1374*u_2*v_2*h^8 - 1524*u_3*v_2*h^8 - 659*v_1*v_2*h^8 + 4318*v_2^2*h^8 + 463*u_1*v_3*h^8 + 4223*u_2*v_3*h^8 + 751*v_1*v_3*h^8 + 74*v_2*v_3*h^8 + 857*u_2*y*h^8 - 2033*u_3*y*h^8 - 1752*v_1*y*h^8 + 2873*v_2*y*h^8 + 1506*v_3*y*h^8 - 52*u_1*h^9 + 2918*u_2*h^9 + 1830*u_3*h^9 + 4694*v_1*h^9 - 533*v_2*h^9 + 4996*v_3*h^9 - 2605*y*h^9 - 3084*h^10,
#  u_3*v_1*v_2*y*h^6 - v_1*v_2*v_3*y*h^6 - 4057*v_1*v_2^2*h^7 - 3446*u_2*v_1*v_3*h^7 + 578*v_1^2*v_3*h^7 + 3790*u_1*v_2*v_3*h^7 + 1113*v_1*v_2*v_3*h^7 + 4835*u_2^2*y*h^7 + 2941*u_2*u_3*y*h^7 + 2693*u_3*v_1*y*h^7 + 3688*u_2*v_2*y*h^7 - 2803*u_3*v_2*y*h^7 - 1366*v_1*v_2*y*h^7 + 3867*v_2^2*y*h^7 - 2458*u_2*v_3*y*h^7 - 2098*v_1*v_3*y*h^7 - 3104*v_2*v_3*y*h^7 + 2254*u_2^2*h^8 + 3760*u_1*u_3*h^8 - 1147*u_2*u_3*h^8 - 4214*u_2*v_1*h^8 - 693*u_3*v_1*h^8 - 336*v_1^2*h^8 + 795*u_1*v_2*h^8 + 3659*u_2*v_2*h^8 - 263*u_3*v_2*h^8 - 2969*v_1*v_2*h^8 + 1670*v_2^2*h^8 - 1995*u_1*v_3*h^8 - 805*u_2*v_3*h^8 + 3371*v_1*v_3*h^8 - 2911*v_2*v_3*h^8 + 3760*u_2*y*h^8 + 4978*u_3*y*h^8 + 746*v_1*y*h^8 - 1919*v_2*y*h^8 - 3998*v_3*y*h^8 - 4854*u_1*h^9 - 3338*u_2*h^9 - 3598*u_3*h^9 - 1836*v_1*h^9 - 1019*v_2*h^9 - 3787*v_3*h^9 + 2191*y*h^9 + 4030*h^10,
#  u_2*u_3*v_1*h^7 - 2276*v_1*v_2^2*h^7 - 1048*u_2*v_1*v_3*h^7 + 2426*v_1^2*v_3*h^7 + 3132*u_1*v_2*v_3*h^7 - 2085*v_1*v_2*v_3*h^7 - 3173*u_2^2*y*h^7 + 567*u_2*u_3*y*h^7 - 2664*u_3*v_1*y*h^7 - 680*u_2*v_2*y*h^7 - 3152*u_3*v_2*y*h^7 + 2954*v_1*v_2*y*h^7 - 158*v_2^2*y*h^7 + 4942*u_2*v_3*y*h^7 + 3527*v_1*v_3*y*h^7 - 522*v_2*v_3*y*h^7 + 930*u_2^2*h^8 - 4104*u_1*u_3*h^8 - 4790*u_2*u_3*h^8 + 2625*u_2*v_1*h^8 - 60*u_3*v_1*h^8 + 773*v_1^2*h^8 - 3790*u_1*v_2*h^8 - 3919*u_2*v_2*h^8 - 1808*u_3*v_2*h^8 + 726*v_1*v_2*h^8 - 3599*v_2^2*h^8 - 4606*u_1*v_3*h^8 - 343*u_2*v_3*h^8 + 1701*v_1*v_3*h^8 + 4882*v_2*v_3*h^8 - 4053*u_2*y*h^8 + 630*u_3*y*h^8 + 1949*v_1*y*h^8 - 2417*v_2*y*h^8 - 2694*v_3*y*h^8 + 4395*u_1*h^9 - 3688*u_2*h^9 - 1432*u_3*h^9 - 1184*v_1*h^9 - 481*v_2*h^9 + 2083*v_3*h^9 + 3137*y*h^9 - 1523*h^10,
#  u_3*v_1^2*h^7 + 3160*v_1*v_2^2*h^7 + 1265*u_2*v_1*v_3*h^7 - 4150*v_1^2*v_3*h^7 - 3795*u_1*v_2*v_3*h^7 + 2530*v_1*v_2*v_3*h^7 - 1477*u_2^2*y*h^7 + 1407*u_2*u_3*y*h^7 + 2330*u_3*v_1*y*h^7 + 4816*u_2*v_2*y*h^7 - 1407*u_3*v_2*y*h^7 + 3613*v_1*v_2*y*h^7 + 3395*v_2^2*y*h^7 - 2289*u_2*v_3*y*h^7 - 2850*v_1*v_3*y*h^7 + 602*v_2*v_3*y*h^7 + 3659*u_2^2*h^8 + 4635*u_1*u_3*h^8 - 2478*u_2*u_3*h^8 - 2739*u_2*v_1*h^8 - 1177*u_3*v_1*h^8 - 499*v_1^2*h^8 - 1759*u_1*v_2*h^8 - 2341*u_2*v_2*h^8 - 4672*u_3*v_2*h^8 + 365*v_1*v_2*h^8 + 2948*v_2^2*h^8 - 479*u_1*v_3*h^8 - 2325*u_2*v_3*h^8 + 4978*v_1*v_3*h^8 + 4737*v_2*v_3*h^8 + 557*u_2*y*h^8 - 719*u_3*y*h^8 + 2705*v_1*y*h^8 + 1770*v_2*y*h^8 + 336*v_3*y*h^8 - 2716*u_1*h^9 - 4554*u_2*h^9 + 1841*u_3*h^9 - 4484*v_1*h^9 - 1217*v_2*h^9 + 4471*v_3*h^9 + 1950*y*h^9 - 3576*h^10,
#  u_2^2*v_2*h^7 - 1562*v_1*v_2^2*h^7 - 1703*u_2*v_1*v_3*h^7 - 896*v_1^2*v_3*h^7 - 4898*u_1*v_2*v_3*h^7 - 3406*v_1*v_2*v_3*h^7 - 1366*u_2^2*y*h^7 - 3124*u_2*u_3*y*h^7 + 2434*u_3*v_1*y*h^7 - 1852*u_2*v_2*y*h^7 + 3124*u_3*v_2*y*h^7 + 4038*v_1*v_2*y*h^7 - 1588*v_2^2*y*h^7 + 95*u_2*v_3*y*h^7 - 2747*v_1*v_3*y*h^7 - 2950*v_2*v_3*y*h^7 + 1923*u_2^2*h^8 - 3040*u_1*u_3*h^8 - 323*u_2*u_3*h^8 - 1334*u_2*v_1*h^8 - 1248*u_3*v_1*h^8 + 3848*v_1^2*h^8 - 3487*u_1*v_2*h^8 - 3703*u_2*v_2*h^8 - 2507*u_3*v_2*h^8 + 1987*v_1*v_2*h^8 + 4799*v_2^2*h^8 + 466*u_1*v_3*h^8 - 3748*u_2*v_3*h^8 + 248*v_1*v_3*h^8 + 1312*v_2*v_3*h^8 + 738*u_2*y*h^8 - 132*u_3*y*h^8 - 494*v_1*y*h^8 - 3633*v_2*y*h^8 + 4590*v_3*y*h^8 + 2903*u_1*h^9 - 215*u_2*h^9 + 2626*u_3*h^9 - 4801*v_1*h^9 - 4967*v_2*h^9 - 3787*v_3*h^9 - 569*y*h^9 - 1341*h^10,
#  u_1*u_3*v_2*h^7 - 2404*v_1*v_2^2*h^7 + 1553*u_2*v_1*v_3*h^7 - 4036*v_1^2*v_3*h^7 - 4669*u_1*v_2*v_3*h^7 + 3115*v_1*v_2*v_3*h^7 + 2081*u_2^2*y*h^7 - 4208*u_2*u_3*y*h^7 + 4022*u_3*v_1*y*h^7 + 3193*u_2*v_2*y*h^7 - 1561*u_3*v_2*y*h^7 - 1391*v_1*v_2*y*h^7 + 4371*v_2^2*y*h^7 + 3677*u_2*v_3*y*h^7 + 2195*v_1*v_3*y*h^7 + 1765*v_2*v_3*y*h^7 - 3366*u_2^2*h^8 - 3265*u_1*u_3*h^8 + 2781*u_2*u_3*h^8 + 2709*u_2*v_1*h^8 - 2133*u_3*v_1*h^8 + 870*v_1^2*h^8 + 1762*u_1*v_2*h^8 + 4277*u_2*v_2*h^8 - 4519*u_3*v_2*h^8 + 2666*v_1*v_2*h^8 - 1938*v_2^2*h^8 + 2741*u_1*v_3*h^8 - 2505*u_2*v_3*h^8 + 701*v_1*v_3*h^8 - 4776*v_2*v_3*h^8 + 3945*u_2*y*h^8 - 4897*u_3*y*h^8 - 3040*v_1*y*h^8 + 2540*v_2*y*h^8 - 86*v_3*y*h^8 + 1315*u_1*h^9 + 3187*u_2*h^9 - 3221*u_3*h^9 + 3985*v_1*h^9 - 3820*v_2*h^9 - 4835*v_3*h^9 - 1508*y*h^9 + 752*h^10,
#  u_3*v_1*v_2*h^7 + 4593*v_1*v_2^2*h^7 + 1584*u_2*v_1*v_3*h^7 + 277*v_1^2*v_3*h^7 - 4761*u_1*v_2*v_3*h^7 + 3176*v_1*v_2*v_3*h^7 - 3742*u_2^2*y*h^7 + 2074*u_2*u_3*y*h^7 - 480*u_3*v_1*y*h^7 - 4070*u_2*v_2*y*h^7 - 2233*u_3*v_2*y*h^7 - 4603*v_1*v_2*y*h^7 + 4819*v_2^2*y*h^7 - 4139*u_2*v_3*y*h^7 + 1483*v_1*v_3*y*h^7 - 3004*v_2*v_3*y*h^7 + 4691*u_2^2*h^8 + 1416*u_1*u_3*h^8 - 3354*u_2*u_3*h^8 + 2231*u_2*v_1*h^8 - 2851*u_3*v_1*h^8 + 1843*v_1^2*h^8 + 1857*u_1*v_2*h^8 - 3495*u_2*v_2*h^8 - 4687*u_3*v_2*h^8 - 4293*v_1*v_2*h^8 - 4738*v_2^2*h^8 + 2620*u_1*v_3*h^8 + 1118*u_2*v_3*h^8 - 4424*v_1*v_3*h^8 + 2452*v_2*v_3*h^8 - 1519*u_2*y*h^8 - 2714*u_3*y*h^8 - 2565*v_1*y*h^8 + 2206*v_2*y*h^8 + 2786*v_3*y*h^8 - 2231*u_1*h^9 + 4072*u_2*h^9 + 3568*u_3*h^9 + 2605*v_1*h^9 + 3268*v_2*h^9 + 1643*v_3*h^9 + 1745*y*h^9 + 1290*h^10,
#  u_1*v_2^2*h^7 + 279*v_1*v_2^2*h^7 + 441*u_2*v_1*v_3*h^7 - 3229*v_1^2*v_3*h^7 - 1323*u_1*v_2*v_3*h^7 + 882*v_1*v_2*v_3*h^7 + 1171*u_2^2*y*h^7 + 2278*u_2*u_3*y*h^7 + 4251*u_3*v_1*y*h^7 + 1442*u_2*v_2*y*h^7 - 2278*u_3*v_2*y*h^7 - 303*v_1*v_2*y*h^7 + 4472*v_2^2*y*h^7 + 1180*u_2*v_3*y*h^7 - 4452*v_1*v_3*y*h^7 - 3461*v_2*v_3*y*h^7 + 4856*u_2^2*h^8 - 1927*u_1*u_3*h^8 - 4012*u_2*u_3*h^8 + 1094*u_2*v_1*h^8 - 3817*u_3*v_1*h^8 - 2551*v_1^2*h^8 + 2192*u_1*v_2*h^8 - 4367*u_2*v_2*h^8 - 3752*u_3*v_2*h^8 - 1438*v_1*v_2*h^8 - 275*v_2^2*h^8 + 1135*u_1*v_3*h^8 - 3366*u_2*v_3*h^8 + 4868*v_1*v_3*h^8 + 3656*v_2*v_3*h^8 - 548*u_2*y*h^8 + 4452*u_3*y*h^8 + 2630*v_1*y*h^8 - 3542*v_2*y*h^8 - 262*v_3*y*h^8 + 4841*u_1*h^9 - 972*u_2*h^9 + 269*u_3*h^9 + 544*v_1*h^9 - 671*v_2*h^9 - 37*v_3*h^9 - 3391*y*h^9 - 1650*h^10,
#  u_2*v_2^2*h^7 - 4548*v_1*v_2^2*h^7 + 1045*u_2*v_1*v_3*h^7 + 1584*v_1^2*v_3*h^7 - 3135*u_1*v_2*v_3*h^7 + 2090*v_1*v_2*v_3*h^7 - 3753*u_2^2*y*h^7 + 4808*u_2*u_3*y*h^7 + 2639*u_3*v_1*y*h^7 + 891*u_2*v_2*y*h^7 - 4808*u_3*v_2*y*h^7 - 1680*v_1*v_2*y*h^7 + 2292*v_2^2*y*h^7 - 2491*u_2*v_3*y*h^7 - 120*v_1*v_3*y*h^7 + 4143*v_2*v_3*y*h^7 + 1172*u_2^2*h^8 - 4016*u_1*u_3*h^8 - 3539*u_2*u_3*h^8 + 805*u_2*v_1*h^8 + 1185*u_3*v_1*h^8 - 4843*v_1^2*h^8 + 1172*u_1*v_2*h^8 + 4215*u_2*v_2*h^8 + 322*u_3*v_2*h^8 - 3571*v_1*v_2*h^8 + 1387*v_2^2*h^8 + 1229*u_1*v_3*h^8 + 3052*u_2*v_3*h^8 - 433*v_1*v_3*h^8 - 3749*v_2*v_3*h^8 + 817*u_2*y*h^8 - 409*u_3*y*h^8 + 1008*v_1*y*h^8 - 3235*v_2*y*h^8 - 546*v_3*y*h^8 - 1937*u_1*h^9 + 2089*u_2*h^9 + 4975*u_3*h^9 + 427*v_1*h^9 + 2134*v_2*h^9 - 1645*v_3*h^9 - 4466*y*h^9 + 688*h^10,
#  v_1^2*v_2^2*h^5 + 726*u_2^2*v_2*h^6 - 2933*u_1*v_2^2*h^6 + 2649*u_2*v_2^2*h^6 + 3282*v_1*v_2^2*h^6 - 399*u_2^2*y*h^6 + 3883*u_3*v_1*y*h^6 + 2775*u_2*v_2*y*h^6 - 707*v_1*v_2*y*h^6 - 276*v_2^2*y*h^6 - 3883*v_1*v_3*y*h^6 - 2933*u_2^2*h^7 + 963*u_1*u_3*h^7 + 586*u_2*v_1*h^7 - 4875*u_3*v_1*h^7 + 3592*v_1^2*h^7 + 4994*u_1*v_2*h^7 + 4099*u_2*v_2*h^7 + 2189*v_1*v_2*h^7 - 2690*v_2^2*h^7 - 3880*u_1*v_3*h^7 + 1361*v_1*v_3*h^7 + 241*u_2*y*h^7 + 43*u_3*y*h^7 + 340*v_1*y*h^7 + 2811*v_2*y*h^7 - 300*v_3*y*h^7 + 4714*u_1*h^8 - 2685*u_2*h^8 + 4101*u_3*h^8 - 1814*v_1*h^8 + 313*v_2*h^8 + 2870*v_3*h^8 - 4033*y*h^8 - 1720*h^9,
#  u_2^2*v_2*y*h^5 + 3387*u_2^2*v_2*h^6 - 1387*u_1*v_2^2*h^6 + 575*u_2*v_2^2*h^6 - 1607*v_1*v_2^2*h^6 + 2509*u_2^2*y*h^6 + 4900*u_3*v_1*y*h^6 + 4433*u_2*v_2*y*h^6 - 4180*v_1*v_2*y*h^6 - 339*v_2^2*y*h^6 - 4900*v_1*v_3*y*h^6 + 3107*u_2^2*h^7 - 1530*u_1*u_3*h^7 + 4627*u_2*v_1*h^7 + 3434*u_3*v_1*h^7 + 1708*v_1^2*h^7 - 258*u_1*v_2*h^7 - 4939*u_2*v_2*h^7 - 1234*v_1*v_2*h^7 + 1683*v_2^2*h^7 + 1650*u_1*v_3*h^7 + 755*v_1*v_3*h^7 + 214*u_2*y*h^7 + 4998*u_3*y*h^7 + 630*v_1*y*h^7 - 4056*v_2*y*h^7 - 1154*v_3*y*h^7 - 412*u_1*h^8 + 1693*u_2*h^8 + 3369*u_3*h^8 - 1001*v_1*h^8 - 4516*v_2*h^8 - 909*v_3*h^8 + 2475*y*h^8 - 2829*h^9,
#  u_2*v_2^2*y*h^5 - 2981*u_2^2*v_2*h^6 - 3149*u_1*v_2^2*h^6 - 2374*u_2*v_2^2*h^6 + 2215*v_1*v_2^2*h^6 - 4844*u_2^2*y*h^6 - 163*u_3*v_1*y*h^6 + 1823*u_2*v_2*y*h^6 + 4919*v_1*v_2*y*h^6 + 584*v_2^2*y*h^6 + 163*v_1*v_3*y*h^6 - 1133*u_2^2*h^7 - 1284*u_1*u_3*h^7 + 892*u_2*v_1*h^7 - 2099*u_3*v_1*h^7 + 4523*v_1^2*h^7 - 2960*u_1*v_2*h^7 - 2515*u_2*v_2*h^7 + 3840*v_1*v_2*h^7 - 892*v_2^2*h^7 - 1715*u_1*v_3*h^7 - 2232*v_1*v_3*h^7 - 1781*u_2*y*h^7 + 1200*u_3*y*h^7 - 4995*v_1*y*h^7 + 2529*v_2*y*h^7 + 2685*v_3*y*h^7 + 725*u_1*h^8 - 667*u_2*h^8 + 608*u_3*h^8 + 3886*v_1*h^8 + 657*v_2*h^8 + 4760*v_3*h^8 + 2855*y*h^8 - 3354*h^9,
#  v_1*v_2^2*y*h^5 + 3379*u_2^2*v_2*h^6 - 4370*u_1*v_2^2*h^6 + 4230*u_2*v_2^2*h^6 + 2890*v_1*v_2^2*h^6 - 1853*u_2^2*y*h^6 - 708*u_3*v_1*y*h^6 + 4167*u_2*v_2*y*h^6 - 1571*v_1*v_2*y*h^6 - 2079*v_2^2*y*h^6 + 708*v_1*v_3*y*h^6 - 3445*u_2^2*h^7 - 3548*u_1*u_3*h^7 - 2702*u_2*v_1*h^7 + 4798*u_3*v_1*h^7 + 3413*v_1^2*h^7 + 3951*u_1*v_2*h^7 + 2213*u_2*v_2*h^7 - 4766*v_1*v_2*h^7 - 1101*v_2^2*h^7 - 4959*u_1*v_3*h^7 + 2874*v_1*v_3*h^7 + 1627*u_2*y*h^7 - 990*u_3*y*h^7 + 1422*v_1*y*h^7 + 453*v_2*y*h^7 + 2644*v_3*y*h^7 + 1149*u_1*h^8 - 3017*u_2*h^8 + 3701*u_3*h^8 + 2303*v_1*h^8 + 3565*v_2*h^8 + 3673*v_3*h^8 + 1557*y*h^8 + 2576*h^9,
#  v_1^2*v_2*h^6 + 4410*u_2^2*y*h^6 - 2396*u_2*v_2*y*h^6 + 123*v_1*v_2*y*h^6 - 2014*v_2^2*y*h^6 + 3157*u_2^2*h^7 - 1211*u_2*v_1*h^7 - 2955*v_1^2*h^7 - 3781*u_1*v_2*h^7 + 139*u_2*v_2*h^7 - 4153*v_1*v_2*h^7 + 1114*v_2^2*h^7 - 3495*u_2*y*h^7 + 4613*v_1*y*h^7 + 3473*v_2*y*h^7 - 912*u_1*h^8 + 1199*u_2*h^8 + 1795*v_1*h^8 + 4576*v_2*h^8 - 2031*y*h^8 + 921*h^9,
#  u_2^2*v_1*h^5 - 813*v_1^2*v_2*h^5 - 6*u_1*v_2^2*h^5 + 5*v_1*v_2^2*h^5 - 3133*u_2^2*y*h^5 - 2793*u_2*v_2*y*h^5 - 1144*v_1*v_2*y*h^5 - 2110*v_2^2*y*h^5 + 3220*u_2^2*h^6 + 1857*u_2*v_1*h^6 + 4807*v_1^2*h^6 - 2716*u_1*v_2*h^6 + 2799*u_2*v_2*h^6 - 2233*v_1*v_2*h^6 - 2685*v_2^2*h^6 - 4017*u_2*y*h^6 + 3918*v_1*y*h^6 - 4591*v_2*y*h^6 - 917*u_1*h^7 + 2431*u_2*h^7 + 907*v_1*h^7 - 4383*v_2*h^7 + 998*y*h^7 + 4882*h^8,
#  u_2*v_1^2*h^5 + 3508*v_1^2*v_2*h^5 - 1113*u_2^2*y*h^5 + 2226*u_2*v_2*y*h^5 + 4475*v_1*v_2*y*h^5 - 1113*v_2^2*y*h^5 + 2707*u_2^2*h^6 + 328*u_2*v_1*h^6 + 2468*v_1^2*h^6 - 2397*u_1*v_2*h^6 + 4424*u_2*v_2*h^6 - 3920*v_1*v_2*h^6 + 2876*v_2^2*h^6 + 4257*u_2*y*h^6 - 591*v_1*y*h^6 + 3353*v_2*y*h^6 - 4974*u_1*h^7 + 1350*u_2*h^7 + 4472*v_1*h^7 + 4701*v_2*h^7 + 4893*y*h^7 + 4704*h^8,
#  u_2*v_1*v_2*h^5 + 4912*v_1^2*v_2*h^5 - 3*u_1*v_2^2*h^5 + 2*v_1*v_2^2*h^5 - 1156*u_2^2*y*h^5 + 2161*u_2*v_2*y*h^5 - 1966*v_1*v_2*y*h^5 + 3392*v_2^2*y*h^5 + 393*u_2^2*h^6 + 2682*u_2*v_1*h^6 - 2055*v_1^2*h^6 + 2500*u_1*v_2*h^6 + 2765*u_2*v_2*h^6 + 4070*v_1*v_2*h^6 + 1023*v_2^2*h^6 - 4318*u_2*y*h^6 - 358*v_1*y*h^6 + 2006*v_2*y*h^6 + 1536*u_1*h^7 - 4998*u_2*h^7 + 3338*v_1*h^7 - 1366*v_2*h^7 + 4481*y*h^7 - 1821*h^8,
#  u_2*v_1*y*h^4 - v_1*v_2*y*h^4 + 1231*u_2*v_1*h^5 - 4923*v_1^2*h^5 - 3997*u_1*v_2*h^5 - 84*v_1*v_2*h^5 - 2873*u_2*y*h^5 - 589*v_1*y*h^5 - 649*v_2*y*h^5 - 2623*u_1*h^6 + 2643*u_2*h^6 + 383*v_1*h^6 - 364*v_2*h^6 - 2246*y*h^6 + 2406*h^7,
#  u_1*u_2*h^5 - 1037*u_2*v_1*h^5 - 2892*v_1^2*h^5 + 3107*u_1*v_2*h^5 - 2071*v_1*v_2*h^5 - 4725*u_2*y*h^5 - 2250*v_1*y*h^5 - 2992*v_2*y*h^5 + 1564*u_1*h^6 + 1697*u_2*h^6 - 4643*v_1*h^6 - 1858*v_2*h^6 - 4278*y*h^6 + 4591*h^7,
#  u_1*v_1*h^5 - 2277*u_2*v_1*h^5 + 1035*v_1^2*h^5 - 3176*u_1*v_2*h^5 - 4554*v_1*v_2*h^5 + 3589*u_2*y*h^5 + 3479*v_1*y*h^5 + 1449*v_2*y*h^5 + 456*u_1*h^6 - 3363*u_2*h^6 - 2563*v_1*h^6 - 117*v_2*h^6 - 102*y*h^6 - 1907*h^7,
#  u_1*v_1^2*h^3 + 4666*u_1*v_1*h^4 - 3420*v_1^2*h^4 - 1576*u_2*y*h^4 + 1345*v_1*y*h^4 + 1576*v_2*y*h^4 - 2536*u_1*h^5 - 411*u_2*h^5 + 2898*v_1*h^5 - 1133*v_2*h^5 + 1070*y*h^5 - 4948*h^6,
#  v_1^2*y*h^3 - 2865*u_1*v_1*h^4 - 748*v_1^2*h^4 - 4252*u_2*y*h^4 + 3772*v_1*y*h^4 + 4252*v_2*y*h^4 - 4547*u_1*h^5 + 3904*u_2*h^5 + 4414*v_1*h^5 - 4181*v_2*h^5 - 4667*y*h^5 - 4452*h^6,
#  u_1^2*h^3 - 2*u_1*v_1*h^3 + v_1^2*h^3 - 1870*v_1*y*h^3 - 233*u_1*h^4 + 2414*v_1*h^4 - 2921*y*h^4 - 2746*h^5,
#  u_1*y*h^2 - v_1*y*h^2 - 2487*u_1*h^3 + 1537*v_1*h^3 + 4096*y*h^3 + 4616*h^4,
#  u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + 692*u_1^2*h + 1384*u_1*y*h - 613*u_1*h^2 - u_2*h^2 + 3459*v_1*h^2 + 2953*y*h^2 + 4266*h^3,
#  u_2^3 + 3*u_2^2*y + 3*u_2*y^2 - 1706*u_2^2*h - 3412*u_2*y*h - 1733*u_1*h^2 + 2802*u_2*h^2 - u_3*h^2 + 1734*v_1*h^2 + 106*y*h^2 - 4386*h^3,
#  u_3^3 + 3*u_3^2*y + 3*u_3*y^2 - 3094*u_3^2*h + 3819*u_3*y*h - 1903*u_1*h^2 + 2048*u_3*h^2 + 1904*v_1*h^2 - 2053*y*h^2 - 70*h^3,
#  v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + 692*v_1^2*h + 1384*v_1*y*h - 3458*u_1*h^2 - 3703*v_1*h^2 - v_2*h^2 + 2953*y*h^2 + 4266*h^3,
#  v_2^3 + 3*v_2^2*y + 3*v_2*y^2 - 1706*v_2^2*h - 3412*v_2*y*h - 1733*u_1*h^2 + 1734*v_1*h^2 + 2802*v_2*h^2 - v_3*h^2 + 106*y*h^2 - 4386*h^3,
#  v_3^3 + 3*v_3^2*y + 3*v_3*y^2 - 3094*v_3^2*h + 3819*v_3*y*h - 1903*u_1*h^2 + 1904*v_1*h^2 + 2048*v_3*h^2 - 2053*y*h^2 - 3728*h^3,
#  y^3 - 2398*u_1*h^2 + 2397*v_1*h^2 + 2554*y*h^2 + 3300*h^3,
#  y^2*h + 2033*u_1*h^2 - 2033*v_1*h^2 - 4024*y*h^2 - 4859*h^3]

# %%
res = ideal(polys_h).graded_free_resolution(algorithm="minimal")
res
# Out:
# S(0) <-- S(-3)⊕S(-3)⊕S(-3)⊕S(-3)⊕S(-3)⊕S(-3)⊕S(-3)⊕S(-3) <-- S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-17) <-- S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18) <-- S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19) <-- S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20) <-- S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21) <-- S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22) <-- S(-23)⊕S(-23)⊕S(-23)⊕S(-23)⊕S(-23)⊕S(-23)⊕S(-23) <-- 0

# %%
cm_regularity(res)
# Out:
# 16
