# %% [markdown]
# # MiMC Solving Degree For Attack With Two Plain Texts
# Empirical solving degree for increasing round numbers of MiMC with two plain/ciphertext samples.
#
# Prime: $p = 10007$.
#
# Round numbers: $r \in \{ 2, 3, 4 \}$.

# %%
from lazard_gb_algorithm import *
load("MiMC.sage")
load("utilities.sage")

# %% [markdown]
# ## p = 10007, r = 2

# %%
p = 10007
field = GF(p, "a")

rounds = 2

mimc = MiMC(field=field, rounds=rounds)

print("")

key = field.random_element()
print("Key:", key)

plain_1 = field.random_element()
cipher_1 = mimc.encryption(plain_1, key)

print("Plain 1:", plain_1)
print("Cipher 1:", cipher_1)

plain_2 = field.random_element()
cipher_2 = mimc.encryption(plain_2, key)

print("Plain 2:", plain_2)
print("Cipher 2:", cipher_2)

print("")

polys = mimc.generate_two_plain_text_polynomials(plain_1, 
                                                 cipher_1, 
                                                 plain_2, 
                                                 cipher_2,
                                                 info_level=0)
polys_h = [poly.homogenize() for poly in polys]

for i in range(0, 2 * rounds):
    print(polys[i])
    if i == rounds - 1:
        print("\n")
# Out:
# MiMC Parameters
# Field: Finite Field of size 10007
# r: 2
# Constants: [7681, 4771]
#
# Key: 9396
# Plain 1: 6138
# Cipher 1: 6053
# Plain 2: 5946
# Cipher 2: 7183
#
# y^3 + 1429*y^2 - u_1 + 3540*y - 4990
# u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + y^3 + 4306*u_1^2 - 1395*u_1*y + 4306*y^2 - 445*u_1 - 444*y + 3417
#
#
# y^3 + 853*y^2 - v_1 - 4303*y + 4682
# v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + y^3 + 4306*v_1^2 - 1395*v_1*y + 4306*y^2 - 445*v_1 - 444*y + 2287

# %%
lazard_gb_algorithm(polys)
# Out:
# Ring: Multivariate Polynomial Ring in u_1, v_1, y over Finite Field of size 10007
# Input polynomials:
# [y^3 + 1429*y^2 - u_1 + 3540*y - 4990, u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + y^3 + 4306*u_1^2 - 1395*u_1*y + 4306*y^2 - 445*u_1 - 444*y + 3417, y^3 + 853*y^2 - v_1 - 4303*y + 4682, v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + y^3 + 4306*v_1^2 - 1395*v_1*y + 4306*y^2 - 445*v_1 - 444*y + 2287]
#
# --- Degree 0 ---
# Computing all monomials up to degree: 0
# Time needed: 0.08426189422607422
# Computing Macaulay matrix.
# Time needed: 1.9073486328125e-06
# Performing Gaussian Elimination.
# Time needed: 0.00019788742065429688
# Is Groebner Basis: False
#
# --- Degree 1 ---
# Computing all monomials up to degree: 1
# Time needed: 0.015092849731445312
# Computing Macaulay matrix.
# Time needed: 2.1457672119140625e-06
# Performing Gaussian Elimination.
# Time needed: 0.00018286705017089844
# Is Groebner Basis: False
#
# --- Degree 2 ---
# Computing all monomials up to degree: 2
# Time needed: 0.0011327266693115234
# Computing Macaulay matrix.
# Time needed: 9.5367431640625e-07
# Performing Gaussian Elimination.
# Time needed: 0.00013208389282226562
# Is Groebner Basis: False
#
# --- Degree 3 ---
# Computing all monomials up to degree: 3
# Time needed: 0.0011622905731201172
# Computing Macaulay matrix.
# Time needed: 1.1920928955078125e-06
# Performing Gaussian Elimination.
# Time needed: 0.0001697540283203125
# Is Groebner Basis: False
#
# --- Degree 4 ---
# Computing all monomials up to degree: 4
# Time needed: 0.0030472278594970703
# Computing Macaulay matrix.
# Time needed: 1.6689300537109375e-06
# Performing Gaussian Elimination.
# Time needed: 0.00030303001403808594
# Is Groebner Basis: False
#
# --- Degree 5 ---
# Computing all monomials up to degree: 5
# Time needed: 0.0029375553131103516
# Computing Macaulay matrix.
# Time needed: 1.9073486328125e-06
# Performing Gaussian Elimination.
# Time needed: 0.0005433559417724609
# Is Groebner Basis: False
#
# --- Degree 6 ---
# Computing all monomials up to degree: 6
# Time needed: 0.002838134765625
# Computing Macaulay matrix.
# Time needed: 1.1920928955078125e-06
# Performing Gaussian Elimination.
# Time needed: 0.0015316009521484375
# Is Groebner Basis: False
#
# --- Degree 7 ---
# Computing all monomials up to degree: 7
# Time needed: 0.003256082534790039
# Computing Macaulay matrix.
# Time needed: 3.814697265625e-06
# Performing Gaussian Elimination.
# Time needed: 0.003117799758911133
# Is Groebner Basis: False
#
# --- Degree 8 ---
# Computing all monomials up to degree: 8
# Time needed: 0.003590106964111328
# Computing Macaulay matrix.
# Time needed: 1.9073486328125e-06
# Performing Gaussian Elimination.
# Time needed: 0.004151105880737305
# Is Groebner Basis: True
# Total time needed: 0.20563840866088867
# [u_1 + 3452, v_1 - 2460, y + 611]

# %%
lazard_gb_algorithm(polys_h)
# Out:
# Ring: Multivariate Polynomial Ring in u_1, v_1, y, h over Finite Field of size 10007
# Input polynomials:
# [y^3 + 1429*y^2*h - u_1*h^2 + 3540*y*h^2 - 4990*h^3, u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + y^3 + 4306*u_1^2*h - 1395*u_1*y*h + 4306*y^2*h - 445*u_1*h^2 - 444*y*h^2 + 3417*h^3, y^3 + 853*y^2*h - v_1*h^2 - 4303*y*h^2 + 4682*h^3, v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + y^3 + 4306*v_1^2*h - 1395*v_1*y*h + 4306*y^2*h - 445*v_1*h^2 - 444*y*h^2 + 2287*h^3]
#
# --- Degree 0 ---
# Computing all monomials up to degree: 0
# Time needed: 0.0004930496215820312
# Computing Macaulay matrix.
# Time needed: 1.1920928955078125e-06
# Performing Gaussian Elimination.
# Time needed: 7.653236389160156e-05
# Is Groebner Basis: False
#
# --- Degree 1 ---
# Computing all monomials up to degree: 1
# Time needed: 0.0009691715240478516
# Computing Macaulay matrix.
# Time needed: 1.1920928955078125e-06
# Performing Gaussian Elimination.
# Time needed: 0.00013184547424316406
# Is Groebner Basis: False
#
# --- Degree 2 ---
# Computing all monomials up to degree: 2
# Time needed: 0.003118276596069336
# Computing Macaulay matrix.
# Time needed: 7.3909759521484375e-06
# Performing Gaussian Elimination.
# Time needed: 0.0002739429473876953
# Is Groebner Basis: False
#
# --- Degree 3 ---
# Computing all monomials up to degree: 3
# Time needed: 0.0017244815826416016
# Computing Macaulay matrix.
# Time needed: 1.6689300537109375e-06
# Performing Gaussian Elimination.
# Time needed: 0.00035119056701660156
# Is Groebner Basis: False
#
# --- Degree 4 ---
# Computing all monomials up to degree: 4
# Time needed: 0.0021507740020751953
# Computing Macaulay matrix.
# Time needed: 3.0994415283203125e-06
# Performing Gaussian Elimination.
# Time needed: 0.00034117698669433594
# Is Groebner Basis: False
#
# --- Degree 5 ---
# Computing all monomials up to degree: 5
# Time needed: 0.0036211013793945312
# Computing Macaulay matrix.
# Time needed: 1.1920928955078125e-06
# Performing Gaussian Elimination.
# Time needed: 0.0007174015045166016
# Is Groebner Basis: False
#
# --- Degree 6 ---
# Computing all monomials up to degree: 6
# Time needed: 0.004716396331787109
# Computing Macaulay matrix.
# Time needed: 1.6689300537109375e-06
# Performing Gaussian Elimination.
# Time needed: 0.0023746490478515625
# Is Groebner Basis: False
#
# --- Degree 7 ---
# Computing all monomials up to degree: 7
# Time needed: 0.00611114501953125
# Computing Macaulay matrix.
# Time needed: 2.86102294921875e-06
# Performing Gaussian Elimination.
# Time needed: 0.00424647331237793
# Is Groebner Basis: False
#
# --- Degree 8 ---
# Computing all monomials up to degree: 8
# Time needed: 0.008132457733154297
# Computing Macaulay matrix.
# Time needed: 2.6226043701171875e-06
# Performing Gaussian Elimination.
# Time needed: 0.010432720184326172
# Is Groebner Basis: True
# Total time needed: 0.1771697998046875
# [u_1*h^7 + 3452*h^8,
#  v_1*h^7 - 2460*h^8,
#  y*h^7 + 611*h^8,
#  u_1*v_1*h^5 + 2701*u_1*h^6 - 386*v_1*h^6 - 1944*y*h^6 - 4751*h^7,
#  v_1^2*h^5 - 902*u_1*h^6 + 462*v_1*h^6 + 2097*y*h^6 - 4250*h^7,
#  v_1*y*h^5 - 3866*u_1*h^6 + 1188*v_1*h^6 - 3278*y*h^6 + 4022*h^7,
#  u_1*v_1^2*h^3 - 1818*u_1*v_1*h^4 + 2123*v_1^2*h^4 + 2123*v_1*y*h^4 + 372*u_1*h^5 - 4590*v_1*h^5 - 990*y*h^5 - 4245*h^6,
#  v_1^2*y*h^3 - 842*u_1*v_1*h^4 + 1885*v_1^2*h^4 + 2590*v_1*y*h^4 + 4695*u_1*h^5 + 3444*v_1*h^5 + 1732*y*h^5 - 1103*h^6,
#  u_1^2*h^3 - 2*u_1*v_1*h^3 + v_1^2*h^3 - 1545*v_1*y*h^3 - 4688*u_1*h^4 + 2834*v_1*h^4 - 2423*y*h^4 + 1592*h^5,
#  u_1*y*h^2 - v_1*y*h^2 + 3428*u_1*h^3 - 4004*v_1*h^3 - 4129*y*h^3 - 2633*h^4,
#  u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + 4306*u_1^2*h - 1395*u_1*y*h - 1742*u_1*h^2 + 1298*v_1*h^2 - 889*y*h^2 + 2929*h^3,
#  v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + 4306*v_1^2*h - 1395*v_1*y*h - 1297*u_1*h^2 + 853*v_1*h^2 - 889*y*h^2 + 1799*h^3,
#  y^3 + 3563*u_1*h^2 - 3564*v_1*h^2 + 639*y*h^2 + 1910*h^3,
#  y^2*h - 3770*u_1*h^2 + 3770*v_1*h^2 - 2575*y*h^2 + 2068*h^3]

# %%
res = ideal(polys_h).graded_free_resolution(algorithm="minimal")
res
# Out:
# S(0) <-- S(-3)⊕S(-3)⊕S(-3)⊕S(-3) <-- S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-9) <-- S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-10)⊕S(-10)⊕S(-10) <-- S(-11)⊕S(-11)⊕S(-11) <-- 0

# %%
cm_regularity(res)
# Out:
# 8

# %% [markdown]
# ## p = 10007, r = 3

# %%
p = 10007
field = GF(p, "a")

rounds = 3

mimc = MiMC(field=field, rounds=rounds)

print("")

key = field.random_element()
print("Key:", key)

plain_1 = field.random_element()
cipher_1 = mimc.encryption(plain_1, key)

print("Plain 1:", plain_1)
print("Cipher 1:", cipher_1)

plain_2 = field.random_element()
cipher_2 = mimc.encryption(plain_2, key)

print("Plain 2:", plain_2)
print("Cipher 2:", cipher_2)

print("")

polys = mimc.generate_two_plain_text_polynomials(plain_1, 
                                                 cipher_1, 
                                                 plain_2, 
                                                 cipher_2,
                                                 info_level=0)
polys_h = [poly.homogenize() for poly in polys]

for i in range(0, 2 * rounds):
    print(polys[i])
    if i == rounds - 1:
        print("\n")
# Out:
# MiMC Parameters
# Field: Finite Field of size 10007
# r: 3
# Constants: [2075, 360, 5300]
#
# Key: 3905
# Plain 1: 2883
# Cipher 1: 9541
# Plain 2: 3575
# Cipher 2: 6053
#
# y^3 + 4867*y^2 - u_1 + 3709*y + 2121
# u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + y^3 + 1080*u_1^2 + 2160*u_1*y + 1080*y^2 - 1473*u_1 - u_2 - 1473*y + 3366
# u_2^3 + 3*u_2^2*y + 3*u_2*y^2 + y^3 - 4114*u_2^2 + 1779*u_2*y - 4114*y^2 + 1053*u_2 + 1054*y - 536
#
#
# y^3 - 3064*y^2 - v_1 + 510*y - 172
# v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + y^3 + 1080*v_1^2 + 2160*v_1*y + 1080*y^2 - 1473*v_1 - v_2 - 1473*y + 3366
# v_2^3 + 3*v_2^2*y + 3*v_2*y^2 + y^3 - 4114*v_2^2 + 1779*v_2*y - 4114*y^2 + 1053*v_2 + 1054*y + 2952

# %%
lazard_gb_algorithm(polys)
# Out:
# Ring: Multivariate Polynomial Ring in u_1, u_2, v_1, v_2, y over Finite Field of size 10007
# Input polynomials:
# [y^3 + 4867*y^2 - u_1 + 3709*y + 2121, u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + y^3 + 1080*u_1^2 + 2160*u_1*y + 1080*y^2 - 1473*u_1 - u_2 - 1473*y + 3366, u_2^3 + 3*u_2^2*y + 3*u_2*y^2 + y^3 - 4114*u_2^2 + 1779*u_2*y - 4114*y^2 + 1053*u_2 + 1054*y - 536, y^3 - 3064*y^2 - v_1 + 510*y - 172, v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + y^3 + 1080*v_1^2 + 2160*v_1*y + 1080*y^2 - 1473*v_1 - v_2 - 1473*y + 3366, v_2^3 + 3*v_2^2*y + 3*v_2*y^2 + y^3 - 4114*v_2^2 + 1779*v_2*y - 4114*y^2 + 1053*v_2 + 1054*y + 2952]
#
# --- Degree 0 ---
# Computing all monomials up to degree: 0
# Time needed: 0.00063323974609375
# Computing Macaulay matrix.
# Time needed: 9.5367431640625e-07
# Performing Gaussian Elimination.
# Time needed: 7.033348083496094e-05
# Is Groebner Basis: False
#
# --- Degree 1 ---
# Computing all monomials up to degree: 1
# Time needed: 0.0011088848114013672
# Computing Macaulay matrix.
# Time needed: 1.430511474609375e-06
# Performing Gaussian Elimination.
# Time needed: 0.00012826919555664062
# Is Groebner Basis: False
#
# --- Degree 2 ---
# Computing all monomials up to degree: 2
# Time needed: 0.0011224746704101562
# Computing Macaulay matrix.
# Time needed: 1.6689300537109375e-06
# Performing Gaussian Elimination.
# Time needed: 0.00015592575073242188
# Is Groebner Basis: False
#
# --- Degree 3 ---
# Computing all monomials up to degree: 3
# Time needed: 0.002111196517944336
# Computing Macaulay matrix.
# Time needed: 1.9073486328125e-06
# Performing Gaussian Elimination.
# Time needed: 0.00019884109497070312
# Is Groebner Basis: False
#
# --- Degree 4 ---
# Computing all monomials up to degree: 4
# Time needed: 0.00388336181640625
# Computing Macaulay matrix.
# Time needed: 2.1457672119140625e-06
# Performing Gaussian Elimination.
# Time needed: 0.0005474090576171875
# Is Groebner Basis: False
#
# --- Degree 5 ---
# Computing all monomials up to degree: 5
# Time needed: 0.004769325256347656
# Computing Macaulay matrix.
# Time needed: 1.6689300537109375e-06
# Performing Gaussian Elimination.
# Time needed: 0.001687765121459961
# Is Groebner Basis: False
#
# --- Degree 6 ---
# Computing all monomials up to degree: 6
# Time needed: 0.00917506217956543
# Computing Macaulay matrix.
# Time needed: 2.6226043701171875e-06
# Performing Gaussian Elimination.
# Time needed: 0.005802154541015625
# Is Groebner Basis: False
#
# --- Degree 7 ---
# Computing all monomials up to degree: 7
# Time needed: 0.012540578842163086
# Computing Macaulay matrix.
# Time needed: 1.9073486328125e-06
# Performing Gaussian Elimination.
# Time needed: 0.02078533172607422
# Is Groebner Basis: False
#
# --- Degree 8 ---
# Computing all monomials up to degree: 8
# Time needed: 0.02100205421447754
# Computing Macaulay matrix.
# Time needed: 3.5762786865234375e-06
# Performing Gaussian Elimination.
# Time needed: 0.07264041900634766
# Is Groebner Basis: False
#
# --- Degree 9 ---
# Computing all monomials up to degree: 9
# Time needed: 0.029528379440307617
# Computing Macaulay matrix.
# Time needed: 3.0994415283203125e-06
# Performing Gaussian Elimination.
# Time needed: 0.20032858848571777
# Is Groebner Basis: False
#
# --- Degree 10 ---
# Computing all monomials up to degree: 10
# Time needed: 0.053778648376464844
# Computing Macaulay matrix.
# Time needed: 4.5299530029296875e-06
# Performing Gaussian Elimination.
# Time needed: 0.5182294845581055
# Is Groebner Basis: False
#
# --- Degree 11 ---
# Computing all monomials up to degree: 11
# Time needed: 0.06771636009216309
# Computing Macaulay matrix.
# Time needed: 5.4836273193359375e-06
# Performing Gaussian Elimination.
# Time needed: 1.604478359222412
# Is Groebner Basis: False
#
# --- Degree 12 ---
# Computing all monomials up to degree: 12
# Time needed: 0.08816385269165039
# Computing Macaulay matrix.
# Time needed: 6.198883056640625e-06
# Performing Gaussian Elimination.
# Time needed: 3.2672135829925537
# Is Groebner Basis: True
# Total time needed: 8.591354131698608
# [u_1 - 3321, u_2 - 1637, v_1 + 812, v_2 - 1249, y - 3905]

# %%
lazard_gb_algorithm(polys_h)
# Out:
# Ring: Multivariate Polynomial Ring in u_1, u_2, v_1, v_2, y, h over Finite Field of size 10007
# Input polynomials:
# [y^3 + 4867*y^2*h - u_1*h^2 + 3709*y*h^2 + 2121*h^3, u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + y^3 + 1080*u_1^2*h + 2160*u_1*y*h + 1080*y^2*h - 1473*u_1*h^2 - u_2*h^2 - 1473*y*h^2 + 3366*h^3, u_2^3 + 3*u_2^2*y + 3*u_2*y^2 + y^3 - 4114*u_2^2*h + 1779*u_2*y*h - 4114*y^2*h + 1053*u_2*h^2 + 1054*y*h^2 - 536*h^3, y^3 - 3064*y^2*h - v_1*h^2 + 510*y*h^2 - 172*h^3, v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + y^3 + 1080*v_1^2*h + 2160*v_1*y*h + 1080*y^2*h - 1473*v_1*h^2 - v_2*h^2 - 1473*y*h^2 + 3366*h^3, v_2^3 + 3*v_2^2*y + 3*v_2*y^2 + y^3 - 4114*v_2^2*h + 1779*v_2*y*h - 4114*y^2*h + 1053*v_2*h^2 + 1054*y*h^2 + 2952*h^3]
#
# --- Degree 0 ---
# Computing all monomials up to degree: 0
# Time needed: 0.0008585453033447266
# Computing Macaulay matrix.
# Time needed: 2.6226043701171875e-06
# Performing Gaussian Elimination.
# Time needed: 0.0002193450927734375
# Is Groebner Basis: False
#
# --- Degree 1 ---
# Computing all monomials up to degree: 1
# Time needed: 0.0011184215545654297
# Computing Macaulay matrix.
# Time needed: 2.1457672119140625e-06
# Performing Gaussian Elimination.
# Time needed: 0.000156402587890625
# Is Groebner Basis: False
#
# --- Degree 2 ---
# Computing all monomials up to degree: 2
# Time needed: 0.0013477802276611328
# Computing Macaulay matrix.
# Time needed: 1.1920928955078125e-06
# Performing Gaussian Elimination.
# Time needed: 0.00015425682067871094
# Is Groebner Basis: False
#
# --- Degree 3 ---
# Computing all monomials up to degree: 3
# Time needed: 0.0026628971099853516
# Computing Macaulay matrix.
# Time needed: 1.430511474609375e-06
# Performing Gaussian Elimination.
# Time needed: 0.0002315044403076172
# Is Groebner Basis: False
#
# --- Degree 4 ---
# Computing all monomials up to degree: 4
# Time needed: 0.007494926452636719
# Computing Macaulay matrix.
# Time needed: 3.337860107421875e-06
# Performing Gaussian Elimination.
# Time needed: 0.0007493495941162109
# Is Groebner Basis: False
#
# --- Degree 5 ---
# Computing all monomials up to degree: 5
# Time needed: 0.009116888046264648
# Computing Macaulay matrix.
# Time needed: 2.6226043701171875e-06
# Performing Gaussian Elimination.
# Time needed: 0.003359079360961914
# Is Groebner Basis: False
#
# --- Degree 6 ---
# Computing all monomials up to degree: 6
# Time needed: 0.015629053115844727
# Computing Macaulay matrix.
# Time needed: 2.384185791015625e-06
# Performing Gaussian Elimination.
# Time needed: 0.010266542434692383
# Is Groebner Basis: False
#
# --- Degree 7 ---
# Computing all monomials up to degree: 7
# Time needed: 0.02592635154724121
# Computing Macaulay matrix.
# Time needed: 2.1457672119140625e-06
# Performing Gaussian Elimination.
# Time needed: 0.04370403289794922
# Is Groebner Basis: False
#
# --- Degree 8 ---
# Computing all monomials up to degree: 8
# Time needed: 0.0437924861907959
# Computing Macaulay matrix.
# Time needed: 3.0994415283203125e-06
# Performing Gaussian Elimination.
# Time needed: 0.15221238136291504
# Is Groebner Basis: False
#
# --- Degree 9 ---
# Computing all monomials up to degree: 9
# Time needed: 0.07288384437561035
# Computing Macaulay matrix.
# Time needed: 3.814697265625e-06
# Performing Gaussian Elimination.
# Time needed: 0.519564151763916
# Is Groebner Basis: False
#
# --- Degree 10 ---
# Computing all monomials up to degree: 10
# Time needed: 0.11487126350402832
# Computing Macaulay matrix.
# Time needed: 1.4781951904296875e-05
# Performing Gaussian Elimination.
# Time needed: 1.6860389709472656
# Is Groebner Basis: False
#
# --- Degree 11 ---
# Computing all monomials up to degree: 11
# Time needed: 0.17212152481079102
# Computing Macaulay matrix.
# Time needed: 5.9604644775390625e-06
# Performing Gaussian Elimination.
# Time needed: 4.504681825637817
# Is Groebner Basis: False
#
# --- Degree 12 ---
# Computing all monomials up to degree: 12
# Time needed: 0.2900254726409912
# Computing Macaulay matrix.
# Time needed: 5.245208740234375e-06
# Performing Gaussian Elimination.
# Time needed: 20.834694385528564
# Is Groebner Basis: True
# Total time needed: 39.47740578651428
# [u_1*h^11 - 3321*h^12,
#  u_2*h^11 - 1637*h^12,
#  v_1*h^11 + 812*h^12,
#  v_2*h^11 - 1249*h^12,
#  y*h^11 - 3905*h^12,
#  u_2^2*h^9 - 4740*u_1*h^10 + 2179*u_2*h^10 + 4051*v_1*h^10 + 2092*v_2*h^10 + 4948*y*h^10 - 4290*h^11,
#  u_2*v_1*h^9 - 474*u_1*h^10 - 1832*u_2*h^10 - 4886*v_1*h^10 - 1783*v_2*h^10 + 839*y*h^10 - 5001*h^11,
#  v_1^2*h^9 - 2916*u_1*h^10 + 1816*u_2*h^10 - 1312*v_1*h^10 - 4630*v_2*h^10 + 2914*y*h^10 + 683*h^11,
#  u_1*v_2*h^9 + 1546*u_1*h^10 - 4102*u_2*h^10 - 4823*v_1*h^10 + 4379*v_2*h^10 - 8*y*h^10 - 3291*h^11,
#  u_2*v_2*h^9 - 973*u_1*h^10 + 560*u_2*h^10 - 4923*v_1*h^10 + 2544*v_2*h^10 + 3506*y*h^10 - 1456*h^11,
#  v_1*v_2*h^9 + 877*u_1*h^10 - 1299*u_2*h^10 - 3976*v_1*h^10 - 2199*v_2*h^10 - 1106*y*h^10 + 2261*h^11,
#  v_2^2*h^9 + 932*u_1*h^10 + 3155*u_2*h^10 + 2774*v_1*h^10 + 3280*v_2*h^10 - 4738*y*h^10 + 2969*h^11,
#  u_2*y*h^9 + 563*u_1*h^10 - 3379*u_2*h^10 - 2594*v_1*h^10 + 2777*v_2*h^10 + 2900*y*h^10 + 3648*h^11,
#  v_1*y*h^9 + 3724*u_1*h^10 + 3941*u_2*h^10 + 1454*v_1*h^10 + 1119*v_2*h^10 + 3903*y*h^10 - 4403*h^11,
#  v_2*y*h^9 + 51*u_1*h^10 - 1872*u_2*h^10 - 601*v_1*h^10 - 2651*v_2*h^10 + 3371*y*h^10 - 4303*h^11,
#  u_2^2*v_2^2*h^6 - 1681*u_2^2*h^8 - 3852*u_2*v_1*h^8 + 3155*v_1^2*h^8 + 2364*u_1*v_2*h^8 - 2590*u_2*v_2*h^8 + 2995*v_1*v_2*h^8 - 2649*v_2^2*h^8 + 1827*u_2*y*h^8 + 773*v_1*y*h^8 + 3335*v_2*y*h^8 + 4073*u_1*h^9 - 1186*u_2*h^9 + 497*v_1*h^9 - 4482*v_2*h^9 - 2341*y*h^9 - 1106*h^10,
#  u_2^2*v_2*h^7 + 2530*u_2^2*h^8 + 170*u_2*v_1*h^8 + 1997*v_1^2*h^8 + 3423*u_1*v_2*h^8 + 3696*u_2*v_2*h^8 + 3352*v_1*v_2*h^8 + 1864*v_2^2*h^8 - 3763*u_2*y*h^8 + 754*v_1*y*h^8 - 3992*v_2*y*h^8 + 2228*u_1*h^9 + 1811*u_2*h^9 - 1091*v_1*h^9 + 1587*v_2*h^9 + 314*y*h^9 - 4932*h^10,
#  u_1*v_2^2*h^7 + 3747*u_2^2*h^8 + 1297*u_2*v_1*h^8 + 4730*v_1^2*h^8 + 2700*u_1*v_2*h^8 - 2084*u_2*v_2*h^8 + 588*v_1*v_2*h^8 - 4498*v_2^2*h^8 - 2359*u_2*y*h^8 + 4314*v_1*y*h^8 - 2566*v_2*y*h^8 - 4801*u_1*h^9 + 4858*u_2*h^9 - 4889*v_1*h^9 + 3059*v_2*h^9 - 4989*y*h^9 - 4811*h^10,
#  u_2*v_2^2*h^7 + 4571*u_2^2*h^8 + 269*u_2*v_1*h^8 + 3926*v_1^2*h^8 + 4192*u_1*v_2*h^8 - 2032*u_2*v_2*h^8 + 2920*v_1*v_2*h^8 + 2466*v_2^2*h^8 - 859*u_2*y*h^8 - 4727*v_1*y*h^8 + 730*v_2*y*h^8 + 3809*u_1*h^9 + 3719*u_2*h^9 + 3126*v_1*h^9 + 2700*v_2*h^9 + 347*y*h^9 - 428*h^10,
#  v_1*v_2^2*h^7 - 3938*u_2^2*h^8 + 547*u_2*v_1*h^8 - 3947*v_1^2*h^8 - 549*u_1*v_2*h^8 - 2621*u_2*v_2*h^8 + 2406*v_1*v_2*h^8 + 293*v_2^2*h^8 + 4558*u_2*y*h^8 - 3248*v_1*y*h^8 + 4018*v_2*y*h^8 + 2843*u_1*h^9 - 2488*u_2*h^9 - 1661*v_1*h^9 - 4254*v_2*h^9 + 544*y*h^9 - 1599*h^10,
#  u_2^2*y*h^7 + 3740*u_2^2*h^8 + 1377*u_2*v_1*h^8 + 1852*v_1^2*h^8 - 3318*u_1*v_2*h^8 - 3268*u_2*v_2*h^8 + 3536*v_1*v_2*h^8 - 1917*v_2^2*h^8 + 2276*u_2*y*h^8 + 1124*v_1*y*h^8 - 13*v_2*y*h^8 + 4360*u_1*h^9 - 4690*u_2*h^9 + 67*v_1*h^9 + 2135*v_2*h^9 + 3885*y*h^9 - 4601*h^10,
#  u_2*v_2*y*h^7 + 2596*u_2^2*h^8 + 4874*u_2*v_1*h^8 - 2770*v_1^2*h^8 - 765*u_1*v_2*h^8 + 2144*u_2*v_2*h^8 - 4769*v_1*v_2*h^8 - 3896*v_2^2*h^8 - 4182*u_2*y*h^8 + 3996*v_1*y*h^8 - 756*v_2*y*h^8 - 4826*u_1*h^9 + 3690*u_2*h^9 + 3441*v_1*h^9 - 2875*v_2*h^9 + 392*y*h^9 + 372*h^10,
#  v_1*v_2*y*h^7 + 2147*u_2^2*h^8 + 2108*u_2*v_1*h^8 + 2444*v_1^2*h^8 + 1433*u_1*v_2*h^8 + 1161*u_2*v_2*h^8 + 3250*v_1*v_2*h^8 + 2475*v_2^2*h^8 - 2280*u_2*y*h^8 - 546*v_1*y*h^8 - 315*v_2*y*h^8 - 45*u_1*h^9 - 3036*u_2*h^9 - 951*v_1*h^9 + 257*v_2*h^9 + 3408*y*h^9 + 651*h^10,
#  v_2^2*y*h^7 - 3822*u_2^2*h^8 + 289*u_2*v_1*h^8 + 2021*v_1^2*h^8 + 3266*u_1*v_2*h^8 + 3389*u_2*v_2*h^8 - 126*v_1*v_2*h^8 + 3321*v_2^2*h^8 + 3038*u_2*y*h^8 + 2522*v_1*y*h^8 - 2746*v_2*y*h^8 - 3787*u_1*h^9 + 2723*u_2*h^9 - 2410*v_1*h^9 - 3274*v_2*h^9 - 1948*y*h^9 + 3807*h^10,
#  v_1^2*v_2^2*h^5 + 1897*u_2^2*v_2*h^6 + 2402*u_1*v_2^2*h^6 - 3442*u_2*v_2^2*h^6 + 4495*v_1*v_2^2*h^6 - 4381*u_2^2*y*h^6 + 2475*u_2*v_2*y*h^6 - 1963*v_1*v_2*y*h^6 - 1791*v_2^2*y*h^6 + 1532*u_2^2*h^7 + 1756*u_2*v_1*h^7 + 4912*v_1^2*h^7 - 2325*u_1*v_2*h^7 + 4574*u_2*v_2*h^7 - 3868*v_1*v_2*h^7 - 2828*v_2^2*h^7 + 2683*u_2*y*h^7 + 900*v_1*y*h^7 + 4741*v_2*y*h^7 - 546*u_1*h^8 - 773*u_2*h^8 + 563*v_1*h^8 - 352*v_2*h^8 - 521*y*h^8 + 128*h^9,
#  u_2^2*v_2*y*h^5 + 1943*u_2^2*v_2*h^6 + 201*u_1*v_2^2*h^6 - 1990*u_2*v_2^2*h^6 + 1150*v_1*v_2^2*h^6 - 3118*u_2^2*y*h^6 - 2082*u_2*v_2*y*h^6 - 2213*v_1*v_2*y*h^6 + 1281*v_2^2*y*h^6 - 2255*u_2^2*h^7 - 3549*u_2*v_1*h^7 + 4487*v_1^2*h^7 - 3312*u_1*v_2*h^7 - 1720*u_2*v_2*h^7 - 4155*v_1*v_2*h^7 - 923*v_2^2*h^7 - 39*u_2*y*h^7 + 3873*v_1*y*h^7 - 4933*v_2*y*h^7 - 159*u_1*h^8 + 4006*u_2*h^8 - 3056*v_1*h^8 - 1417*v_2*h^8 + 2912*y*h^8 + 3604*h^9,
#  u_2*v_2^2*y*h^5 - 4600*u_2^2*v_2*h^6 + 4825*u_1*v_2^2*h^6 + 4587*u_2*v_2^2*h^6 - 1154*v_1*v_2^2*h^6 - 657*u_2^2*y*h^6 + 4998*u_2*v_2*y*h^6 + 2909*v_1*v_2*y*h^6 + 4927*v_2^2*y*h^6 + 2483*u_2^2*h^7 - 4182*u_2*v_1*h^7 - 3522*v_1^2*h^7 - 4129*u_1*v_2*h^7 + 1935*u_2*v_2*h^7 + 2202*v_1*v_2*h^7 - 2710*v_2^2*h^7 - 4898*u_2*y*h^7 + 1655*v_1*y*h^7 + 223*v_2*y*h^7 - 2457*u_1*h^8 + 608*u_2*h^8 + 3036*v_1*h^8 - 1447*v_2*h^8 - 4088*y*h^8 + 2101*h^9,
#  v_1*v_2^2*y*h^5 - 1548*u_2^2*v_2*h^6 - 481*u_1*v_2^2*h^6 + 1175*u_2*v_2^2*h^6 + 1452*v_1*v_2^2*h^6 - 3443*u_2^2*y*h^6 - 2978*u_2*v_2*y*h^6 + 687*v_1*v_2*y*h^6 + 1857*v_2^2*y*h^6 - 2172*u_2^2*h^7 - 3858*u_2*v_1*h^7 + 331*v_1^2*h^7 - 3651*u_1*v_2*h^7 - 2587*u_2*v_2*h^7 + 3261*v_1*v_2*h^7 + 584*v_2^2*h^7 + 2363*u_2*y*h^7 + 2018*v_1*y*h^7 + 197*v_2*y*h^7 - 4647*u_1*h^8 + 4042*u_2*h^8 + 1434*v_1*h^8 + 365*v_2*h^8 + 3947*y*h^8 + 891*h^9,
#  v_1^2*v_2*h^6 - 3372*u_2^2*y*h^6 - 1867*u_2*v_2*y*h^6 - 1645*v_1*v_2*y*h^6 - 4768*v_2^2*y*h^6 - 1585*u_2^2*h^7 - 1026*u_2*v_1*h^7 - 2656*v_1^2*h^7 + u_1*v_2*h^7 + 350*u_2*v_2*h^7 + 268*v_1*v_2*h^7 - 560*v_2^2*h^7 - 4803*u_2*y*h^7 + 3592*v_1*y*h^7 + 2823*v_2*y*h^7 - 281*u_1*h^8 - 1116*u_2*h^8 - 3846*v_1*h^8 - 48*v_2*h^8 - 3618*y*h^8 + 4495*h^9,
#  u_2^2*v_1*h^5 + 3463*v_1^2*v_2*h^5 - 6*u_1*v_2^2*h^5 + 5*v_1*v_2^2*h^5 - 3134*u_2^2*y*h^5 - 3835*u_2*v_2*y*h^5 + 3148*v_1*v_2*y*h^5 - 4458*v_2^2*y*h^5 - 4448*u_2^2*h^6 + 1549*u_2*v_1*h^6 + 1757*v_1^2*h^6 + 3651*u_1*v_2*h^6 + 3833*u_2*v_2*h^6 - 3646*v_1*v_2*h^6 - 4978*v_2^2*h^6 + 2098*u_2*y*h^6 + 1911*v_1*y*h^6 + 2703*v_2*y*h^6 - 1261*u_1*h^7 + 3063*u_2*h^7 + 3083*v_1*h^7 + 508*v_2*h^7 + 2477*y*h^7 + 2996*h^8,
#  u_2*v_1^2*h^5 + 74*v_1^2*v_2*h^5 - 831*u_2^2*y*h^5 + 1662*u_2*v_2*y*h^5 - 1194*v_1*v_2*y*h^5 - 831*v_2^2*y*h^5 - 465*u_2^2*h^6 - 4036*u_2*v_1*h^6 - 1049*v_1^2*h^6 + 40*u_1*v_2*h^6 - 919*u_2*v_2*h^6 - 3406*v_1*v_2*h^6 + 1384*v_2^2*h^6 + 3468*u_2*y*h^6 - 2134*v_1*y*h^6 + 3485*v_2*y*h^6 - 259*u_1*h^7 + 2217*u_2*h^7 - 3654*v_1*h^7 + 2404*v_2*h^7 - 3672*y*h^7 + 3162*h^8,
#  u_2*v_1*v_2*h^5 + 2526*v_1^2*v_2*h^5 - 3*u_1*v_2^2*h^5 + 2*v_1*v_2^2*h^5 + 3055*u_2^2*y*h^5 + 1453*u_2*v_2*y*h^5 - 339*v_1*v_2*y*h^5 - 4792*v_2^2*y*h^5 - 1000*u_2^2*h^6 - 44*u_2*v_1*h^6 - 2972*v_1^2*h^6 - 3942*u_1*v_2*h^6 - 4862*u_2*v_2*h^6 + 4594*v_1*v_2*h^6 + 4747*v_2^2*h^6 + 375*u_2*y*h^6 - 3649*v_1*y*h^6 + 2909*v_2*y*h^6 + 1826*u_1*h^7 - 4055*u_2*h^7 - 1585*v_1*h^7 - 877*v_2*h^7 - 3604*y*h^7 - 4470*h^8,
#  u_2*v_1*y*h^4 - v_1*v_2*y*h^4 - 2371*u_2*v_1*h^5 - 3861*v_1^2*h^5 + 2346*u_1*v_2*h^5 - 3754*v_1*v_2*h^5 - 3652*u_2*y*h^5 + 999*v_1*y*h^5 + 4049*v_2*y*h^5 + 961*u_1*h^6 + 1666*u_2*h^6 - 4537*v_1*h^6 - 4516*v_2*h^6 - 208*y*h^6 - 1771*h^7,
#  u_1*u_2*h^5 + 2467*u_2*v_1*h^5 + 4594*v_1^2*h^5 + 2602*u_1*v_2*h^5 + 4937*v_1*v_2*h^5 + 4121*u_2*y*h^5 + 3604*v_1*y*h^5 - 4827*v_2*y*h^5 - 3258*u_1*h^6 - 184*u_2*h^6 - 396*v_1*h^6 - 832*v_2*h^6 - 3354*y*h^6 - 164*h^7,
#  u_1*v_1*h^5 + 1651*u_2*v_1*h^5 - 2469*v_1^2*h^5 - 4953*u_1*v_2*h^5 + 3302*v_1*v_2*h^5 - 2223*u_2*y*h^5 - 2936*v_1*y*h^5 + 3668*v_2*y*h^5 - 1269*u_1*h^6 + 4817*u_2*h^6 - 4585*v_1*h^6 - 4394*v_2*h^6 + 4077*y*h^6 + 42*h^7,
#  u_1*v_1^2*h^3 - 2948*u_1*v_1*h^4 - 2035*v_1^2*h^4 + 4308*u_2*y*h^4 - 209*v_1*y*h^4 - 4308*v_2*y*h^4 + 2694*u_1*h^5 - 3960*u_2*h^5 - 64*v_1*h^5 - 4591*v_2*h^5 + 3587*y*h^5 + 2388*h^6,
#  v_1^2*y*h^3 + 4689*u_1*v_1*h^4 + 844*v_1^2*h^4 - 4245*u_2*y*h^4 - 810*v_1*y*h^4 + 4245*v_2*y*h^4 + 2960*u_1*h^5 + 587*u_2*h^5 + 4401*v_1*h^5 + 47*v_2*h^5 - 1071*y*h^5 + 347*h^6,
#  u_1^2*h^3 - 2*u_1*v_1*h^3 + v_1^2*h^3 + 3241*v_1*y*h^3 + 443*u_1*h^4 - 4011*v_1*h^4 - 1049*y*h^4 - 2528*h^5,
#  u_1*y*h^2 - v_1*y*h^2 - 3665*u_1*h^3 - 4266*v_1*h^3 - 4180*y*h^3 + 4792*h^4,
#  u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + 1080*u_1^2*h + 2160*u_1*y*h - 2709*u_1*h^2 - u_2*h^2 + 1237*v_1*h^2 - 784*y*h^2 - 4302*h^3,
#  u_2^3 + 3*u_2^2*y + 3*u_2*y^2 - 4114*u_2^2*h + 1779*u_2*y*h + 3153*u_1*h^2 + 1053*u_2*h^2 - 3152*v_1*h^2 + 1153*y*h^2 + 4868*h^3,
#  v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + 1080*v_1^2*h + 2160*v_1*y*h - 1236*u_1*h^2 - 236*v_1*h^2 - v_2*h^2 - 784*y*h^2 - 4302*h^3,
#  v_2^3 + 3*v_2^2*y + 3*v_2*y^2 - 4114*v_2^2*h + 1779*v_2*y*h + 3153*u_1*h^2 - 3152*v_1*h^2 + 1053*v_2*h^2 + 1153*y*h^2 - 1651*h^3,
#  y^3 - 2293*u_1*h^2 + 2292*v_1*h^2 + 686*y*h^2 + 4002*h^3,
#  y^2*h - 2656*u_1*h^2 + 2656*v_1*h^2 + 601*y*h^2 - 4055*h^3]

# %%
res = ideal(polys_h).graded_free_resolution(algorithm="minimal")
res
# Out:
# S(0) <-- S(-3)⊕S(-3)⊕S(-3)⊕S(-3)⊕S(-3)⊕S(-3) <-- S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-13) <-- S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-14)⊕S(-14)⊕S(-14)⊕S(-14)⊕S(-14) <-- S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15) <-- S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-16)⊕S(-16)⊕S(-16)⊕S(-16)⊕S(-16)⊕S(-16)⊕S(-16)⊕S(-16)⊕S(-16)⊕S(-16) <-- S(-17)⊕S(-17)⊕S(-17)⊕S(-17)⊕S(-17) <-- 0

# %%
cm_regularity(res)
# Out:
# 12

# %% [markdown]
# ## p = 10007, r = 4

# %%
p = 10007
field = GF(p, "a")

rounds = 4

mimc = MiMC(field=field, rounds=rounds)

print("")

key = field.random_element()
print("Key:", key)

plain_1 = field.random_element()
cipher_1 = mimc.encryption(plain_1, key)

print("Plain 1:", plain_1)
print("Cipher 1:", cipher_1)

plain_2 = field.random_element()
cipher_2 = mimc.encryption(plain_2, key)

print("Plain 2:", plain_2)
print("Cipher 2:", cipher_2)

print("")

polys = mimc.generate_two_plain_text_polynomials(plain_1, 
                                                 cipher_1, 
                                                 plain_2, 
                                                 cipher_2,
                                                 info_level=0)
polys_h = [poly.homogenize() for poly in polys]

for i in range(0, 2 * rounds):
    print(polys[i])
    if i == rounds - 1:
        print("\n")
# Out:
# MiMC Parameters
# Field: Finite Field of size 10007
# r: 4
# Constants: [8293, 9481, 7557, 6209]
#
# Key: 7658
# Plain 1: 7620
# Cipher 1: 9400
# Plain 2: 3661
# Cipher 2: 7582
#
# y^3 - 2296*y^2 - u_1 - 691*y + 3939
# u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + y^3 - 1578*u_1^2 - 3156*u_1*y - 1578*y^2 - 553*u_1 - u_2 - 553*y + 225
# u_2^3 + 3*u_2^2*y + 3*u_2*y^2 + y^3 + 2657*u_2^2 - 4693*u_2*y + 2657*y^2 + 4907*u_2 - u_3 + 4907*y + 2088
# u_3^3 + 3*u_3^2*y + 3*u_3*y^2 + y^3 - 1387*u_3^2 - 2774*u_3*y - 1387*y^2 + 4144*u_3 + 4145*y - 2029
#
#
# y^3 - 4166*y^2 - v_1 + 4475*y + 2245
# v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + y^3 - 1578*v_1^2 - 3156*v_1*y - 1578*y^2 - 553*v_1 - v_2 - 553*y + 225
# v_2^3 + 3*v_2^2*y + 3*v_2*y^2 + y^3 + 2657*v_2^2 - 4693*v_2*y + 2657*y^2 + 4907*v_2 - v_3 + 4907*y + 2088
# v_3^3 + 3*v_3^2*y + 3*v_3*y^2 + y^3 - 1387*v_3^2 - 2774*v_3*y - 1387*y^2 + 4144*v_3 + 4145*y - 211

# %%
lazard_gb_algorithm(polys)
# Out:
# Ring: Multivariate Polynomial Ring in u_1, u_2, u_3, v_1, v_2, v_3, y over Finite Field of size 10007
# Input polynomials:
# [y^3 - 2296*y^2 - u_1 - 691*y + 3939, u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + y^3 - 1578*u_1^2 - 3156*u_1*y - 1578*y^2 - 553*u_1 - u_2 - 553*y + 225, u_2^3 + 3*u_2^2*y + 3*u_2*y^2 + y^3 + 2657*u_2^2 - 4693*u_2*y + 2657*y^2 + 4907*u_2 - u_3 + 4907*y + 2088, u_3^3 + 3*u_3^2*y + 3*u_3*y^2 + y^3 - 1387*u_3^2 - 2774*u_3*y - 1387*y^2 + 4144*u_3 + 4145*y - 2029, y^3 - 4166*y^2 - v_1 + 4475*y + 2245, v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + y^3 - 1578*v_1^2 - 3156*v_1*y - 1578*y^2 - 553*v_1 - v_2 - 553*y + 225, v_2^3 + 3*v_2^2*y + 3*v_2*y^2 + y^3 + 2657*v_2^2 - 4693*v_2*y + 2657*y^2 + 4907*v_2 - v_3 + 4907*y + 2088, v_3^3 + 3*v_3^2*y + 3*v_3*y^2 + y^3 - 1387*v_3^2 - 2774*v_3*y - 1387*y^2 + 4144*v_3 + 4145*y - 211]
#
# --- Degree 0 ---
# Computing all monomials up to degree: 0
# Time needed: 0.00052642822265625
# Computing Macaulay matrix.
# Time needed: 2.1457672119140625e-06
# Performing Gaussian Elimination.
# Time needed: 8.034706115722656e-05
# Is Groebner Basis: False
#
# --- Degree 1 ---
# Computing all monomials up to degree: 1
# Time needed: 0.0012021064758300781
# Computing Macaulay matrix.
# Time needed: 1.1920928955078125e-06
# Performing Gaussian Elimination.
# Time needed: 0.000606536865234375
# Is Groebner Basis: False
#
# --- Degree 2 ---
# Computing all monomials up to degree: 2
# Time needed: 0.0013971328735351562
# Computing Macaulay matrix.
# Time needed: 2.1457672119140625e-06
# Performing Gaussian Elimination.
# Time needed: 0.00015783309936523438
# Is Groebner Basis: False
#
# --- Degree 3 ---
# Computing all monomials up to degree: 3
# Time needed: 0.0030269622802734375
# Computing Macaulay matrix.
# Time needed: 1.6689300537109375e-06
# Performing Gaussian Elimination.
# Time needed: 0.00024509429931640625
# Is Groebner Basis: False
#
# --- Degree 4 ---
# Computing all monomials up to degree: 4
# Time needed: 0.0071675777435302734
# Computing Macaulay matrix.
# Time needed: 2.384185791015625e-06
# Performing Gaussian Elimination.
# Time needed: 0.0011277198791503906
# Is Groebner Basis: False
#
# --- Degree 5 ---
# Computing all monomials up to degree: 5
# Time needed: 0.014316082000732422
# Computing Macaulay matrix.
# Time needed: 2.384185791015625e-06
# Performing Gaussian Elimination.
# Time needed: 0.005460023880004883
# Is Groebner Basis: False
#
# --- Degree 6 ---
# Computing all monomials up to degree: 6
# Time needed: 0.028666973114013672
# Computing Macaulay matrix.
# Time needed: 4.76837158203125e-06
# Performing Gaussian Elimination.
# Time needed: 0.03328132629394531
# Is Groebner Basis: False
#
# --- Degree 7 ---
# Computing all monomials up to degree: 7
# Time needed: 0.053202152252197266
# Computing Macaulay matrix.
# Time needed: 3.5762786865234375e-06
# Performing Gaussian Elimination.
# Time needed: 0.17336463928222656
# Is Groebner Basis: False
#
# --- Degree 8 ---
# Computing all monomials up to degree: 8
# Time needed: 0.10023999214172363
# Computing Macaulay matrix.
# Time needed: 6.198883056640625e-06
# Performing Gaussian Elimination.
# Time needed: 1.0723364353179932
# Is Groebner Basis: False
#
# --- Degree 9 ---
# Computing all monomials up to degree: 9
# Time needed: 0.2814140319824219
# Computing Macaulay matrix.
# Time needed: 5.7220458984375e-06
# Performing Gaussian Elimination.
# Time needed: 4.5785956382751465
# Is Groebner Basis: False
#
# --- Degree 10 ---
# Computing all monomials up to degree: 10
# Time needed: 0.3027992248535156
# Computing Macaulay matrix.
# Time needed: 6.4373016357421875e-06
# Performing Gaussian Elimination.
# Time needed: 36.557178258895874
# Is Groebner Basis: False
#
# --- Degree 11 ---
# Computing all monomials up to degree: 11
# Time needed: 0.4978525638580322
# Computing Macaulay matrix.
# Time needed: 5.9604644775390625e-06
# Performing Gaussian Elimination.
# Time needed: 169.02398657798767
# Is Groebner Basis: False
#
# --- Degree 12 ---
# Computing all monomials up to degree: 12
# Time needed: 0.8037621974945068
# Computing Macaulay matrix.
# Time needed: 6.4373016357421875e-06
# Performing Gaussian Elimination.
# Time needed: 493.35623812675476
# Is Groebner Basis: False
#
# --- Degree 13 ---
# Computing all monomials up to degree: 13
# Time needed: 1.5887250900268555
# Computing Macaulay matrix.
# Time needed: 6.9141387939453125e-06
# Performing Gaussian Elimination.
# Time needed: 1436.5608661174774
# Is Groebner Basis: False
#
# --- Degree 14 ---
# Computing all monomials up to degree: 14
# Time needed: 1.8406600952148438
# Computing Macaulay matrix.
# Time needed: 7.152557373046875e-06
# Performing Gaussian Elimination.
# Time needed: 4631.600446462631
# Is Groebner Basis: False
#
# --- Degree 15 ---
# Computing all monomials up to degree: 15
# Time needed: 3.820293426513672
# Computing Macaulay matrix.
# Time needed: 6.198883056640625e-06
# Performing Gaussian Elimination.
# Time needed: 10193.125271320343
# Is Groebner Basis: False
#
# --- Degree 16 ---
# Computing all monomials up to degree: 16
# Time needed: 4.870495080947876
# Computing Macaulay matrix.
# Time needed: 8.821487426757812e-06
# Performing Gaussian Elimination.
# Time needed: 25127.311333417892
# Is Groebner Basis: True
# Total time needed: 42379.00825214386
# [u_1 + 1106,
#  u_2 + 1408,
#  u_3 + 3534,
#  v_1 - 636,
#  v_2 - 3652,
#  v_3 - 2042,
#  y + 2349]

# %%
lazard_gb_algorithm(polys_h)
# Out:
# Ring: Multivariate Polynomial Ring in u_1, u_2, u_3, v_1, v_2, v_3, y, h over Finite Field of size 10007
# Input polynomials:
# [y^3 - 2296*y^2*h - u_1*h^2 - 691*y*h^2 + 3939*h^3, u_1^3 + 3*u_1^2*y + 3*u_1*y^2 + y^3 - 1578*u_1^2*h - 3156*u_1*y*h - 1578*y^2*h - 553*u_1*h^2 - u_2*h^2 - 553*y*h^2 + 225*h^3, u_2^3 + 3*u_2^2*y + 3*u_2*y^2 + y^3 + 2657*u_2^2*h - 4693*u_2*y*h + 2657*y^2*h + 4907*u_2*h^2 - u_3*h^2 + 4907*y*h^2 + 2088*h^3, u_3^3 + 3*u_3^2*y + 3*u_3*y^2 + y^3 - 1387*u_3^2*h - 2774*u_3*y*h - 1387*y^2*h + 4144*u_3*h^2 + 4145*y*h^2 - 2029*h^3, y^3 - 4166*y^2*h - v_1*h^2 + 4475*y*h^2 + 2245*h^3, v_1^3 + 3*v_1^2*y + 3*v_1*y^2 + y^3 - 1578*v_1^2*h - 3156*v_1*y*h - 1578*y^2*h - 553*v_1*h^2 - v_2*h^2 - 553*y*h^2 + 225*h^3, v_2^3 + 3*v_2^2*y + 3*v_2*y^2 + y^3 + 2657*v_2^2*h - 4693*v_2*y*h + 2657*y^2*h + 4907*v_2*h^2 - v_3*h^2 + 4907*y*h^2 + 2088*h^3, v_3^3 + 3*v_3^2*y + 3*v_3*y^2 + y^3 - 1387*v_3^2*h - 2774*v_3*y*h - 1387*y^2*h + 4144*v_3*h^2 + 4145*y*h^2 - 211*h^3]
#
# --- Degree 0 ---
# Computing all monomials up to degree: 0
# Time needed: 0.0005922317504882812
# Computing Macaulay matrix.
# Time needed: 1.1920928955078125e-06
# Performing Gaussian Elimination.
# Time needed: 7.62939453125e-05
# Is Groebner Basis: False
#
# --- Degree 1 ---
# Computing all monomials up to degree: 1
# Time needed: 0.002099752426147461
# Computing Macaulay matrix.
# Time needed: 3.0994415283203125e-06
# Performing Gaussian Elimination.
# Time needed: 0.00018358230590820312
# Is Groebner Basis: False
#
# --- Degree 2 ---
# Computing all monomials up to degree: 2
# Time needed: 0.0020394325256347656
# Computing Macaulay matrix.
# Time needed: 1.430511474609375e-06
# Performing Gaussian Elimination.
# Time needed: 0.0002071857452392578
# Is Groebner Basis: False
#
# --- Degree 3 ---
# Computing all monomials up to degree: 3
# Time needed: 0.006200075149536133
# Computing Macaulay matrix.
# Time needed: 1.6689300537109375e-06
# Performing Gaussian Elimination.
# Time needed: 0.0005140304565429688
# Is Groebner Basis: False
#
# --- Degree 4 ---
# Computing all monomials up to degree: 4
# Time needed: 0.012600898742675781
# Computing Macaulay matrix.
# Time needed: 2.384185791015625e-06
# Performing Gaussian Elimination.
# Time needed: 0.001861572265625
# Is Groebner Basis: False
#
# --- Degree 5 ---
# Computing all monomials up to degree: 5
# Time needed: 0.028466224670410156
# Computing Macaulay matrix.
# Time needed: 3.0994415283203125e-06
# Performing Gaussian Elimination.
# Time needed: 0.010094881057739258
# Is Groebner Basis: False
#
# --- Degree 6 ---
# Computing all monomials up to degree: 6
# Time needed: 0.0628213882446289
# Computing Macaulay matrix.
# Time needed: 5.0067901611328125e-06
# Performing Gaussian Elimination.
# Time needed: 0.08833432197570801
# Is Groebner Basis: False
#
# --- Degree 7 ---
# Computing all monomials up to degree: 7
# Time needed: 0.2130753993988037
# Computing Macaulay matrix.
# Time needed: 5.9604644775390625e-06
# Performing Gaussian Elimination.
# Time needed: 0.4851522445678711
# Is Groebner Basis: False
#
# --- Degree 8 ---
# Computing all monomials up to degree: 8
# Time needed: 0.263413667678833
# Computing Macaulay matrix.
# Time needed: 7.62939453125e-06
# Performing Gaussian Elimination.
# Time needed: 3.3090832233428955
# Is Groebner Basis: False
#
# --- Degree 9 ---
# Computing all monomials up to degree: 9
# Time needed: 0.6466145515441895
# Computing Macaulay matrix.
# Time needed: 6.67572021484375e-06
# Performing Gaussian Elimination.
# Time needed: 23.490265607833862
# Is Groebner Basis: False
#
# --- Degree 10 ---
# Computing all monomials up to degree: 10
# Time needed: 1.1839838027954102
# Computing Macaulay matrix.
# Time needed: 5.7220458984375e-06
# Performing Gaussian Elimination.
# Time needed: 153.85294556617737
# Is Groebner Basis: False
#
# --- Degree 11 ---
# Computing all monomials up to degree: 11
# Time needed: 1.3336412906646729
# Computing Macaulay matrix.
# Time needed: 5.9604644775390625e-06
# Performing Gaussian Elimination.
# Time needed: 663.9457628726959
# Is Groebner Basis: False
#
# --- Degree 12 ---
# Computing all monomials up to degree: 12
# Time needed: 2.634280204772949
# Computing Macaulay matrix.
# Time needed: 8.106231689453125e-06
# Performing Gaussian Elimination.
# Time needed: 2341.566554069519
# Is Groebner Basis: False
#
# --- Degree 13 ---
# Computing all monomials up to degree: 13
# Time needed: 4.213667154312134
# Computing Macaulay matrix.
# Time needed: 6.4373016357421875e-06
# Performing Gaussian Elimination.
# Time needed: 7808.830991983414
# Is Groebner Basis: False
#
# --- Degree 14 ---
# Computing all monomials up to degree: 14
# Time needed: 6.964911937713623
# Computing Macaulay matrix.
# Time needed: 6.198883056640625e-06
# Performing Gaussian Elimination.
# Time needed: 22825.886057138443
# Is Groebner Basis: False
#
# --- Degree 15 ---
# Computing all monomials up to degree: 15
# Time needed: 10.665425300598145
# Computing Macaulay matrix.
# Time needed: 6.67572021484375e-06
# Performing Gaussian Elimination.
# Time needed: 51665.177974939346
# Is Groebner Basis: False
#
# --- Degree 16 ---
# Computing all monomials up to degree: 16
# Time needed: 13.960731029510498
# Computing Macaulay matrix.
# Time needed: 4.0531158447265625e-06
# Performing Gaussian Elimination.
# Time needed: 94795.589407444
# Is Groebner Basis: True
# Total time needed: 181930.50687098503
# [u_1*h^15 + 1106*h^16,
#  u_2*h^15 + 1408*h^16,
#  u_3*h^15 + 3534*h^16,
#  v_1*h^15 - 636*h^16,
#  v_2*h^15 - 3652*h^16,
#  v_3*h^15 - 2042*h^16,
#  y*h^15 + 2349*h^16,
#  u_2^2*h^13 - 442*u_1*h^14 - 917*u_2*h^14 - 924*u_3*h^14 + 4618*v_1*h^14 + 3528*v_2*h^14 + 2742*v_3*h^14 + 1205*y*h^14 + 129*h^15,
#  u_1*u_3*h^13 - 2899*u_1*h^14 - 966*u_2*h^14 + 3439*u_3*h^14 - 1273*v_1*h^14 - 1457*v_2*h^14 - 653*v_3*h^14 + 918*y*h^14 - 503*h^15,
#  u_2*u_3*h^13 - 717*u_1*h^14 + 3931*u_2*h^14 + 2142*u_3*h^14 + 4279*v_1*h^14 + 944*v_2*h^14 + 2678*v_3*h^14 + 4322*y*h^14 - 3323*h^15,
#  u_3^2*h^13 - 1766*u_1*h^14 + 3146*u_2*h^14 + 1635*u_3*h^14 + 1609*v_1*h^14 + 4022*v_2*h^14 - 4644*v_3*h^14 + 4852*y*h^14 + 3383*h^15,
#  u_2*v_1*h^13 + 123*u_1*h^14 - 371*u_2*h^14 + 4716*u_3*h^14 - 1713*v_1*h^14 + 2845*v_2*h^14 - 4624*v_3*h^14 - 254*y*h^14 - 1105*h^15,
#  u_3*v_1*h^13 + 939*u_1*h^14 + 2121*u_2*h^14 - 2001*u_3*h^14 - 2975*v_1*h^14 + 1200*v_2*h^14 - 3327*v_3*h^14 - 4499*y*h^14 + 1217*h^15,
#  v_1^2*h^13 - 1971*u_1*h^14 - 4977*u_2*h^14 - 391*u_3*h^14 - 701*v_1*h^14 + 601*v_2*h^14 + 3405*v_3*h^14 + 3381*y*h^14 + 4322*h^15,
#  u_1*v_2*h^13 + 394*u_1*h^14 + 1075*u_2*h^14 + 1836*u_3*h^14 + 398*v_1*h^14 + 1881*v_2*h^14 - 4793*v_3*h^14 + 4989*y*h^14 + 2039*h^15,
#  u_2*v_2*h^13 - 1027*u_1*h^14 - 2181*u_2*h^14 - 2003*u_3*h^14 + 4479*v_1*h^14 - 1421*v_2*h^14 - 2001*v_3*h^14 + 3567*y*h^14 - 3585*h^15,
#  u_3*v_2*h^13 + 4593*u_1*h^14 + 4089*u_2*h^14 - 369*u_3*h^14 + 2547*v_1*h^14 - 3027*v_2*h^14 - 2469*v_3*h^14 - 1932*y*h^14 + 4789*h^15,
#  v_1*v_2*h^13 - 4691*u_1*h^14 + 4029*u_2*h^14 + 2397*u_3*h^14 - 377*v_1*h^14 + 2523*v_2*h^14 - 1430*v_3*h^14 - 1760*y*h^14 - 3007*h^15,
#  v_2^2*h^13 + 181*u_1*h^14 - 4214*u_2*h^14 - 3437*u_3*h^14 + 4974*v_1*h^14 - 2198*v_2*h^14 - 490*v_3*h^14 + 4039*y*h^14 - 3670*h^15,
#  u_1*v_3*h^13 + 3854*u_1*h^14 + 3933*u_2*h^14 + 2645*u_3*h^14 + 4770*v_1*h^14 + 4420*v_2*h^14 - 3010*v_3*h^14 + 3828*y*h^14 - 3250*h^15,
#  u_2*v_3*h^13 + 4051*u_1*h^14 - 3038*u_2*h^14 + 1207*u_3*h^14 + 1867*v_1*h^14 + 2126*v_2*h^14 + 2457*v_3*h^14 + 4147*y*h^14 + 3944*h^15,
#  u_3*v_3*h^13 - 3287*u_1*h^14 + 754*u_2*h^14 - 4520*u_3*h^14 - 4201*v_1*h^14 + 4197*v_2*h^14 - 138*v_3*h^14 - 853*y*h^14 - 568*h^15,
#  v_1*v_3*h^13 + 1929*u_1*h^14 + 3003*u_2*h^14 - 4197*u_3*h^14 - 4093*v_1*h^14 - 3673*v_2*h^14 - 4548*v_3*h^14 + 4496*y*h^14 - 2404*h^15,
#  v_2*v_3*h^13 - 1858*u_1*h^14 - 1666*u_2*h^14 + 2850*u_3*h^14 + 3473*v_1*h^14 + 4203*v_2*h^14 - 2614*v_3*h^14 + 3731*y*h^14 + 1231*h^15,
#  v_3^2*h^13 + 1709*u_1*h^14 - 3712*u_2*h^14 + 4410*u_3*h^14 + 258*v_1*h^14 + 2383*v_2*h^14 + 3009*v_3*h^14 - 1149*y*h^14 - 4615*h^15,
#  u_2*y*h^13 - 4034*u_1*h^14 - 3539*u_2*h^14 - 2130*u_3*h^14 - 562*v_1*h^14 - 1432*v_2*h^14 + 4812*v_3*h^14 + 3207*y*h^14 - 3214*h^15,
#  u_3*y*h^13 + 1494*u_1*h^14 - 2874*u_2*h^14 - 2235*u_3*h^14 + 4421*v_1*h^14 + 3740*v_2*h^14 + 4392*v_3*h^14 + 1841*y*h^14 - 499*h^15,
#  v_1*y*h^13 - 3792*u_1*h^14 - 3181*u_2*h^14 - 1712*u_3*h^14 - 2545*v_1*h^14 + 3841*v_2*h^14 - 4658*v_3*h^14 + 1371*y*h^14 + 3389*h^15,
#  v_2*y*h^13 - 380*u_1*h^14 + 2272*u_2*h^14 + 4376*u_3*h^14 + 2166*v_1*h^14 - 1990*v_2*h^14 - 1802*v_3*h^14 + 3087*y*h^14 + 2452*h^15,
#  v_3*y*h^13 + 1263*u_1*h^14 - 4678*u_2*h^14 - 4776*u_3*h^14 + 3312*v_1*h^14 + 3829*v_2*h^14 - 793*v_3*h^14 + 1098*y*h^14 - 2506*h^15,
#  u_2^2*u_3*h^11 - 346*u_2^2*h^12 - 3723*u_1*u_3*h^12 - 2792*u_2*u_3*h^12 + 3489*u_3^2*h^12 - 4324*u_2*v_1*h^12 + 1941*u_3*v_1*h^12 - 2522*v_1^2*h^12 + 2666*u_1*v_2*h^12 - 1280*u_2*v_2*h^12 + 95*u_3*v_2*h^12 + 1157*v_1*v_2*h^12 - 953*v_2^2*h^12 + 1162*u_1*v_3*h^12 - 1637*u_2*v_3*h^12 + 3371*u_3*v_3*h^12 + 4174*v_1*v_3*h^12 + 4921*v_2*v_3*h^12 - 2351*v_3^2*h^12 + 387*u_2*y*h^12 + 720*u_3*y*h^12 - 1469*v_1*y*h^12 + 3232*v_2*y*h^12 + 71*v_3*y*h^12 + 2570*u_1*h^13 + 2296*u_2*h^13 - 4590*u_3*h^13 + 201*v_1*h^13 + 1771*v_2*h^13 - 3384*v_3*h^13 + 936*y*h^13 + 1032*h^14,
#  u_1*u_3^2*h^11 - 2913*u_2^2*h^12 + 4002*u_1*u_3*h^12 - 2273*u_2*u_3*h^12 + 1932*u_3^2*h^12 - 2479*u_2*v_1*h^12 + 663*u_3*v_1*h^12 - 2886*v_1^2*h^12 + 3136*u_1*v_2*h^12 - 2921*u_2*v_2*h^12 - 440*u_3*v_2*h^12 + 1321*v_1*v_2*h^12 + 3187*v_2^2*h^12 + 2480*u_1*v_3*h^12 + 1374*u_2*v_3*h^12 - 1209*u_3*v_3*h^12 - 860*v_1*v_3*h^12 - 145*v_2*v_3*h^12 - 4570*v_3^2*h^12 - 583*u_2*y*h^12 - 2418*u_3*y*h^12 + 2129*v_1*y*h^12 + 2737*v_2*y*h^12 + 4241*v_3*y*h^12 - 230*u_1*h^13 + 2022*u_2*h^13 + 4546*u_3*h^13 + 2056*v_1*h^13 + 2388*v_2*h^13 + 4021*v_3*h^13 + 3666*y*h^13 - 708*h^14,
#  u_2*u_3^2*h^11 - 3414*u_2^2*h^12 + 1449*u_1*u_3*h^12 - 1109*u_2*u_3*h^12 + 2448*u_3^2*h^12 + 1345*u_2*v_1*h^12 - 1383*u_3*v_1*h^12 + 1281*v_1^2*h^12 + 1367*u_1*v_2*h^12 - 623*u_2*v_2*h^12 - 3867*u_3*v_2*h^12 - 2699*v_1*v_2*h^12 + 4859*v_2^2*h^12 + 817*u_1*v_3*h^12 - 3770*u_2*v_3*h^12 - 3380*u_3*v_3*h^12 - 3147*v_1*v_3*h^12 + 2271*v_2*v_3*h^12 + 2527*v_3^2*h^12 + 2369*u_2*y*h^12 - 905*u_3*y*h^12 + 884*v_1*y*h^12 + 3622*v_2*y*h^12 - 223*v_3*y*h^12 - 2973*u_1*h^13 - 3394*u_2*h^13 - 3109*u_3*h^13 + 4654*v_1*h^13 - 3191*v_2*h^13 + 4201*v_3*h^13 - 1249*y*h^13 + 2853*h^14,
#  u_3^2*v_1*h^11 + 2888*u_2^2*h^12 + 1699*u_1*u_3*h^12 - 2798*u_2*u_3*h^12 + 3456*u_3^2*h^12 + 3136*u_2*v_1*h^12 + 4525*u_3*v_1*h^12 + 23*v_1^2*h^12 - 1761*u_1*v_2*h^12 + 4335*u_2*v_2*h^12 - 840*u_3*v_2*h^12 + 3570*v_1*v_2*h^12 - 3473*v_2^2*h^12 - 690*u_1*v_3*h^12 - 904*u_2*v_3*h^12 - 4279*u_3*v_3*h^12 + 3873*v_1*v_3*h^12 - 635*v_2*v_3*h^12 - 4117*v_3^2*h^12 - 3842*u_2*y*h^12 - 1872*u_3*y*h^12 - 2966*v_1*y*h^12 - 28*v_2*y*h^12 + 4584*v_3*y*h^12 - 808*u_1*h^13 - 2861*u_2*h^13 - 3604*u_3*h^13 - 4340*v_1*h^13 - 3859*v_2*h^13 - 3634*v_3*h^13 + 4109*y*h^13 - 287*h^14,
#  u_2*u_3*v_2*h^11 + 3114*u_2^2*h^12 - 1170*u_1*u_3*h^12 + 2668*u_2*u_3*h^12 + 2126*u_3^2*h^12 - 907*u_2*v_1*h^12 + 4536*u_3*v_1*h^12 - 1288*v_1^2*h^12 - 4767*u_1*v_2*h^12 - 856*u_2*v_2*h^12 - 1228*u_3*v_2*h^12 + 3180*v_1*v_2*h^12 - 4826*v_2^2*h^12 + 2081*u_1*v_3*h^12 + 2472*u_2*v_3*h^12 - 26*u_3*v_3*h^12 - 1719*v_1*v_3*h^12 - 1393*v_2*v_3*h^12 + 274*v_3^2*h^12 + 1693*u_2*y*h^12 - 1659*u_3*y*h^12 - 2242*v_1*y*h^12 - 3846*v_2*y*h^12 + 1333*v_3*y*h^12 + 4577*u_1*h^13 - 2353*u_2*h^13 + 1206*u_3*h^13 - 1155*v_1*h^13 - 3121*v_2*h^13 + 939*v_3*h^13 - 4388*y*h^13 + 400*h^14,
#  u_3^2*v_2*h^11 - 1862*u_2^2*h^12 + 2916*u_1*u_3*h^12 - 4328*u_2*u_3*h^12 + 2632*u_3^2*h^12 - 4540*u_2*v_1*h^12 + 1832*u_3*v_1*h^12 + 3690*v_1^2*h^12 - 3561*u_1*v_2*h^12 - 2072*u_2*v_2*h^12 - 1420*u_3*v_2*h^12 - 4239*v_1*v_2*h^12 + 1581*v_2^2*h^12 - 3851*u_1*v_3*h^12 + 4722*u_2*v_3*h^12 - 117*u_3*v_3*h^12 - 3121*v_1*v_3*h^12 + 2191*v_2*v_3*h^12 + 1682*v_3^2*h^12 - 3924*u_2*y*h^12 - 1064*u_3*y*h^12 + 171*v_1*y*h^12 - 4403*v_2*y*h^12 - 4763*v_3*y*h^12 + 1930*u_1*h^13 + 2386*u_2*h^13 + 1497*u_3*h^13 + 2010*v_1*h^13 + 1548*v_2*h^13 - 4128*v_3*h^13 - 4785*y*h^13 + 3725*h^14,
#  u_3*v_2^2*h^11 + 1414*u_2^2*h^12 + 1142*u_1*u_3*h^12 + 2413*u_2*u_3*h^12 - 4024*u_3^2*h^12 + 4811*u_2*v_1*h^12 + 1663*u_3*v_1*h^12 + 3133*v_1^2*h^12 - 4269*u_1*v_2*h^12 + 3301*u_2*v_2*h^12 + 4356*u_3*v_2*h^12 + 2483*v_1*v_2*h^12 - 4856*v_2^2*h^12 - 2670*u_1*v_3*h^12 - 1671*u_2*v_3*h^12 + 413*u_3*v_3*h^12 - 4828*v_1*v_3*h^12 - 3278*v_2*v_3*h^12 - 2191*v_3^2*h^12 - 1517*u_2*y*h^12 + 1807*u_3*y*h^12 - 4593*v_1*y*h^12 - 21*v_2*y*h^12 + 4*v_3*y*h^12 + 2623*u_1*h^13 - 2362*u_2*h^13 - 3324*u_3*h^13 + 4438*v_1*h^13 - 3978*v_2*h^13 + 1327*v_3*h^13 + 1187*y*h^13 - 4054*h^14,
#  u_2^2*v_3*h^11 + 578*u_2^2*h^12 + 4625*u_1*u_3*h^12 + 502*u_2*u_3*h^12 + 3645*u_3^2*h^12 + 1969*u_2*v_1*h^12 + 3504*u_3*v_1*h^12 - 3163*v_1^2*h^12 - 4784*u_1*v_2*h^12 - 4464*u_2*v_2*h^12 + 1060*u_3*v_2*h^12 + 3972*v_1*v_2*h^12 + 4359*v_2^2*h^12 + 3508*u_1*v_3*h^12 - 1556*u_2*v_3*h^12 - 3647*u_3*v_3*h^12 + 4483*v_1*v_3*h^12 - 1737*v_2*v_3*h^12 + 4327*v_3^2*h^12 - 1219*u_2*y*h^12 - 3080*u_3*y*h^12 - 750*v_1*y*h^12 - 573*v_2*y*h^12 - 724*v_3*y*h^12 - 1732*u_1*h^13 - 4862*u_2*h^13 - 4416*u_3*h^13 + 3888*v_1*h^13 - 1213*v_2*h^13 + 1986*v_3*h^13 + 4953*y*h^13 + 2456*h^14,
#  u_1*u_3*v_3*h^11 - 2259*u_2^2*h^12 + 203*u_1*u_3*h^12 + 3984*u_2*u_3*h^12 + 652*u_3^2*h^12 - 1339*u_2*v_1*h^12 + 348*u_3*v_1*h^12 + 2328*v_1^2*h^12 + 306*u_1*v_2*h^12 - 87*u_2*v_2*h^12 - 1851*u_3*v_2*h^12 - 252*v_1*v_2*h^12 - 2070*v_2^2*h^12 + 4372*u_1*v_3*h^12 - 2285*u_2*v_3*h^12 + 3220*u_3*v_3*h^12 - 3042*v_1*v_3*h^12 - 561*v_2*v_3*h^12 + 4812*v_3^2*h^12 - 1000*u_2*y*h^12 + 3385*u_3*y*h^12 + 1989*v_1*y*h^12 + 1404*v_2*y*h^12 - 1433*v_3*y*h^12 - 413*u_1*h^13 - 480*u_2*h^13 - 2873*u_3*h^13 - 3775*v_1*h^13 + 1837*v_2*h^13 - 14*v_3*h^13 + 3531*y*h^13 + 4458*h^14,
#  u_2*u_3*v_3*h^11 - 2021*u_2^2*h^12 + 2682*u_1*u_3*h^12 + 1893*u_2*u_3*h^12 - 3203*u_3^2*h^12 + 2553*u_2*v_1*h^12 + 1193*u_3*v_1*h^12 - 4065*v_1^2*h^12 + 2304*u_1*v_2*h^12 - 2308*u_2*v_2*h^12 - 3971*u_3*v_2*h^12 + 2559*v_1*v_2*h^12 + 2768*v_2^2*h^12 - 3860*u_1*v_3*h^12 - 4052*u_2*v_3*h^12 - 47*u_3*v_3*h^12 + 2230*v_1*v_3*h^12 - 966*v_2*v_3*h^12 - 870*v_3^2*h^12 + 3317*u_2*y*h^12 + 4322*u_3*y*h^12 - 4864*v_1*y*h^12 + 3044*v_2*y*h^12 + 128*v_3*y*h^12 - 292*u_1*h^13 + 63*u_2*h^13 + 2324*u_3*h^13 - 4974*v_1*h^13 + 3412*v_2*h^13 + 3306*v_3*h^13 - 2595*y*h^13 + 3852*h^14,
#  u_3^2*v_3*h^11 + 2025*u_2^2*h^12 - 1270*u_1*u_3*h^12 - 3931*u_2*u_3*h^12 - 2254*u_3^2*h^12 - 3231*u_2*v_1*h^12 - 365*u_3*v_1*h^12 - 1033*v_1^2*h^12 - 808*u_1*v_2*h^12 - 3808*u_2*v_2*h^12 + 3080*u_3*v_2*h^12 + 1756*v_1*v_2*h^12 - 978*v_2^2*h^12 + 518*u_1*v_3*h^12 + 1171*u_2*v_3*h^12 - 3752*u_3*v_3*h^12 + 1664*v_1*v_3*h^12 - 2742*v_2*v_3*h^12 - 78*v_3^2*h^12 + 1327*u_2*y*h^12 + 2485*u_3*y*h^12 + 2316*v_1*y*h^12 - 1960*v_2*y*h^12 + 617*v_3*y*h^12 + 4618*u_1*h^13 - 134*u_2*h^13 + 4044*u_3*h^13 - 83*v_1*h^13 + 1669*v_2*h^13 - 4328*v_3*h^13 - 3276*y*h^13 - 115*h^14,
#  u_3*v_1*v_3*h^11 - 3*u_2^2*h^12 + 2394*u_1*u_3*h^12 - 4204*u_2*u_3*h^12 + 305*u_3^2*h^12 - 1686*u_2*v_1*h^12 - 473*u_3*v_1*h^12 + 1072*v_1^2*h^12 - 166*u_1*v_2*h^12 - 1860*u_2*v_2*h^12 + 2657*u_3*v_2*h^12 - 2376*v_1*v_2*h^12 - 3903*v_2^2*h^12 - 4819*u_1*v_3*h^12 + 88*u_2*v_3*h^12 + 2152*u_3*v_3*h^12 - 1248*v_1*v_3*h^12 + 2203*v_2*v_3*h^12 + 679*v_3^2*h^12 + 399*u_2*y*h^12 - 3112*u_3*y*h^12 - 3636*v_1*y*h^12 + 2789*v_2*y*h^12 + 4699*v_3*y*h^12 - 339*u_1*h^13 + 3869*u_2*h^13 + 4308*u_3*h^13 + 3966*v_1*h^13 - 310*v_2*h^13 + 1316*v_3*h^13 - 277*y*h^13 + 2460*h^14,
#  u_1*v_2*v_3*h^11 + 1702*u_2^2*h^12 - 2555*u_1*u_3*h^12 - 3788*u_2*u_3*h^12 + 465*u_3^2*h^12 + 1857*u_2*v_1*h^12 + 2018*u_3*v_1*h^12 - 3698*v_1^2*h^12 + 2194*u_1*v_2*h^12 + 973*u_2*v_2*h^12 + 1509*u_3*v_2*h^12 + 3051*v_1*v_2*h^12 - 4397*v_2^2*h^12 - 4490*u_1*v_3*h^12 + 2311*u_2*v_3*h^12 - 1799*u_3*v_3*h^12 + 2304*v_1*v_3*h^12 - 4632*v_2*v_3*h^12 + 2941*v_3^2*h^12 + 2717*u_2*y*h^12 - 3343*u_3*y*h^12 - 4164*v_1*y*h^12 - 2137*v_2*y*h^12 + 1892*v_3*y*h^12 - 2064*u_1*h^13 - 329*u_2*h^13 - 88*u_3*h^13 - 3603*v_1*h^13 - 3500*v_2*h^13 + 3815*v_3*h^13 - 1820*y*h^13 - 3548*h^14,
#  u_2*v_2*v_3*h^11 + 897*u_2^2*h^12 + 4004*u_1*u_3*h^12 + 4864*u_2*u_3*h^12 + 4120*u_3^2*h^12 - 219*u_2*v_1*h^12 - 2390*u_3*v_1*h^12 + 3742*v_1^2*h^12 + 2792*u_1*v_2*h^12 + 1446*u_2*v_2*h^12 - 85*u_3*v_2*h^12 + 1914*v_1*v_2*h^12 + 272*v_2^2*h^12 + 3191*u_1*v_3*h^12 + 1208*u_2*v_3*h^12 - 2298*u_3*v_3*h^12 + 3652*v_1*v_3*h^12 - 4911*v_2*v_3*h^12 - 1935*v_3^2*h^12 - 3184*u_2*y*h^12 + 3118*u_3*y*h^12 + 4285*v_1*y*h^12 + 3750*v_2*y*h^12 - 16*v_3*y*h^12 + 94*u_1*h^13 - 1095*u_2*h^13 + 3803*u_3*h^13 + 4863*v_1*h^13 + 3653*v_2*h^13 - 2284*v_3*h^13 + 79*y*h^13 - 2642*h^14,
#  u_3*v_2*v_3*h^11 - 3737*u_2^2*h^12 - 4644*u_1*u_3*h^12 + 3766*u_2*u_3*h^12 - 4769*u_3^2*h^12 - 458*u_2*v_1*h^12 - 4873*u_3*v_1*h^12 + 1360*v_1^2*h^12 + 2078*u_1*v_2*h^12 - 207*u_2*v_2*h^12 + 3152*u_3*v_2*h^12 - 1048*v_1*v_2*h^12 - 378*v_2^2*h^12 - 3545*u_1*v_3*h^12 - 29*u_2*v_3*h^12 + 3715*u_3*v_3*h^12 + 1669*v_1*v_3*h^12 + 2830*v_2*v_3*h^12 - 4419*v_3^2*h^12 - 1568*u_2*y*h^12 - 2531*u_3*y*h^12 - 1938*v_1*y*h^12 - 2392*v_2*y*h^12 + 1037*v_3*y*h^12 - 3307*u_1*h^13 + 4034*u_2*h^13 + 4884*u_3*h^13 - 724*v_1*h^13 + 206*v_2*h^13 - 2713*v_3*h^13 + 4664*y*h^13 + 501*h^14,
#  v_1*v_2*v_3*h^11 - 4321*u_2^2*h^12 + 4329*u_1*u_3*h^12 - 1003*u_2*u_3*h^12 - 4726*u_3^2*h^12 + 1112*u_2*v_1*h^12 - 3909*u_3*v_1*h^12 + 618*v_1^2*h^12 + 1265*u_1*v_2*h^12 - 3199*u_2*v_2*h^12 - 896*u_3*v_2*h^12 + 1842*v_1*v_2*h^12 + 1160*v_2^2*h^12 + 3847*u_1*v_3*h^12 + 2071*u_2*v_3*h^12 + 4985*u_3*v_3*h^12 - 1566*v_1*v_3*h^12 - 1787*v_2*v_3*h^12 - 3681*v_3^2*h^12 - 2472*u_2*y*h^12 - 3000*u_3*y*h^12 - 257*v_1*y*h^12 + 3802*v_2*y*h^12 + 4266*v_3*y*h^12 + 2431*u_1*h^13 + 2801*u_2*h^13 + 343*u_3*h^13 - 2855*v_1*h^13 - 4367*v_2*h^13 + 1202*v_3*h^13 - 387*y*h^13 - 611*h^14,
#  v_2^2*v_3*h^11 + 3432*u_2^2*h^12 - 4525*u_1*u_3*h^12 + 4159*u_2*u_3*h^12 - 31*u_3^2*h^12 - 2911*u_2*v_1*h^12 + 3716*u_3*v_1*h^12 + 977*v_1^2*h^12 + 1908*u_1*v_2*h^12 + 3315*u_2*v_2*h^12 - 2769*u_3*v_2*h^12 + 2073*v_1*v_2*h^12 + 3564*v_2^2*h^12 - 4919*u_1*v_3*h^12 + 560*u_2*v_3*h^12 + 1047*u_3*v_3*h^12 - 940*v_1*v_3*h^12 - 413*v_2*v_3*h^12 + 4328*v_3^2*h^12 - 4316*u_2*y*h^12 - 1654*u_3*y*h^12 - 2513*v_1*y*h^12 - 3040*v_2*y*h^12 - 2540*v_3*y*h^12 - 2238*u_1*h^13 - 3142*u_2*h^13 - 4850*u_3*h^13 + 158*v_1*h^13 + 2553*v_2*h^13 + 814*v_3*h^13 + 4914*y*h^13 - 3834*h^14,
#  u_1*v_3^2*h^11 - 279*u_2^2*h^12 - 2521*u_1*u_3*h^12 + 3916*u_2*u_3*h^12 - 4355*u_3^2*h^12 + 314*u_2*v_1*h^12 - 228*u_3*v_1*h^12 - 3951*v_1^2*h^12 - 3344*u_1*v_2*h^12 - 4633*u_2*v_2*h^12 - 709*u_3*v_2*h^12 + 3235*v_1*v_2*h^12 - 887*v_2^2*h^12 - 2640*u_1*v_3*h^12 + 580*u_2*v_3*h^12 + 3012*u_3*v_3*h^12 + 2052*v_1*v_3*h^12 - 3533*v_2*v_3*h^12 - 3833*v_3^2*h^12 + 3981*u_2*y*h^12 + 3471*u_3*y*h^12 - 2250*v_1*y*h^12 + 3151*v_2*y*h^12 + 1434*v_3*y*h^12 + 1332*u_1*h^13 + 1958*u_2*h^13 + 4577*u_3*h^13 + 3112*v_1*h^13 + 2436*v_2*h^13 + 2098*v_3*h^13 + 2065*y*h^13 + 2783*h^14,
#  u_2*v_3^2*h^11 + 3535*u_2^2*h^12 - 3993*u_1*u_3*h^12 + 170*u_2*u_3*h^12 - 3418*u_3^2*h^12 + 2125*u_2*v_1*h^12 - 24*u_3*v_1*h^12 + 1316*v_1^2*h^12 - 2104*u_1*v_2*h^12 - 3841*u_2*v_2*h^12 - 3940*u_3*v_2*h^12 - 4485*v_1*v_2*h^12 - 4954*v_2^2*h^12 - 1645*u_1*v_3*h^12 - 3267*u_2*v_3*h^12 + 2512*u_3*v_3*h^12 - 4565*v_1*v_3*h^12 - 1697*v_2*v_3*h^12 + 326*v_3^2*h^12 - 3423*u_2*y*h^12 + 1008*u_3*y*h^12 - 3217*v_1*y*h^12 + 575*v_2*y*h^12 - 1430*v_3*y*h^12 + 1158*u_1*h^13 - 3415*u_2*h^13 + 965*u_3*h^13 - 232*v_1*h^13 - 270*v_2*h^13 + 3329*v_3*h^13 + 4260*y*h^13 + 2399*h^14,
#  u_3*v_3^2*h^11 - 2692*u_2^2*h^12 + 1881*u_1*u_3*h^12 - 1962*u_2*u_3*h^12 - 984*u_3^2*h^12 + 813*u_2*v_1*h^12 + 959*u_3*v_1*h^12 - 1342*v_1^2*h^12 + 2942*u_1*v_2*h^12 + 2341*u_2*v_2*h^12 - 4057*u_3*v_2*h^12 + 4321*v_1*v_2*h^12 + 1436*v_2^2*h^12 + 3616*u_1*v_3*h^12 + 2375*u_2*v_3*h^12 + 2375*u_3*v_3*h^12 - 807*v_1*v_3*h^12 + 3146*v_2*v_3*h^12 - 4459*v_3^2*h^12 - 564*u_2*y*h^12 + 2931*u_3*y*h^12 - 1894*v_1*y*h^12 + 2781*v_2*y*h^12 + 3717*v_3*y*h^12 - 4405*u_1*h^13 - 441*u_2*h^13 + 3511*u_3*h^13 + 3697*v_1*h^13 - 39*v_2*h^13 + 2510*v_3*h^13 + 2314*y*h^13 + 3130*h^14,
#  v_1*v_3^2*h^11 - 1064*u_2^2*h^12 + 3412*u_1*u_3*h^12 + 3645*u_2*u_3*h^12 + 1658*u_3^2*h^12 - 3330*u_2*v_1*h^12 - 680*u_3*v_1*h^12 + 1981*v_1^2*h^12 + 4784*u_1*v_2*h^12 + 2645*u_2*v_2*h^12 - 2835*u_3*v_2*h^12 + 1398*v_1*v_2*h^12 - 1157*v_2^2*h^12 - 467*u_1*v_3*h^12 - 4367*u_2*v_3*h^12 - 2200*u_3*v_3*h^12 - 1464*v_1*v_3*h^12 + 1955*v_2*v_3*h^12 + 1031*v_3^2*h^12 - 3526*u_2*y*h^12 + 3092*u_3*y*h^12 - 3861*v_1*y*h^12 - 709*v_2*y*h^12 - 452*v_3*y*h^12 + 660*u_1*h^13 - 919*u_2*h^13 + 1079*u_3*h^13 + 4173*v_1*h^13 + 3142*v_2*h^13 - 4072*v_3*h^13 - 679*y*h^13 + 2009*h^14,
#  v_2*v_3^2*h^11 - 4586*u_2^2*h^12 + 4651*u_1*u_3*h^12 - 2477*u_2*u_3*h^12 - 3188*u_3^2*h^12 - 2380*u_2*v_1*h^12 - 2536*u_3*v_1*h^12 - 1649*v_1^2*h^12 - 220*u_1*v_2*h^12 - 3800*u_2*v_2*h^12 - 4388*u_3*v_2*h^12 + 2889*v_1*v_2*h^12 - 2660*v_2^2*h^12 + 303*u_1*v_3*h^12 + 1848*u_2*v_3*h^12 + 4955*u_3*v_3*h^12 + 87*v_1*v_3*h^12 + 843*v_2*v_3*h^12 - 2147*v_3^2*h^12 - 2869*u_2*y*h^12 + 2685*u_3*y*h^12 - 1917*v_1*y*h^12 + 76*v_2*y*h^12 - 1249*v_3*y*h^12 + 2712*u_1*h^13 - 1960*u_2*h^13 - 2812*u_3*h^13 + 2656*v_1*h^13 - 4569*v_2*h^13 - 2498*v_3*h^13 - 2412*y*h^13 + 325*h^14,
#  u_2^2*y*h^11 - 4835*u_2^2*h^12 - 908*u_1*u_3*h^12 + 4355*u_2*u_3*h^12 - 4882*u_3^2*h^12 + 222*u_2*v_1*h^12 + 3453*u_3*v_1*h^12 - 2520*v_1^2*h^12 - 666*u_1*v_2*h^12 + 2770*u_2*v_2*h^12 + 4816*u_3*v_2*h^12 - 908*v_1*v_2*h^12 - 1708*v_2^2*h^12 + 3092*u_1*v_3*h^12 + 3068*u_2*v_3*h^12 + 3359*u_3*v_3*h^12 + 4014*v_1*v_3*h^12 - 3982*v_2*v_3*h^12 - 3403*v_3^2*h^12 - 1499*u_2*y*h^12 - 4943*u_3*y*h^12 + 755*v_1*y*h^12 - 3374*v_2*y*h^12 - 4406*v_3*y*h^12 + 2102*u_1*h^13 - 428*u_2*h^13 - 3830*u_3*h^13 - 1989*v_1*h^13 - 4706*v_2*h^13 + 26*v_3*h^13 - 599*y*h^13 + 114*h^14,
#  u_2*u_3*y*h^11 + 4888*u_2^2*h^12 + 3164*u_1*u_3*h^12 + 494*u_2*u_3*h^12 + 2316*u_3^2*h^12 + 2838*u_2*v_1*h^12 + 1210*u_3*v_1*h^12 + 1754*v_1^2*h^12 - 2826*u_1*v_2*h^12 + 2684*u_2*v_2*h^12 + 4490*u_3*v_2*h^12 + 1851*v_1*v_2*h^12 - 1547*v_2^2*h^12 - 121*u_1*v_3*h^12 - 3424*u_2*v_3*h^12 - 879*u_3*v_3*h^12 - 2822*v_1*v_3*h^12 - 1405*v_2*v_3*h^12 + 3104*v_3^2*h^12 - 1238*u_2*y*h^12 - 2767*u_3*y*h^12 - 2454*v_1*y*h^12 - 4909*v_2*y*h^12 - 3158*v_3*y*h^12 + 4265*u_1*h^13 + 456*u_2*h^13 - 360*u_3*h^13 + 3635*v_1*h^13 - 2149*v_2*h^13 + 159*v_3*h^13 - 672*y*h^13 + 97*h^14,
#  u_3^2*y*h^11 + 2733*u_2^2*h^12 - 631*u_1*u_3*h^12 - 4501*u_2*u_3*h^12 + 3039*u_3^2*h^12 + 3880*u_2*v_1*h^12 + 2004*u_3*v_1*h^12 + 362*v_1^2*h^12 - 2576*u_1*v_2*h^12 + 2440*u_2*v_2*h^12 - 2226*u_3*v_2*h^12 - 1055*v_1*v_2*h^12 - 4603*v_2^2*h^12 + 456*u_1*v_3*h^12 + 249*u_2*v_3*h^12 + 2206*u_3*v_3*h^12 - 2514*v_1*v_3*h^12 + 673*v_2*v_3*h^12 - 425*v_3^2*h^12 + 3831*u_2*y*h^12 - 169*u_3*y*h^12 - 3235*v_1*y*h^12 + 1206*v_2*y*h^12 + 3446*v_3*y*h^12 + 4068*u_1*h^13 + 4472*u_2*h^13 - 4853*u_3*h^13 + 3569*v_1*h^13 + 3925*v_2*h^13 + 3654*v_3*h^13 - 1884*y*h^13 + 3439*h^14,
#  u_3*v_1*y*h^11 + 3547*u_2^2*h^12 + 3274*u_1*u_3*h^12 - 3303*u_2*u_3*h^12 + 4377*u_3^2*h^12 + 2830*u_2*v_1*h^12 + 869*u_3*v_1*h^12 - 1308*v_1^2*h^12 - 878*u_1*v_2*h^12 + 170*u_2*v_2*h^12 + 4281*u_3*v_2*h^12 + 3612*v_1*v_2*h^12 + 3720*v_2^2*h^12 - 843*u_1*v_3*h^12 - 1613*u_2*v_3*h^12 - 2031*u_3*v_3*h^12 + 4342*v_1*v_3*h^12 + 2052*v_2*v_3*h^12 + 1033*v_3^2*h^12 + 2559*u_2*y*h^12 + 2383*u_3*y*h^12 + 3328*v_1*y*h^12 + 1591*v_2*y*h^12 - 2181*v_3*y*h^12 + 4674*u_1*h^13 + 4804*u_2*h^13 + 3665*u_3*h^13 + 1497*v_1*h^13 + 2388*v_2*h^13 - 840*v_3*h^13 - 1416*y*h^13 + 1264*h^14,
#  u_2*v_2*y*h^11 - 1514*u_2^2*h^12 + 4936*u_1*u_3*h^12 - 2329*u_2*u_3*h^12 - 2510*u_3^2*h^12 - 4680*u_2*v_1*h^12 - 2751*u_3*v_1*h^12 - 1048*v_1^2*h^12 - 2252*u_1*v_2*h^12 + 3159*u_2*v_2*h^12 - 2738*u_3*v_2*h^12 - 1728*v_1*v_2*h^12 - 2570*v_2^2*h^12 - 373*u_1*v_3*h^12 - 1554*u_2*v_3*h^12 - 3569*u_3*v_3*h^12 + 3216*v_1*v_3*h^12 - 3580*v_2*v_3*h^12 + 2236*v_3^2*h^12 - 4626*u_2*y*h^12 - 2762*u_3*y*h^12 + 1276*v_1*y*h^12 - 964*v_2*y*h^12 + 3797*v_3*y*h^12 - 3835*u_1*h^13 - 2201*u_2*h^13 - 3051*u_3*h^13 - 4432*v_1*h^13 + 4109*v_2*h^13 - 2474*v_3*h^13 - 4284*y*h^13 - 3967*h^14,
#  u_3*v_2*y*h^11 + 77*u_2^2*h^12 - 1534*u_1*u_3*h^12 - 290*u_2*u_3*h^12 + 1149*u_3^2*h^12 + 917*u_2*v_1*h^12 - 2765*u_3*v_1*h^12 - 605*v_1^2*h^12 + 1830*u_1*v_2*h^12 - 1573*u_2*v_2*h^12 + 2252*u_3*v_2*h^12 + 4414*v_1*v_2*h^12 + 3233*v_2^2*h^12 + 4826*u_1*v_3*h^12 - 2825*u_2*v_3*h^12 + 2571*u_3*v_3*h^12 + 1737*v_1*v_3*h^12 + 3339*v_2*v_3*h^12 + 657*v_3^2*h^12 - 4395*u_2*y*h^12 - 2495*u_3*y*h^12 + 2701*v_1*y*h^12 - 4704*v_2*y*h^12 - 3754*v_3*y*h^12 - 3079*u_1*h^13 - 2608*u_2*h^13 - 1067*u_3*h^13 + 2260*v_1*h^13 + 4790*v_2*h^13 - 2724*v_3*h^13 - 2086*y*h^13 + 44*h^14,
#  v_1*v_2*y*h^11 - 2318*u_2^2*h^12 - 1083*u_1*u_3*h^12 - 433*u_2*u_3*h^12 + 1137*u_3^2*h^12 - 4732*u_2*v_1*h^12 + 2261*u_3*v_1*h^12 - 2744*v_1^2*h^12 - 3618*u_1*v_2*h^12 + 3366*u_2*v_2*h^12 + 1649*u_3*v_2*h^12 - 3500*v_1*v_2*h^12 - 2888*v_2^2*h^12 - 2603*u_1*v_3*h^12 - 1381*u_2*v_3*h^12 + 4155*u_3*v_3*h^12 - 4893*v_1*v_3*h^12 - 2379*v_2*v_3*h^12 - 3246*v_3^2*h^12 - 2120*u_2*y*h^12 - 3414*u_3*y*h^12 - 3106*v_1*y*h^12 + 3745*v_2*y*h^12 + 1455*v_3*y*h^12 + 1186*u_1*h^13 + 3198*u_2*h^13 - 2100*u_3*h^13 + 4968*v_1*h^13 + 2620*v_2*h^13 + 4024*v_3*h^13 - 3361*y*h^13 + 629*h^14,
#  v_2^2*y*h^11 - 1738*u_2^2*h^12 - 3484*u_1*u_3*h^12 + 966*u_2*u_3*h^12 + 2898*u_3^2*h^12 - 2857*u_2*v_1*h^12 + 413*u_3*v_1*h^12 - 1266*v_1^2*h^12 + 1227*u_1*v_2*h^12 - 1341*u_2*v_2*h^12 + 4606*u_3*v_2*h^12 - 1693*v_1*v_2*h^12 + 1607*v_2^2*h^12 - 26*u_1*v_3*h^12 - 707*u_2*v_3*h^12 - 4013*u_3*v_3*h^12 + 1129*v_1*v_3*h^12 + 3698*v_2*v_3*h^12 + 4261*v_3^2*h^12 + 2770*u_2*y*h^12 + 1086*u_3*y*h^12 + 26*v_1*y*h^12 + 3997*v_2*y*h^12 - 4793*v_3*y*h^12 + 491*u_1*h^13 + 2111*u_2*h^13 - 3208*u_3*h^13 + 1623*v_1*h^13 - 2378*v_2*h^13 - 4603*v_3*h^13 - 10*y*h^13 - 2383*h^14,
#  u_2*v_3*y*h^11 - 4670*u_2^2*h^12 - 4704*u_1*u_3*h^12 - 778*u_2*u_3*h^12 + 1502*u_3^2*h^12 + 4618*u_2*v_1*h^12 + 2262*u_3*v_1*h^12 - 1902*v_1^2*h^12 - 3552*u_1*v_2*h^12 - 3348*u_2*v_2*h^12 + 3308*u_3*v_2*h^12 + 1308*v_1*v_2*h^12 + 2435*v_2^2*h^12 - 4265*u_1*v_3*h^12 + 3939*u_2*v_3*h^12 - 4885*u_3*v_3*h^12 + 3008*v_1*v_3*h^12 + 1509*v_2*v_3*h^12 + 476*v_3^2*h^12 + 2908*u_2*y*h^12 + 3229*u_3*y*h^12 - 4874*v_1*y*h^12 - 59*v_2*y*h^12 - 3023*v_3*y*h^12 + 795*u_1*h^13 + 2517*u_2*h^13 + 2829*u_3*h^13 + 2777*v_1*h^13 + 101*v_2*h^13 - 292*v_3*h^13 - 2155*y*h^13 - 4159*h^14,
#  u_3*v_3*y*h^11 + 1284*u_2^2*h^12 - 4293*u_1*u_3*h^12 - 62*u_2*u_3*h^12 + 3755*u_3^2*h^12 + 33*u_2*v_1*h^12 + 2572*u_3*v_1*h^12 + 1967*v_1^2*h^12 + 380*u_1*v_2*h^12 + 1290*u_2*v_2*h^12 + 3139*u_3*v_2*h^12 + 1237*v_1*v_2*h^12 + 661*v_2^2*h^12 + 3907*u_1*v_3*h^12 - 3758*u_2*v_3*h^12 + 1999*u_3*v_3*h^12 + 3848*v_1*v_3*h^12 + 1098*v_2*v_3*h^12 - 2311*v_3^2*h^12 - 1034*u_2*y*h^12 - 2804*u_3*y*h^12 + 1217*v_1*y*h^12 - 3650*v_2*y*h^12 + 4636*v_3*y*h^12 - 825*u_1*h^13 - 2949*u_2*h^13 + 3268*u_3*h^13 + 144*v_1*h^13 - 2183*v_2*h^13 - 4048*v_3*h^13 - 939*y*h^13 + 528*h^14,
#  v_1*v_3*y*h^11 - 3484*u_2^2*h^12 + 1700*u_1*u_3*h^12 - 1364*u_2*u_3*h^12 - 3668*u_3^2*h^12 - 1909*u_2*v_1*h^12 + 1930*u_3*v_1*h^12 + 4162*v_1^2*h^12 - 3231*u_1*v_2*h^12 + 4651*u_2*v_2*h^12 - 1791*u_3*v_2*h^12 - 413*v_1*v_2*h^12 + 2740*v_2^2*h^12 + 547*u_1*v_3*h^12 + 4575*u_2*v_3*h^12 - 1349*u_3*v_3*h^12 + 1819*v_1*v_3*h^12 - 1424*v_2*v_3*h^12 - 1931*v_3^2*h^12 - 2874*u_2*y*h^12 + 1938*u_3*y*h^12 - 2264*v_1*y*h^12 + 2688*v_2*y*h^12 + 1741*v_3*y*h^12 - 1966*u_1*h^13 - 2899*u_2*h^13 - 2908*u_3*h^13 + 2230*v_1*h^13 - 1203*v_2*h^13 - 4155*v_3*h^13 + 4994*y*h^13 - 1469*h^14,
#  v_2*v_3*y*h^11 - 1270*u_2^2*h^12 + 2204*u_1*u_3*h^12 - 4242*u_2*u_3*h^12 - 2149*u_3^2*h^12 - 1957*u_2*v_1*h^12 + 2639*u_3*v_1*h^12 + 935*v_1^2*h^12 - 3053*u_1*v_2*h^12 - 3887*u_2*v_2*h^12 + 914*u_3*v_2*h^12 + 1679*v_1*v_2*h^12 + 538*v_2^2*h^12 + 2488*u_1*v_3*h^12 + 2834*u_2*v_3*h^12 - 2791*u_3*v_3*h^12 - 4861*v_1*v_3*h^12 + 1343*v_2*v_3*h^12 + 1737*v_3^2*h^12 + 2582*u_2*y*h^12 + 1900*u_3*y*h^12 + 1082*v_1*y*h^12 - 4828*v_2*y*h^12 - 3807*v_3*y*h^12 - 2706*u_1*h^13 - 4877*u_2*h^13 + 4091*u_3*h^13 - 4557*v_1*h^13 - 1925*v_2*h^13 - 481*v_3*h^13 - 3364*y*h^13 - 3858*h^14,
#  v_3^2*y*h^11 + 3800*u_2^2*h^12 + 2953*u_1*u_3*h^12 - 1305*u_2*u_3*h^12 + 2751*u_3^2*h^12 - 3249*u_2*v_1*h^12 + 1277*u_3*v_1*h^12 - 284*v_1^2*h^12 - 1305*u_1*v_2*h^12 + 882*u_2*v_2*h^12 - 2038*u_3*v_2*h^12 + 2141*v_1*v_2*h^12 - 4978*v_2^2*h^12 + 4563*u_1*v_3*h^12 + 3930*u_2*v_3*h^12 + 234*u_3*v_3*h^12 + 611*v_1*v_3*h^12 + 4095*v_2*v_3*h^12 + 1177*v_3^2*h^12 + 604*u_2*y*h^12 - 3594*u_3*y*h^12 + 2574*v_1*y*h^12 - 941*v_2*y*h^12 + 71*v_3*y*h^12 + 246*u_1*h^13 - 2270*u_2*h^13 - 4375*u_3*h^13 + 1898*v_1*h^13 + 3215*v_2*h^13 + 3156*v_3*h^13 + 851*y*h^13 - 900*h^14,
#  u_2^2*u_3^2*v_3*h^8 - 665*u_2^2*u_3*h^10 + 449*u_1*u_3^2*h^10 + 3926*u_2*u_3^2*h^10 - 1998*u_3^2*v_1*h^10 + 494*u_2*u_3*v_2*h^10 + 4935*u_3^2*v_2*h^10 + 778*u_3*v_2^2*h^10 + 3838*u_2^2*v_3*h^10 - 3334*u_1*u_3*v_3*h^10 - 1138*u_2*u_3*v_3*h^10 - 4061*u_3^2*v_3*h^10 - 2980*u_3*v_1*v_3*h^10 - 1330*u_1*v_2*v_3*h^10 - 19*u_2*v_2*v_3*h^10 - 1900*u_3*v_2*v_3*h^10 + 100*v_1*v_2*v_3*h^10 - 3546*v_2^2*v_3*h^10 + 55*u_1*v_3^2*h^10 + 2951*u_2*v_3^2*h^10 - 3764*u_3*v_3^2*h^10 - 1575*v_1*v_3^2*h^10 + 4330*v_2*v_3^2*h^10 - 1990*u_2^2*y*h^10 - 3593*u_2*u_3*y*h^10 - 1218*u_3^2*y*h^10 + 1339*u_3*v_1*y*h^10 - 589*u_2*v_2*y*h^10 - 4621*u_3*v_2*y*h^10 - 358*v_1*v_2*y*h^10 + 381*v_2^2*y*h^10 + 1140*u_2*v_3*y*h^10 - 1839*u_3*v_3*y*h^10 - 175*v_1*v_3*y*h^10 - 1893*v_2*v_3*y*h^10 - 1960*v_3^2*y*h^10 - 2053*u_2^2*h^11 + 4552*u_1*u_3*h^11 + 3029*u_2*u_3*h^11 + 3529*u_3^2*h^11 + 1421*u_2*v_1*h^11 + 1006*u_3*v_1*h^11 - 3606*v_1^2*h^11 - 2319*u_1*v_2*h^11 + 3757*u_2*v_2*h^11 + 4802*u_3*v_2*h^11 - 4920*v_1*v_2*h^11 + 2507*v_2^2*h^11 + 1872*u_1*v_3*h^11 - 1358*u_2*v_3*h^11 - 3792*u_3*v_3*h^11 + 3008*v_1*v_3*h^11 - 2783*v_2*v_3*h^11 + 2060*v_3^2*h^11 + 2480*u_2*y*h^11 - 3332*u_3*y*h^11 - 4514*v_1*y*h^11 - 3888*v_2*y*h^11 + 543*v_3*y*h^11 - 1564*u_1*h^12 - 348*u_2*h^12 - 2076*u_3*h^12 + 2763*v_1*h^12 - 4097*v_2*h^12 + 1359*v_3*h^12 - 4595*y*h^12 + 3054*h^13,
#  u_2*u_3^2*v_2*v_3*h^8 + 1834*u_2^2*u_3*h^10 - 4735*u_1*u_3^2*h^10 - 4477*u_2*u_3^2*h^10 + 3043*u_3^2*v_1*h^10 - 4902*u_2*u_3*v_2*h^10 + 1217*u_3^2*v_2*h^10 - 3426*u_3*v_2^2*h^10 + 2428*u_2^2*v_3*h^10 - 3494*u_1*u_3*v_3*h^10 + 3740*u_2*u_3*v_3*h^10 - 302*u_3^2*v_3*h^10 - 2611*u_3*v_1*v_3*h^10 - 4985*u_1*v_2*v_3*h^10 + 4325*u_2*v_2*v_3*h^10 - 3259*u_3*v_2*v_3*h^10 - 908*v_1*v_2*v_3*h^10 + 4882*v_2^2*v_3*h^10 - 2395*u_1*v_3^2*h^10 - 4792*u_2*v_3^2*h^10 + 2032*u_3*v_3^2*h^10 - 4714*v_1*v_3^2*h^10 - 4185*v_2*v_3^2*h^10 - 1561*u_2^2*y*h^10 - 4768*u_2*u_3*y*h^10 + 3478*u_3^2*y*h^10 - 2599*u_3*v_1*y*h^10 - 3594*u_2*v_2*y*h^10 + 117*u_3*v_2*y*h^10 - 2274*v_1*v_2*y*h^10 - 4195*v_2^2*y*h^10 + 869*u_2*v_3*y*h^10 - 3559*u_3*v_3*y*h^10 - 4494*v_1*v_3*y*h^10 - 3995*v_2*v_3*y*h^10 - 2400*v_3^2*y*h^10 + 4407*u_2^2*h^11 + 958*u_1*u_3*h^11 + 3392*u_2*u_3*h^11 - 966*u_3^2*h^11 + 1112*u_2*v_1*h^11 - 287*u_3*v_1*h^11 + 20*v_1^2*h^11 - 648*u_1*v_2*h^11 - 2714*u_2*v_2*h^11 - 3843*u_3*v_2*h^11 - 3329*v_1*v_2*h^11 - 4562*v_2^2*h^11 - 4632*u_1*v_3*h^11 - 4417*u_2*v_3*h^11 + 4389*u_3*v_3*h^11 + 2637*v_1*v_3*h^11 - 2392*v_2*v_3*h^11 - 3780*v_3^2*h^11 - 4840*u_2*y*h^11 - 257*u_3*y*h^11 - 1797*v_1*y*h^11 + 3958*v_2*y*h^11 + 3711*v_3*y*h^11 + 3582*u_1*h^12 + 1470*u_2*h^12 - 4434*u_3*h^12 + 2425*v_1*h^12 - 3320*v_2*h^12 - 1599*v_3*h^12 + 2480*y*h^12 + 1496*h^13,
#  u_3^2*v_2^2*v_3*h^8 - 3409*u_2^2*u_3*h^10 - 4028*u_1*u_3^2*h^10 + 4879*u_2*u_3^2*h^10 + 1438*u_3^2*v_1*h^10 + 3733*u_2*u_3*v_2*h^10 - 3477*u_3^2*v_2*h^10 - 2420*u_3*v_2^2*h^10 - 1632*u_2^2*v_3*h^10 + 3882*u_1*u_3*v_3*h^10 - 3217*u_2*u_3*v_3*h^10 - 197*u_3^2*v_3*h^10 - 1941*u_3*v_1*v_3*h^10 - 1773*u_1*v_2*v_3*h^10 - 3310*u_2*v_2*v_3*h^10 - 3597*u_3*v_2*v_3*h^10 + 1594*v_1*v_2*v_3*h^10 - 3535*v_2^2*v_3*h^10 + 288*u_1*v_3^2*h^10 - 2347*u_2*v_3^2*h^10 - 2834*u_3*v_3^2*h^10 - 4253*v_1*v_3^2*h^10 + 589*v_2*v_3^2*h^10 + 4557*u_2^2*y*h^10 + 1401*u_2*u_3*y*h^10 - 3104*u_3^2*y*h^10 + 4902*u_3*v_1*y*h^10 - 2936*u_2*v_2*y*h^10 - 2515*u_3*v_2*y*h^10 + 957*v_1*v_2*y*h^10 - 18*v_2^2*y*h^10 - 1611*u_2*v_3*y*h^10 - 3966*u_3*v_3*y*h^10 + 861*v_1*v_3*y*h^10 + 3760*v_2*v_3*y*h^10 - 4885*v_3^2*y*h^10 + 4924*u_2^2*h^11 + 4281*u_1*u_3*h^11 + 4355*u_2*u_3*h^11 - 1057*u_3^2*h^11 + 2550*u_2*v_1*h^11 + 1261*u_3*v_1*h^11 - 576*v_1^2*h^11 - 3879*u_1*v_2*h^11 - 1870*u_2*v_2*h^11 - 1191*u_3*v_2*h^11 - 3862*v_1*v_2*h^11 + 2068*v_2^2*h^11 + 35*u_1*v_3*h^11 - 1946*u_2*v_3*h^11 - 3407*u_3*v_3*h^11 - 3347*v_1*v_3*h^11 + 4157*v_2*v_3*h^11 + 4870*v_3^2*h^11 + 4396*u_2*y*h^11 - 1178*u_3*y*h^11 - 4463*v_1*y*h^11 - 1630*v_2*y*h^11 - 2896*v_3*y*h^11 - 94*u_1*h^12 + 2202*u_2*h^12 + 2829*u_3*h^12 + 3253*v_1*h^12 + 3780*v_2*h^12 + 1206*v_3*h^12 - 1421*y*h^12 + 3139*h^13,
#  u_2^2*u_3*v_3^2*h^8 - 1193*u_2^2*u_3*h^10 + 427*u_1*u_3^2*h^10 - 1105*u_2*u_3^2*h^10 + 2312*u_3^2*v_1*h^10 + 3566*u_2*u_3*v_2*h^10 - 4925*u_3^2*v_2*h^10 - 922*u_3*v_2^2*h^10 - 3240*u_2^2*v_3*h^10 + 1004*u_1*u_3*v_3*h^10 - 862*u_2*u_3*v_3*h^10 - 4549*u_3^2*v_3*h^10 + 4368*u_3*v_1*v_3*h^10 - 4720*u_1*v_2*v_3*h^10 - 3871*u_2*v_2*v_3*h^10 - 1501*u_3*v_2*v_3*h^10 - 2955*v_1*v_2*v_3*h^10 + 2557*v_2^2*v_3*h^10 + 2101*u_1*v_3^2*h^10 - 2472*u_2*v_3^2*h^10 - 4769*u_3*v_3^2*h^10 + 4504*v_1*v_3^2*h^10 + 3144*v_2*v_3^2*h^10 - 1910*u_2^2*y*h^10 - 591*u_2*u_3*y*h^10 - 2003*u_3^2*y*h^10 + 2547*u_3*v_1*y*h^10 - 928*u_2*v_2*y*h^10 + 4375*u_3*v_2*y*h^10 - 3321*v_1*v_2*y*h^10 - 2597*v_2^2*y*h^10 + 4684*u_2*v_3*y*h^10 - 4281*u_3*v_3*y*h^10 + 4610*v_1*v_3*y*h^10 + 4375*v_2*v_3*y*h^10 + 228*v_3^2*y*h^10 - 3846*u_2^2*h^11 + 756*u_1*u_3*h^11 + 306*u_2*u_3*h^11 + 2253*u_3^2*h^11 - 1906*u_2*v_1*h^11 + 3621*u_3*v_1*h^11 - 571*v_1^2*h^11 - 909*u_1*v_2*h^11 - 3922*u_2*v_2*h^11 + 50*u_3*v_2*h^11 + 3327*v_1*v_2*h^11 - 4552*v_2^2*h^11 - 4634*u_1*v_3*h^11 - 622*u_2*v_3*h^11 - 3010*u_3*v_3*h^11 + 2334*v_1*v_3*h^11 - 973*v_2*v_3*h^11 + 4951*v_3^2*h^11 + 3446*u_2*y*h^11 - 3449*u_3*y*h^11 - 1760*v_1*y*h^11 + 212*v_2*y*h^11 - 1108*v_3*y*h^11 - 2580*u_1*h^12 + 414*u_2*h^12 + 4858*u_3*h^12 - 3475*v_1*h^12 - 1534*v_2*h^12 + 4444*v_3*h^12 + 1434*y*h^12 - 2660*h^13,
#  u_1*u_3^2*v_3^2*h^8 - 2597*u_2^2*u_3*h^10 - 3850*u_1*u_3^2*h^10 + 1425*u_2*u_3^2*h^10 + 3291*u_3^2*v_1*h^10 + 3336*u_2*u_3*v_2*h^10 + 3404*u_3^2*v_2*h^10 + 188*u_3*v_2^2*h^10 + 119*u_2^2*v_3*h^10 + 4144*u_1*u_3*v_3*h^10 - 3240*u_2*u_3*v_3*h^10 + 967*u_3^2*v_3*h^10 - 596*u_3*v_1*v_3*h^10 + 2992*u_1*v_2*v_3*h^10 + 1768*u_2*v_2*v_3*h^10 + 94*u_3*v_2*v_3*h^10 + 3073*v_1*v_2*v_3*h^10 + 4227*v_2^2*v_3*h^10 - 200*u_1*v_3^2*h^10 - 2137*u_2*v_3^2*h^10 + 1250*u_3*v_3^2*h^10 + 1329*v_1*v_3^2*h^10 - 4789*v_2*v_3^2*h^10 - 466*u_2^2*y*h^10 + 1589*u_2*u_3*y*h^10 + 3532*u_3^2*y*h^10 - 3480*u_3*v_1*y*h^10 - 4419*u_2*v_2*y*h^10 + 840*u_3*v_2*y*h^10 - 3066*v_1*v_2*y*h^10 - 1537*v_2^2*y*h^10 + 2809*u_2*v_3*y*h^10 + 4269*u_3*v_3*y*h^10 - 1116*v_1*v_3*y*h^10 - 43*v_2*v_3*y*h^10 + 1897*v_3^2*y*h^10 + 1759*u_2^2*h^11 - 3916*u_1*u_3*h^11 + 1219*u_2*u_3*h^11 + 1087*u_3^2*h^11 + 939*u_2*v_1*h^11 + 4877*u_3*v_1*h^11 - 2255*v_1^2*h^11 + 832*u_1*v_2*h^11 - 4418*u_2*v_2*h^11 - 853*u_3*v_2*h^11 + 2442*v_1*v_2*h^11 - 605*v_2^2*h^11 + 4219*u_1*v_3*h^11 - 989*u_2*v_3*h^11 + 4549*u_3*v_3*h^11 + 4171*v_1*v_3*h^11 - 3627*v_2*v_3*h^11 + 4441*v_3^2*h^11 - 4131*u_2*y*h^11 + 242*u_3*y*h^11 + 4025*v_1*y*h^11 + 4116*v_2*y*h^11 - 1905*v_3*y*h^11 + 2708*u_1*h^12 - 2802*u_2*h^12 + 27*u_3*h^12 - 1704*v_1*h^12 + 4145*v_2*h^12 - 1716*v_3*h^12 + 140*y*h^12 + 10*h^13,
#  u_2*u_3^2*v_3^2*h^8 + 4340*u_2^2*u_3*h^10 - 2323*u_1*u_3^2*h^10 - 1669*u_2*u_3^2*h^10 + 629*u_3^2*v_1*h^10 + 2615*u_2*u_3*v_2*h^10 - 2717*u_3^2*v_2*h^10 + 4007*u_3*v_2^2*h^10 - 3751*u_2^2*v_3*h^10 - 299*u_1*u_3*v_3*h^10 + 4256*u_2*u_3*v_3*h^10 - 1960*u_3^2*v_3*h^10 + 4178*u_3*v_1*v_3*h^10 - 2463*u_1*v_2*v_3*h^10 - 70*u_2*v_2*v_3*h^10 - 3055*u_3*v_2*v_3*h^10 + 1954*v_1*v_2*v_3*h^10 + 2324*v_2^2*v_3*h^10 - 3807*u_1*v_3^2*h^10 - 921*u_2*v_3^2*h^10 - 1671*u_3*v_3^2*h^10 + 3810*v_1*v_3^2*h^10 + 651*v_2*v_3^2*h^10 - 3376*u_2^2*y*h^10 - 1110*u_2*u_3*y*h^10 + 756*u_3^2*y*h^10 - 4947*u_3*v_1*y*h^10 + 682*u_2*v_2*y*h^10 - 4940*u_3*v_2*y*h^10 + 2689*v_1*v_2*y*h^10 + 507*v_2^2*y*h^10 + 1514*u_2*v_3*y*h^10 - 1593*u_3*v_3*y*h^10 - 785*v_1*v_3*y*h^10 + 2361*v_2*v_3*y*h^10 - 816*v_3^2*y*h^10 - 135*u_2^2*h^11 - 120*u_1*u_3*h^11 + 1365*u_3^2*h^11 - 792*u_2*v_1*h^11 + 500*u_3*v_1*h^11 - 1154*v_1^2*h^11 - 4677*u_1*v_2*h^11 + 2578*u_2*v_2*h^11 - 4520*u_3*v_2*h^11 - 3515*v_1*v_2*h^11 + 4712*v_2^2*h^11 + 2353*u_1*v_3*h^11 - 379*u_2*v_3*h^11 + 1030*u_3*v_3*h^11 + 521*v_1*v_3*h^11 + 1133*v_2*v_3*h^11 + 2943*v_3^2*h^11 - 918*u_2*y*h^11 + 2717*u_3*y*h^11 - 1147*v_1*y*h^11 - 4015*v_2*y*h^11 + 2150*v_3*y*h^11 - 4845*u_1*h^12 + 4531*u_2*h^12 - 4712*u_3*h^12 + 1429*v_1*h^12 + 1625*v_2*h^12 - 1212*v_3*h^12 + 3852*y*h^12 - 3073*h^13,
#  u_3^2*v_1*v_3^2*h^8 + 72*u_2^2*u_3*h^10 - 219*u_1*u_3^2*h^10 - 1655*u_2*u_3^2*h^10 - 146*u_3^2*v_1*h^10 + 867*u_2*u_3*v_2*h^10 - 4336*u_3^2*v_2*h^10 + 3079*u_3*v_2^2*h^10 + 4042*u_2^2*v_3*h^10 + 4166*u_1*u_3*v_3*h^10 - 4817*u_2*u_3*v_3*h^10 - 270*u_3^2*v_3*h^10 - 471*u_3*v_1*v_3*h^10 + 517*u_1*v_2*v_3*h^10 + 3822*u_2*v_2*v_3*h^10 - 947*u_3*v_2*v_3*h^10 + 3421*v_1*v_2*v_3*h^10 - 4997*v_2^2*v_3*h^10 - 4729*u_1*v_3^2*h^10 - 1843*u_2*v_3^2*h^10 + 1106*u_3*v_3^2*h^10 - 3940*v_1*v_3^2*h^10 - 1916*v_2*v_3^2*h^10 - 980*u_2^2*y*h^10 - 2694*u_2*u_3*y*h^10 - 2237*u_3^2*y*h^10 - 2105*u_3*v_1*y*h^10 - 2792*u_2*v_2*y*h^10 - 1890*u_3*v_2*y*h^10 + 2232*v_1*v_2*y*h^10 + 1456*v_2^2*y*h^10 - 551*u_2*v_3*y*h^10 - 1709*u_3*v_3*y*h^10 - 436*v_1*v_3*y*h^10 - 4292*v_2*v_3*y*h^10 - 2500*v_3^2*y*h^10 - 2374*u_2^2*h^11 - 4557*u_1*u_3*h^11 - 487*u_2*u_3*h^11 - 978*u_3^2*h^11 - 2663*u_2*v_1*h^11 - 1058*u_3*v_1*h^11 + 3699*v_1^2*h^11 - 1444*u_1*v_2*h^11 + 2703*u_2*v_2*h^11 - 2306*u_3*v_2*h^11 + 1547*v_1*v_2*h^11 + 2359*v_2^2*h^11 - 639*u_1*v_3*h^11 + 1047*u_2*v_3*h^11 + 1563*u_3*v_3*h^11 + 2714*v_1*v_3*h^11 - 3206*v_2*v_3*h^11 + 1060*v_3^2*h^11 - 2076*u_2*y*h^11 - 505*u_3*y*h^11 - 416*v_1*y*h^11 + 3951*v_2*y*h^11 + 2311*v_3*y*h^11 - 878*u_1*h^12 - 2140*u_2*h^12 - 2887*u_3*h^12 + 768*v_1*h^12 + 2392*v_2*h^12 - 1860*v_3*h^12 + 1879*y*h^12 + 1053*h^13,
#  u_2*u_3*v_2*v_3^2*h^8 + 1677*u_2^2*u_3*h^10 - 1495*u_1*u_3^2*h^10 + 933*u_2*u_3^2*h^10 + 4694*u_3^2*v_1*h^10 - 65*u_2*u_3*v_2*h^10 - 4352*u_3^2*v_2*h^10 - 120*u_3*v_2^2*h^10 - 520*u_2^2*v_3*h^10 + 3577*u_1*u_3*v_3*h^10 - 3098*u_2*u_3*v_3*h^10 + 1985*u_3^2*v_3*h^10 - 1401*u_3*v_1*v_3*h^10 - 4810*u_1*v_2*v_3*h^10 - 1641*u_2*v_2*v_3*h^10 + 4983*u_3*v_2*v_3*h^10 + 3686*v_1*v_2*v_3*h^10 + 4283*v_2^2*v_3*h^10 - 4528*u_1*v_3^2*h^10 + 4518*u_2*v_3^2*h^10 - 1603*u_3*v_3^2*h^10 - 540*v_1*v_3^2*h^10 + 283*v_2*v_3^2*h^10 + 2128*u_2^2*y*h^10 + 351*u_2*u_3*y*h^10 + 2678*u_3^2*y*h^10 - 4031*u_3*v_1*y*h^10 - 3333*u_2*v_2*y*h^10 - 3570*u_3*v_2*y*h^10 - 1971*v_1*v_2*y*h^10 - 1157*v_2^2*y*h^10 + 1768*u_2*v_3*y*h^10 + 4129*u_3*v_3*y*h^10 + 1192*v_1*v_3*y*h^10 + 4286*v_2*v_3*y*h^10 - 4392*v_3^2*y*h^10 + 1773*u_2^2*h^11 - 3605*u_1*u_3*h^11 - 3208*u_2*u_3*h^11 + 2660*u_3^2*h^11 + 3701*u_2*v_1*h^11 - 3942*u_3*v_1*h^11 - 2280*v_1^2*h^11 - 4665*u_1*v_2*h^11 + 1398*u_2*v_2*h^11 + 2268*u_3*v_2*h^11 - 3023*v_1*v_2*h^11 + 111*v_2^2*h^11 - 294*u_1*v_3*h^11 - 4147*u_2*v_3*h^11 - 4378*u_3*v_3*h^11 + 1328*v_1*v_3*h^11 - 1047*v_2*v_3*h^11 + 2327*v_3^2*h^11 + 934*u_2*y*h^11 - 2647*u_3*y*h^11 + 4128*v_1*y*h^11 + 2276*v_2*y*h^11 - 1920*v_3*y*h^11 - 1681*u_1*h^12 + 2501*u_2*h^12 + 640*u_3*h^12 + 2493*v_1*h^12 - 708*v_2*h^12 + 4613*v_3*h^12 - 3526*y*h^12 - 4604*h^13,
#  u_3^2*v_2*v_3^2*h^8 + 2056*u_2^2*u_3*h^10 - 2502*u_1*u_3^2*h^10 + 3578*u_2*u_3^2*h^10 - 3947*u_3^2*v_1*h^10 + 2237*u_2*u_3*v_2*h^10 + 232*u_3^2*v_2*h^10 - 133*u_3*v_2^2*h^10 - 2538*u_2^2*v_3*h^10 - 4972*u_1*u_3*v_3*h^10 - 4474*u_2*u_3*v_3*h^10 - 4477*u_3^2*v_3*h^10 + 3145*u_3*v_1*v_3*h^10 - 3*u_1*v_2*v_3*h^10 - 4307*u_2*v_2*v_3*h^10 + 2219*u_3*v_2*v_3*h^10 - 3164*v_1*v_2*v_3*h^10 - 154*v_2^2*v_3*h^10 - 1164*u_1*v_3^2*h^10 + 2489*u_2*v_3^2*h^10 - 673*u_3*v_3^2*h^10 - 2580*v_1*v_3^2*h^10 - 4616*v_2*v_3^2*h^10 - 953*u_2^2*y*h^10 - 1448*u_2*u_3*y*h^10 - 4678*u_3^2*y*h^10 + 2444*u_3*v_1*y*h^10 + 2332*u_2*v_2*y*h^10 + 1578*u_3*v_2*y*h^10 + 4604*v_1*v_2*y*h^10 + 2071*v_2^2*y*h^10 - 308*u_2*v_3*y*h^10 + 4968*u_3*v_3*y*h^10 - 1793*v_1*v_3*y*h^10 + 2449*v_2*v_3*y*h^10 - 10*v_3^2*y*h^10 + 4388*u_2^2*h^11 - 1353*u_1*u_3*h^11 - 1228*u_2*u_3*h^11 + 1377*u_3^2*h^11 + 1741*u_2*v_1*h^11 - 2220*u_3*v_1*h^11 - 3725*v_1^2*h^11 + 1290*u_1*v_2*h^11 + 1970*u_2*v_2*h^11 + 55*u_3*v_2*h^11 + 4290*v_1*v_2*h^11 - 1732*v_2^2*h^11 + 3353*u_1*v_3*h^11 - 141*u_2*v_3*h^11 + 2419*u_3*v_3*h^11 + 3401*v_1*v_3*h^11 + 197*v_2*v_3*h^11 + 1821*v_3^2*h^11 - 3436*u_2*y*h^11 - 594*u_3*y*h^11 + 3618*v_1*y*h^11 - 1603*v_2*y*h^11 + 2141*v_3*y*h^11 - 3693*u_1*h^12 + 878*u_2*h^12 - 4000*u_3*h^12 + 3003*v_1*h^12 - 594*v_2*h^12 - 2315*v_3*h^12 + 3063*y*h^12 + 4638*h^13,
#  u_3*v_2^2*v_3^2*h^8 - 3897*u_2^2*u_3*h^10 - 3507*u_1*u_3^2*h^10 - 2733*u_2*u_3^2*h^10 - 4014*u_3^2*v_1*h^10 + 4640*u_2*u_3*v_2*h^10 + 3039*u_3^2*v_2*h^10 - 1467*u_3*v_2^2*h^10 + 1929*u_2^2*v_3*h^10 - 2866*u_1*u_3*v_3*h^10 + 2706*u_2*u_3*v_3*h^10 + 2319*u_3^2*v_3*h^10 + 3751*u_3*v_1*v_3*h^10 + 892*u_1*v_2*v_3*h^10 - 59*u_2*v_2*v_3*h^10 - 3629*u_3*v_2*v_3*h^10 + 2102*v_1*v_2*v_3*h^10 + 65*v_2^2*v_3*h^10 - 4896*u_1*v_3^2*h^10 + 4297*u_2*v_3^2*h^10 - 3584*u_3*v_3^2*h^10 - 2288*v_1*v_3^2*h^10 + 1758*v_2*v_3^2*h^10 - 1511*u_2^2*y*h^10 - 2444*u_2*u_3*y*h^10 + 1654*u_3^2*y*h^10 - 487*u_3*v_1*y*h^10 - 266*u_2*v_2*y*h^10 + 3758*u_3*v_2*y*h^10 + 1157*v_1*v_2*y*h^10 - 4135*v_2^2*y*h^10 - 2424*u_2*v_3*y*h^10 + 1134*u_3*v_3*y*h^10 - 1320*v_1*v_3*y*h^10 - 1633*v_2*v_3*y*h^10 - 4477*v_3^2*y*h^10 + 2691*u_2^2*h^11 + 3439*u_1*u_3*h^11 - 622*u_2*u_3*h^11 - 3816*u_3^2*h^11 + 4688*u_2*v_1*h^11 + 1023*u_3*v_1*h^11 - 474*v_1^2*h^11 - 342*u_1*v_2*h^11 - 3841*u_2*v_2*h^11 + 1229*u_3*v_2*h^11 + 453*v_1*v_2*h^11 - 2525*v_2^2*h^11 - 3176*u_1*v_3*h^11 - 2067*u_2*v_3*h^11 + 619*u_3*v_3*h^11 - 3013*v_1*v_3*h^11 + 3102*v_2*v_3*h^11 + 3373*v_3^2*h^11 - 3289*u_2*y*h^11 + 2910*u_3*y*h^11 - 414*v_1*y*h^11 + 1457*v_2*y*h^11 - 2223*v_3*y*h^11 - 2025*u_1*h^12 - 870*u_2*h^12 - 2894*u_3*h^12 - 3194*v_1*h^12 - 496*v_2*h^12 + 2655*v_3*h^12 - 4605*y*h^12 - 4350*h^13,
#  u_3^2*v_3^2*y*h^8 - 3560*u_2^2*u_3*h^10 - 757*u_1*u_3^2*h^10 + 246*u_2*u_3^2*h^10 + 4502*u_3^2*v_1*h^10 - 2272*u_2*u_3*v_2*h^10 - 2862*u_3^2*v_2*h^10 - 3164*u_3*v_2^2*h^10 - 3767*u_2^2*v_3*h^10 + 1735*u_1*u_3*v_3*h^10 + 4855*u_2*u_3*v_3*h^10 - 1487*u_3^2*v_3*h^10 + 4778*u_3*v_1*v_3*h^10 + 1358*u_1*v_2*v_3*h^10 - 1657*u_2*v_2*v_3*h^10 + 3433*u_3*v_2*v_3*h^10 + 3656*v_1*v_2*v_3*h^10 + 3985*v_2^2*v_3*h^10 - 455*u_1*v_3^2*h^10 + 3828*u_2*v_3^2*h^10 - 1666*u_3*v_3^2*h^10 - 2982*v_1*v_3^2*h^10 + 4045*v_2*v_3^2*h^10 + 3924*u_2^2*y*h^10 + 3434*u_2*u_3*y*h^10 - 1021*u_3^2*y*h^10 + 1481*u_3*v_1*y*h^10 + 3442*u_2*v_2*y*h^10 + 3459*u_3*v_2*y*h^10 + 1965*v_1*v_2*y*h^10 - 79*v_2^2*y*h^10 - 4838*u_2*v_3*y*h^10 - 4226*u_3*v_3*y*h^10 + 3198*v_1*v_3*y*h^10 - 1895*v_2*v_3*y*h^10 + 1086*v_3^2*y*h^10 - 3270*u_2^2*h^11 - 3262*u_1*u_3*h^11 - 802*u_2*u_3*h^11 - 4573*u_3^2*h^11 - 3418*u_2*v_1*h^11 + 3951*u_3*v_1*h^11 + 687*v_1^2*h^11 + 99*u_1*v_2*h^11 + 4393*u_2*v_2*h^11 - 3926*u_3*v_2*h^11 + 2518*v_1*v_2*h^11 + 4692*v_2^2*h^11 + 4881*u_1*v_3*h^11 + 4948*u_2*v_3*h^11 - 15*u_3*v_3*h^11 - 3774*v_1*v_3*h^11 - 4804*v_2*v_3*h^11 - 1845*v_3^2*h^11 + 4748*u_2*y*h^11 + 1596*u_3*y*h^11 - 2844*v_1*y*h^11 - 3857*v_2*y*h^11 + 2436*v_3*y*h^11 + 4629*u_1*h^12 - 2779*u_2*h^12 + 3248*u_3*h^12 + 1085*v_1*h^12 + 2226*v_2*h^12 + 1907*v_3*h^12 - 4518*y*h^12 + 3247*h^13,
#  u_2^2*u_3^2*h^9 - 863*u_2^2*u_3*h^10 + 2654*u_1*u_3^2*h^10 - 2370*u_2*u_3^2*h^10 + 2784*u_3^2*v_1*h^10 - 3058*u_2*u_3*v_2*h^10 - 3667*u_3^2*v_2*h^10 + 1070*u_3*v_2^2*h^10 - 4842*u_2^2*v_3*h^10 + 3378*u_1*u_3*v_3*h^10 - 3933*u_2*u_3*v_3*h^10 - 3629*u_3^2*v_3*h^10 + 1081*u_3*v_1*v_3*h^10 + 1522*u_1*v_2*v_3*h^10 - 2602*u_2*v_2*v_3*h^10 + 4805*u_3*v_2*v_3*h^10 + 1998*v_1*v_2*v_3*h^10 - 3478*v_2^2*v_3*h^10 + 1588*u_1*v_3^2*h^10 - 1891*u_2*v_3^2*h^10 - 2815*u_3*v_3^2*h^10 + 1850*v_1*v_3^2*h^10 + 667*v_2*v_3^2*h^10 + 4258*u_2^2*y*h^10 - 3329*u_2*u_3*y*h^10 + 2779*u_3^2*y*h^10 + 4689*u_3*v_1*y*h^10 + 1471*u_2*v_2*y*h^10 - 5000*u_3*v_2*y*h^10 - 1396*v_1*v_2*y*h^10 - 3913*v_2^2*y*h^10 - 2836*u_2*v_3*y*h^10 + 3085*u_3*v_3*y*h^10 - 435*v_1*v_3*y*h^10 + 3156*v_2*v_3*y*h^10 + 2769*v_3^2*y*h^10 - 4963*u_2^2*h^11 + 2*u_1*u_3*h^11 - 1010*u_2*u_3*h^11 - 577*u_3^2*h^11 + 2943*u_2*v_1*h^11 - 3270*u_3*v_1*h^11 - 1384*v_1^2*h^11 - 3089*u_1*v_2*h^11 + 3660*u_2*v_2*h^11 + 316*u_3*v_2*h^11 + 3227*v_1*v_2*h^11 + 3453*v_2^2*h^11 + 382*u_1*v_3*h^11 + 2205*u_2*v_3*h^11 + 1685*u_3*v_3*h^11 + 4791*v_1*v_3*h^11 - 3476*v_2*v_3*h^11 + 1005*v_3^2*h^11 - 4764*u_2*y*h^11 + 2201*u_3*y*h^11 + 4057*v_1*y*h^11 + 3033*v_2*y*h^11 + 4667*v_3*y*h^11 - 1512*u_1*h^12 + 3369*u_2*h^12 - 3254*u_3*h^12 + 2263*v_1*h^12 + 3195*v_2*h^12 - 2197*v_3*h^12 + 922*y*h^12 + 1519*h^13,
#  u_2*u_3^2*v_2*h^9 - 1185*u_2^2*u_3*h^10 - 2950*u_1*u_3^2*h^10 - 1894*u_2*u_3^2*h^10 - 1496*u_3^2*v_1*h^10 - 853*u_2*u_3*v_2*h^10 + 1619*u_3^2*v_2*h^10 - 4918*u_3*v_2^2*h^10 - 870*u_2^2*v_3*h^10 - 1110*u_1*u_3*v_3*h^10 - 4246*u_2*u_3*v_3*h^10 + 3961*u_3^2*v_3*h^10 - 4019*u_3*v_1*v_3*h^10 + 4369*u_1*v_2*v_3*h^10 - 4555*u_2*v_2*v_3*h^10 - 506*u_3*v_2*v_3*h^10 - 4838*v_1*v_2*v_3*h^10 + 4293*v_2^2*v_3*h^10 + 2551*u_1*v_3^2*h^10 - 4917*u_2*v_3^2*h^10 + 1201*u_3*v_3^2*h^10 - 82*v_1*v_3^2*h^10 - 3987*v_2*v_3^2*h^10 + 576*u_2^2*y*h^10 - 3501*u_2*u_3*y*h^10 - 4401*u_3^2*y*h^10 - 1255*u_3*v_1*y*h^10 + 3397*u_2*v_2*y*h^10 + 1371*u_3*v_2*y*h^10 + 2975*v_1*v_2*y*h^10 + 2941*v_2^2*y*h^10 - 3756*u_2*v_3*y*h^10 - 3352*u_3*v_3*y*h^10 + 68*v_1*v_3*y*h^10 + 4678*v_2*v_3*y*h^10 + 2626*v_3^2*y*h^10 - 2618*u_2^2*h^11 + 634*u_1*u_3*h^11 + 535*u_2*u_3*h^11 - 899*u_3^2*h^11 + 703*u_2*v_1*h^11 + 2187*u_3*v_1*h^11 + 1093*v_1^2*h^11 - 173*u_1*v_2*h^11 - 3105*u_2*v_2*h^11 + 3074*u_3*v_2*h^11 + 2997*v_1*v_2*h^11 + 3351*v_2^2*h^11 - 1877*u_1*v_3*h^11 + 1976*u_2*v_3*h^11 - 1056*u_3*v_3*h^11 + 1741*v_1*v_3*h^11 - 688*v_2*v_3*h^11 - 2054*v_3^2*h^11 + 1078*u_2*y*h^11 - 4421*u_3*y*h^11 + 229*v_1*y*h^11 + 2273*v_2*y*h^11 - 2008*v_3*y*h^11 - 4301*u_1*h^12 + 888*u_2*h^12 - 3578*u_3*h^12 - 2590*v_1*h^12 + 1686*v_2*h^12 - 4723*v_3*h^12 + 2203*y*h^12 - 4788*h^13,
#  u_3^2*v_2^2*h^9 - 1717*u_2^2*u_3*h^10 + 1718*u_1*u_3^2*h^10 + 4539*u_2*u_3^2*h^10 + 1052*u_3^2*v_1*h^10 + 2592*u_2*u_3*v_2*h^10 + 3382*u_3^2*v_2*h^10 + 871*u_3*v_2^2*h^10 + 1551*u_2^2*v_3*h^10 - 4270*u_1*u_3*v_3*h^10 + 3102*u_2*u_3*v_3*h^10 + 4302*u_3^2*v_3*h^10 - 4377*u_3*v_1*v_3*h^10 - 2641*u_1*v_2*v_3*h^10 + 419*u_2*v_2*v_3*h^10 + 348*u_3*v_2*v_3*h^10 + 3130*v_1*v_2*v_3*h^10 - 22*v_2^2*v_3*h^10 - 996*u_1*v_3^2*h^10 + 3223*u_2*v_3^2*h^10 - 711*u_3*v_3^2*h^10 - 1670*v_1*v_3^2*h^10 - 90*v_2*v_3^2*h^10 - 1986*u_2^2*y*h^10 - 4069*u_2*u_3*y*h^10 - 2462*u_3^2*y*h^10 - 1214*u_3*v_1*y*h^10 - 1463*u_2*v_2*y*h^10 - 4156*u_3*v_2*y*h^10 - 1229*v_1*v_2*y*h^10 + 1287*v_2^2*y*h^10 - 330*u_2*v_3*y*h^10 + 2481*u_3*v_3*y*h^10 + 3832*v_1*v_3*y*h^10 - 4987*v_2*v_3*y*h^10 + 4849*v_3^2*y*h^10 - 2394*u_2^2*h^11 - 3793*u_1*u_3*h^11 + 2063*u_2*u_3*h^11 - 678*u_3^2*h^11 - 589*u_2*v_1*h^11 + 871*u_3*v_1*h^11 + 2390*v_1^2*h^11 + 1715*u_1*v_2*h^11 + 646*u_2*v_2*h^11 - 1654*u_3*v_2*h^11 + 1008*v_1*v_2*h^11 - 3579*v_2^2*h^11 - 4834*u_1*v_3*h^11 + 2301*u_2*v_3*h^11 - 180*u_3*v_3*h^11 + 2302*v_1*v_3*h^11 + 5003*v_2*v_3*h^11 - 3089*v_3^2*h^11 - 66*u_2*y*h^11 - 13*u_3*y*h^11 + 931*v_1*y*h^11 + 2918*v_2*y*h^11 - 4575*v_3*y*h^11 - 4313*u_1*h^12 - 371*u_2*h^12 - 2748*u_3*h^12 - 2343*v_1*h^12 - 2437*v_2*h^12 + 3981*v_3*h^12 + 1544*y*h^12 + 4331*h^13,
# ...
#  v_1*v_2^2*h^8 + 4884*u_2^2*y*h^8 - 4994*u_2*u_3*y*h^8 + 3464*u_3*v_1*y*h^8 - 383*u_2*v_2*y*h^8 + 3027*u_3*v_2*y*h^8 + 2332*v_1*v_2*y*h^8 - 1428*v_2^2*y*h^8 - 1123*u_2*v_3*y*h^8 + 1699*v_1*v_3*y*h^8 + 3090*v_2*v_3*y*h^8 + 987*u_2^2*h^9 - 4831*u_1*u_3*h^9 - 4507*u_2*u_3*h^9 + 4773*u_2*v_1*h^9 + 1690*u_3*v_1*h^9 + 2137*v_1^2*h^9 + 159*u_1*v_2*h^9 - 404*u_2*v_2*h^9 - 4722*u_3*v_2*h^9 - 1446*v_1*v_2*h^9 + 1885*v_2^2*h^9 + 4473*u_1*v_3*h^9 - 4911*u_2*v_3*h^9 + 2611*v_1*v_3*h^9 - 2053*v_2*v_3*h^9 - 4576*u_2*y*h^9 + 2834*u_3*y*h^9 - 1067*v_1*y*h^9 + 71*v_2*y*h^9 - 3406*v_3*y*h^9 + 2975*u_1*h^10 + 1733*u_2*h^10 + 535*u_3*h^10 + 505*v_1*h^10 + 2217*v_2*h^10 - 4286*v_3*h^10 + 4792*y*h^10 + 2983*h^11,
#  u_2*v_1*v_3*h^8 - 3*u_1*v_2*v_3*h^8 + 2*v_1*v_2*v_3*h^8 - 1337*u_2^2*y*h^8 + 3730*u_2*u_3*y*h^8 - 3870*u_3*v_1*y*h^8 - 286*u_2*v_2*y*h^8 + 2175*u_3*v_2*y*h^8 + 2154*v_1*v_2*y*h^8 + 3443*v_2^2*y*h^8 + 2292*u_2*v_3*y*h^8 - 767*v_1*v_3*y*h^8 - 1554*v_2*v_3*y*h^8 - 526*u_2^2*h^9 + 4710*u_1*u_3*h^9 + 930*u_2*u_3*h^9 + 83*u_2*v_1*h^9 - 62*u_3*v_1*h^9 - 3650*v_1^2*h^9 + 1329*u_1*v_2*h^9 - 1456*u_2*v_2*h^9 - 3705*u_3*v_2*h^9 + 3396*v_1*v_2*h^9 - 3942*v_2^2*h^9 + 1095*u_1*v_3*h^9 - 1460*u_2*v_3*h^9 - 3400*v_1*v_3*h^9 - 2990*v_2*v_3*h^9 + 2957*u_2*y*h^9 - 112*u_3*y*h^9 + 491*v_1*y*h^9 - 4363*v_2*y*h^9 - 2400*v_3*y*h^9 - 389*u_1*h^10 - 2828*u_2*h^10 - 340*u_3*h^10 + 3221*v_1*h^10 - 2266*v_2*h^10 - 2852*v_3*h^10 + 4435*y*h^10 - 2786*h^11,
#  v_1^2*v_3*h^8 + 3997*u_2^2*y*h^8 - 3683*u_2*u_3*y*h^8 - 256*u_3*v_1*y*h^8 + 1374*u_2*v_2*y*h^8 - 4423*u_3*v_2*y*h^8 + 3618*v_1*v_2*y*h^8 + 1900*v_2^2*y*h^8 + 1489*u_2*v_3*y*h^8 - 1466*v_1*v_3*y*h^8 - 3390*v_2*v_3*y*h^8 - 4155*u_2^2*h^9 + 2583*u_1*u_3*h^9 - 4218*u_2*u_3*h^9 - 2660*u_2*v_1*h^9 + 3158*u_3*v_1*h^9 - 3452*v_1^2*h^9 + 1204*u_1*v_2*h^9 + 4552*u_2*v_2*h^9 + 145*u_3*v_2*h^9 + 4538*v_1*v_2*h^9 + 822*v_2^2*h^9 - 1730*u_1*v_3*h^9 + 4100*u_2*v_3*h^9 + 992*v_1*v_3*h^9 - 1748*v_2*v_3*h^9 - 2104*u_2*y*h^9 + 3807*u_3*y*h^9 + 2209*v_1*y*h^9 - 1617*v_2*y*h^9 + 1748*v_3*y*h^9 + 274*u_1*h^10 - 3737*u_2*h^10 + 4705*u_3*h^10 + 899*v_1*h^10 + 1372*v_2*h^10 - 4643*v_3*h^10 - 3692*y*h^10 - 2831*h^11,
#  u_2^2*v_2^2*h^6 - 1647*v_1*v_2^2*h^7 + 2645*u_2*v_1*v_3*h^7 + 4379*v_1^2*v_3*h^7 + 2072*u_1*v_2*v_3*h^7 - 4717*v_1*v_2*v_3*h^7 + 2867*u_2^2*y*h^7 + 1850*u_2*u_3*y*h^7 + 2269*u_3*v_1*y*h^7 - 2482*u_2*v_2*y*h^7 - 1916*u_3*v_2*y*h^7 + 4221*v_1*v_2*y*h^7 - 3830*v_2^2*y*h^7 + 2244*u_2*v_3*y*h^7 - 276*v_1*v_3*y*h^7 - 3735*v_2*v_3*y*h^7 - 3321*u_2^2*h^8 - 1796*u_1*u_3*h^8 + 3326*u_2*u_3*h^8 + 1271*u_2*v_1*h^8 + 3645*u_3*v_1*h^8 - 275*v_1^2*h^8 + 1124*u_1*v_2*h^8 - 1814*u_2*v_2*h^8 + 1470*u_3*v_2*h^8 - 1197*v_1*v_2*h^8 + 4878*v_2^2*h^8 + 3959*u_1*v_3*h^8 - 2678*u_2*v_3*h^8 - 725*v_1*v_3*h^8 - 4233*v_2*v_3*h^8 + 4666*u_2*y*h^8 + 3022*u_3*y*h^8 - 2342*v_1*y*h^8 + 2225*v_2*y*h^8 + 370*v_3*y*h^8 - 2578*u_1*h^9 - 1631*u_2*h^9 - 4982*u_3*h^9 - 306*v_1*h^9 - 1331*v_2*h^9 - 1256*v_3*h^9 + 3103*y*h^9 - 3863*h^10,
#  u_3*v_1*v_2*y*h^6 - v_1*v_2*v_3*y*h^6 + 3620*v_1*v_2^2*h^7 + 2841*u_2*v_1*v_3*h^7 - 887*v_1^2*v_3*h^7 - 3888*u_1*v_2*v_3*h^7 + 4231*v_1*v_2*v_3*h^7 + 4088*u_2^2*y*h^7 + 208*u_2*u_3*y*h^7 - 4233*u_3*v_1*y*h^7 - 713*u_2*v_2*y*h^7 + 3493*u_3*v_2*y*h^7 - 2196*v_1*v_2*y*h^7 + 817*v_2^2*y*h^7 - 1341*u_2*v_3*y*h^7 - 1294*v_1*v_3*y*h^7 + 431*v_2*v_3*y*h^7 - 1791*u_2^2*h^8 + 4322*u_1*u_3*h^8 + 3111*u_2*u_3*h^8 + 1216*u_2*v_1*h^8 - 4711*u_3*v_1*h^8 - 4344*v_1^2*h^8 - 4768*u_1*v_2*h^8 - 2912*u_2*v_2*h^8 - 4804*u_3*v_2*h^8 - 823*v_1*v_2*h^8 + 3241*v_2^2*h^8 - 4081*u_1*v_3*h^8 - 983*u_2*v_3*h^8 + 4276*v_1*v_3*h^8 - 799*v_2*v_3*h^8 - 3370*u_2*y*h^8 + 3249*u_3*y*h^8 + 2233*v_1*y*h^8 - 4988*v_2*y*h^8 + 4750*v_3*y*h^8 - 3849*u_1*h^9 - 524*u_2*h^9 + 1420*u_3*h^9 - 2477*v_1*h^9 - 3585*v_2*h^9 - 1158*v_3*h^9 - 1435*y*h^9 + 4195*h^10,
#  u_2*u_3*v_1*h^7 - 3928*v_1*v_2^2*h^7 - 1104*u_2*v_1*v_3*h^7 - 4428*v_1^2*v_3*h^7 + 3300*u_1*v_2*v_3*h^7 - 2197*v_1*v_2*v_3*h^7 + 763*u_2*u_3*y*h^7 - 3341*u_3*v_1*y*h^7 + 2721*u_2*v_2*y*h^7 + 4937*u_3*v_2*y*h^7 - 3995*v_1*v_2*y*h^7 + 2276*v_2^2*y*h^7 - 2351*u_2*v_3*y*h^7 + 732*v_1*v_3*y*h^7 + 3958*v_2*v_3*y*h^7 - 3309*u_2^2*h^8 - 3947*u_1*u_3*h^8 - 2549*u_2*u_3*h^8 + 1807*u_2*v_1*h^8 + 1875*u_3*v_1*h^8 + 2133*v_1^2*h^8 - 2872*u_1*v_2*h^8 + 2829*u_2*v_2*h^8 + 524*u_3*v_2*h^8 - 969*v_1*v_2*h^8 + 2393*v_2^2*h^8 - 2171*u_1*v_3*h^8 - 2606*u_2*v_3*h^8 - 1040*v_1*v_3*h^8 + 3355*v_2*v_3*h^8 + 653*u_2*y*h^8 - 608*u_3*y*h^8 + 4353*v_1*y*h^8 + 2183*v_2*y*h^8 - 3914*v_3*y*h^8 + 773*u_1*h^9 - 4543*u_2*h^9 - 1587*u_3*h^9 - 4879*v_1*h^9 + 3815*v_2*h^9 + 1089*v_3*h^9 + 1135*y*h^9 + 2507*h^10,
#  u_3*v_1^2*h^7 - 1256*v_1*v_2^2*h^7 - 3609*u_2*v_1*v_3*h^7 - 901*v_1^2*v_3*h^7 + 820*u_1*v_2*v_3*h^7 + 2789*v_1*v_2*v_3*h^7 + 4100*u_2^2*y*h^7 - 2647*u_2*u_3*y*h^7 + 176*u_3*v_1*y*h^7 - 2432*u_2*v_2*y*h^7 + 2647*u_3*v_2*y*h^7 + 3100*v_1*v_2*y*h^7 - 1735*v_2^2*y*h^7 + 2257*u_2*v_3*y*h^7 + 59*v_1*v_3*y*h^7 - 72*v_2*v_3*y*h^7 + 3823*u_2^2*h^8 - 999*u_1*u_3*h^8 - 1535*u_2*u_3*h^8 - 4469*u_2*v_1*h^8 - 2822*u_3*v_1*h^8 - 2587*v_1^2*h^8 - 3811*u_1*v_2*h^8 - 2021*u_2*v_2*h^8 + 817*u_3*v_2*h^8 - 3052*v_1*v_2*h^8 - 1759*v_2^2*h^8 + 3789*u_1*v_3*h^8 - 353*u_2*v_3*h^8 - 4063*v_1*v_3*h^8 - 577*v_2*v_3*h^8 + 2328*u_2*y*h^8 - 3615*u_3*y*h^8 - 3126*v_1*y*h^8 + 3939*v_2*y*h^8 - 4078*v_3*y*h^8 - 323*u_1*h^9 - 48*u_2*h^9 - 3918*u_3*h^9 - 1468*v_1*h^9 + 1412*v_2*h^9 - 3279*v_3*h^9 - 4907*y*h^9 - 2278*h^10,
#  u_2^2*v_2*h^7 + 2604*v_1*v_2^2*h^7 + 67*u_2*v_1*v_3*h^7 - 2863*v_1^2*v_3*h^7 - 201*u_1*v_2*v_3*h^7 + 134*v_1*v_2*v_3*h^7 - 3486*u_2^2*y*h^7 + 4138*u_2*u_3*y*h^7 - 1610*u_3*v_1*y*h^7 - 1929*u_2*v_2*y*h^7 - 4138*u_3*v_2*y*h^7 + 2146*v_1*v_2*y*h^7 - 2368*v_2^2*y*h^7 - 2700*u_2*v_3*y*h^7 - 712*v_1*v_3*y*h^7 - 2534*v_2*v_3*y*h^7 - 3370*u_2^2*h^8 + 667*u_1*u_3*h^8 - 2481*u_2*u_3*h^8 - 1786*u_2*v_1*h^8 - 80*u_3*v_1*h^8 - 2234*v_1^2*h^8 + 3775*u_1*v_2*h^8 + 1475*u_2*v_2*h^8 + 4541*u_3*v_2*h^8 - 455*v_1*v_2*h^8 - 3676*v_2^2*h^8 - 3556*u_1*v_3*h^8 - 3695*u_2*v_3*h^8 + 2785*v_1*v_3*h^8 + 1502*v_2*v_3*h^8 + 3329*u_2*y*h^8 + 3766*u_3*y*h^8 + 378*v_1*y*h^8 - 1012*v_2*y*h^8 + 4464*v_3*y*h^8 - 1237*u_1*h^9 - 4893*u_2*h^9 + 790*u_3*h^9 - 1789*v_1*h^9 + 386*v_2*h^9 + 3648*v_3*h^9 - 1557*y*h^9 + 3398*h^10,
#  u_1*u_3*v_2*h^7 - 516*v_1*v_2^2*h^7 + 2188*u_2*v_1*v_3*h^7 - 4393*v_1^2*v_3*h^7 + 3433*u_1*v_2*v_3*h^7 + 4385*v_1*v_2*v_3*h^7 - 4923*u_2^2*y*h^7 + 2884*u_2*u_3*y*h^7 - 1763*u_3*v_1*y*h^7 + 3694*u_2*v_2*y*h^7 + 2901*u_3*v_2*y*h^7 - 2997*v_1*v_2*y*h^7 + 824*v_2^2*y*h^7 - 718*u_2*v_3*y*h^7 - 292*v_1*v_3*y*h^7 - 772*v_2*v_3*y*h^7 + 1418*u_2^2*h^8 + 1792*u_1*u_3*h^8 + 2145*u_2*u_3*h^8 - 2216*u_2*v_1*h^8 - 984*u_3*v_1*h^8 - 4555*v_1^2*h^8 - 74*u_1*v_2*h^8 + 4315*u_2*v_2*h^8 + 854*u_3*v_2*h^8 + 4457*v_1*v_2*h^8 + 2032*v_2^2*h^8 + 4887*u_1*v_3*h^8 - 3947*u_2*v_3*h^8 - 1156*v_1*v_3*h^8 + 416*v_2*v_3*h^8 - 4968*u_2*y*h^8 + 4128*u_3*y*h^8 - 4281*v_1*y*h^8 - 4828*v_2*y*h^8 - 4470*v_3*y*h^8 + 4805*u_1*h^9 - 3904*u_2*h^9 + 3441*u_3*h^9 + 382*v_1*h^9 + 4613*v_2*h^9 - 526*v_3*h^9 + 4909*y*h^9 - 2206*h^10,
#  u_3*v_1*v_2*h^7 + 2964*v_1*v_2^2*h^7 - 2773*u_2*v_1*v_3*h^7 - 4503*v_1^2*v_3*h^7 - 1697*u_1*v_2*v_3*h^7 + 4469*v_1*v_2*v_3*h^7 - 4244*u_2^2*y*h^7 + 1328*u_2*u_3*y*h^7 - 84*u_3*v_1*y*h^7 + 1364*u_2*v_2*y*h^7 - 2186*u_3*v_2*y*h^7 - 1558*v_1*v_2*y*h^7 - 4095*v_2^2*y*h^7 + 4455*u_2*v_3*y*h^7 + 2141*v_1*v_3*y*h^7 - 2089*v_2*v_3*y*h^7 - 638*u_2^2*h^8 - 1113*u_1*u_3*h^8 - 1691*u_2*u_3*h^8 - 2278*u_2*v_1*h^8 + 1093*u_3*v_1*h^8 - 971*v_1^2*h^8 + 122*u_1*v_2*h^8 + 4585*u_2*v_2*h^8 + 2596*u_3*v_2*h^8 - 3690*v_1*v_2*h^8 - 3061*v_2^2*h^8 - 1711*u_1*v_3*h^8 - 403*u_2*v_3*h^8 - 3977*v_1*v_3*h^8 + 2072*v_2*v_3*h^8 + 3908*u_2*y*h^8 + 670*u_3*y*h^8 - 1523*v_1*y*h^8 + 2879*v_2*y*h^8 + 4806*v_3*y*h^8 - 4265*u_1*h^9 + 2284*u_2*h^9 + 922*u_3*h^9 + 4023*v_1*h^9 - 1003*v_2*h^9 + 576*v_3*h^9 + 19*y*h^9 + 3405*h^10,
#  u_1*v_2^2*h^7 + 2436*v_1*v_2^2*h^7 - 2642*u_2*v_1*v_3*h^7 + 3566*v_1^2*v_3*h^7 - 2081*u_1*v_2*v_3*h^7 + 4723*v_1*v_2*v_3*h^7 - 4737*u_2^2*y*h^7 - 2613*u_2*u_3*y*h^7 - 3106*u_3*v_1*y*h^7 - 2992*u_2*v_2*y*h^7 + 2613*u_3*v_2*y*h^7 + 334*v_1*v_2*y*h^7 + 2805*v_2^2*y*h^7 + 4457*u_2*v_3*y*h^7 - 1667*v_1*v_3*y*h^7 - 2985*v_2*v_3*y*h^7 - 1362*u_2^2*h^8 + 2619*u_1*u_3*h^8 - 3432*u_2*u_3*h^8 - 3597*u_2*v_1*h^8 - 3603*u_3*v_1*h^8 + 4592*v_1^2*h^8 + 3771*u_1*v_2*h^8 - 4484*u_2*v_2*h^8 + 2107*u_3*v_2*h^8 + 139*v_1*v_2*h^8 + 2647*v_2^2*h^8 + 3458*u_1*v_3*h^8 - 368*u_2*v_3*h^8 + 3355*v_1*v_3*h^8 - 2472*v_2*v_3*h^8 + 3921*u_2*y*h^8 - 1258*u_3*y*h^8 - 3205*v_1*y*h^8 + 3712*v_2*y*h^8 - 4111*v_3*y*h^8 - 389*u_1*h^9 + 1203*u_2*h^9 + 1370*u_3*h^9 - 3742*v_1*h^9 + 4511*v_2*h^9 - 2900*v_3*h^9 + 2645*y*h^9 + 2276*h^10,
#  u_2*v_2^2*h^7 + 1235*v_1*v_2^2*h^7 - 1845*u_2*v_1*v_3*h^7 + 2816*v_1^2*v_3*h^7 - 4472*u_1*v_2*v_3*h^7 - 3690*v_1*v_2*v_3*h^7 + 4134*u_2^2*y*h^7 + 2550*u_2*u_3*y*h^7 - 1890*u_3*v_1*y*h^7 - 624*u_2*v_2*y*h^7 - 2550*u_3*v_2*y*h^7 + 44*v_1*v_2*y*h^7 + 1999*v_2^2*y*h^7 - 179*u_2*v_3*y*h^7 - 4068*v_1*v_3*y*h^7 + 2419*v_2*v_3*y*h^7 + 1559*u_2^2*h^8 + 165*u_1*u_3*h^8 - 2177*u_2*u_3*h^8 - 2965*u_2*v_1*h^8 + 1595*u_3*v_1*h^8 + 3819*v_1^2*h^8 + 1563*u_1*v_2*h^8 - 2679*u_2*v_2*h^8 - 3320*u_3*v_2*h^8 - 1719*v_1*v_2*h^8 - 2432*v_2^2*h^8 - 3880*u_1*v_3*h^8 - 560*u_2*v_3*h^8 + 3979*v_1*v_3*h^8 + 4940*v_2*v_3*h^8 - 1912*u_2*y*h^8 - 2283*u_3*y*h^8 + 3255*v_1*y*h^8 - 2502*v_2*y*h^8 - 2122*v_3*y*h^8 + 2272*u_1*h^9 - 3409*u_2*h^9 + 1567*u_3*h^9 + 4423*v_1*h^9 + 3690*v_2*h^9 - 1747*v_3*h^9 + 2988*y*h^9 - 1489*h^10,
#  v_1^2*v_2^2*h^5 + 51*u_2^2*v_2*h^6 - 4289*u_1*v_2^2*h^6 - 2080*u_2*v_2^2*h^6 + 4370*v_1*v_2^2*h^6 - 3812*u_2^2*y*h^6 + 2241*u_3*v_1*y*h^6 - 4792*u_2*v_2*y*h^6 - 4341*v_1*v_2*y*h^6 - 3407*v_2^2*y*h^6 - 2241*v_1*v_3*y*h^6 - 1268*u_2^2*h^7 + 2770*u_1*u_3*h^7 - 1120*u_2*v_1*h^7 - 2449*u_3*v_1*h^7 + 4708*v_1^2*h^7 + 3043*u_1*v_2*h^7 - 376*u_2*v_2*h^7 + 948*v_1*v_2*h^7 - 4212*v_2^2*h^7 + 4117*u_1*v_3*h^7 - 4085*v_1*v_3*h^7 + 741*u_2*y*h^7 - 2213*u_3*y*h^7 - 1212*v_1*y*h^7 + 1832*v_2*y*h^7 + 1230*v_3*y*h^7 + 2482*u_1*h^8 + 2366*u_2*h^8 + 3832*u_3*h^8 - 2277*v_1*h^8 + 3470*v_2*h^8 - 4939*v_3*h^8 + 3676*y*h^8 - 4133*h^9,
#  u_2^2*v_2*y*h^5 + 507*u_2^2*v_2*h^6 + 4894*u_1*v_2^2*h^6 - 2341*u_2*v_2^2*h^6 + 3910*v_1*v_2^2*h^6 + 3690*u_2^2*y*h^6 - 100*u_3*v_1*y*h^6 + 2265*u_2*v_2*y*h^6 + 3075*v_1*v_2*y*h^6 - 3086*v_2^2*y*h^6 + 100*v_1*v_3*y*h^6 - 2423*u_2^2*h^7 + 4814*u_1*u_3*h^7 - 479*u_2*v_1*h^7 - 427*u_3*v_1*h^7 + 3708*v_1^2*h^7 - 2790*u_1*v_2*h^7 - 4064*u_2*v_2*h^7 - 4197*v_1*v_2*h^7 - 2699*v_2^2*h^7 + 2560*u_1*v_3*h^7 + 4884*v_1*v_3*h^7 - 484*u_2*y*h^7 - 3696*u_3*y*h^7 - 2698*v_1*y*h^7 - 4286*v_2*y*h^7 + 1479*v_3*y*h^7 + 4819*u_1*h^8 + 3643*u_2*h^8 + 1394*u_3*h^8 - 3163*v_1*h^8 + 1277*v_2*h^8 - 3388*v_3*h^8 + 4826*y*h^8 - 2760*h^9,
#  u_2*v_2^2*y*h^5 + 2190*u_2^2*v_2*h^6 + 1381*u_1*v_2^2*h^6 + 4064*u_2*v_2^2*h^6 + 693*v_1*v_2^2*h^6 - 19*u_2^2*y*h^6 - 723*u_3*v_1*y*h^6 + 1039*u_2*v_2*y*h^6 - 1980*v_1*v_2*y*h^6 - 2207*v_2^2*y*h^6 + 723*v_1*v_3*y*h^6 - 3009*u_2^2*h^7 - 596*u_1*u_3*h^7 + 3569*u_2*v_1*h^7 - 4721*u_3*v_1*h^7 - 521*v_1^2*h^7 + 4134*u_1*v_2*h^7 + 4976*u_2*v_2*h^7 - 3406*v_1*v_2*h^7 + 1702*v_2^2*h^7 - 346*u_1*v_3*h^7 - 4766*v_1*v_3*h^7 - 2418*u_2*y*h^7 + 3949*u_3*y*h^7 - 640*v_1*y*h^7 + 4633*v_2*y*h^7 - 464*v_3*y*h^7 - 2833*u_1*h^8 + 2216*u_2*h^8 - 1207*u_3*h^8 + 401*v_1*h^8 + 1928*v_2*h^8 + 4432*v_3*h^8 - 2053*y*h^8 + 3932*h^9,
#  v_1*v_2^2*y*h^5 + 4580*u_2^2*v_2*h^6 - 4282*u_1*v_2^2*h^6 - 668*u_2*v_2^2*h^6 + 3343*v_1*v_2^2*h^6 - 2169*u_2^2*y*h^6 - 1542*u_3*v_1*y*h^6 - 1188*u_2*v_2*y*h^6 - 1773*v_1*v_2*y*h^6 + 1729*v_2^2*y*h^6 + 1542*v_1*v_3*y*h^6 + 3374*u_2^2*h^7 - 1901*u_1*u_3*h^7 + 2717*u_2*v_1*h^7 - 4880*u_3*v_1*h^7 - 3007*v_1^2*h^7 - 4493*u_1*v_2*h^7 + 1883*u_2*v_2*h^7 + 1031*v_1*v_2*h^7 - 731*v_2^2*h^7 + 716*u_1*v_3*h^7 - 233*v_1*v_3*h^7 + 1669*u_2*y*h^7 - 500*u_3*y*h^7 - 4906*v_1*y*h^7 + 2272*v_2*y*h^7 - 1278*v_3*y*h^7 - 4742*u_1*h^8 - 1846*u_2*h^8 - 1149*u_3*h^8 + 763*v_1*h^8 + 200*v_2*h^8 + 315*v_3*h^8 - 671*y*h^8 + 3051*h^9,
#  v_1^2*v_2*h^6 - 1733*u_2^2*y*h^6 + 4760*u_2*v_2*y*h^6 - 3540*v_1*v_2*y*h^6 - 3027*v_2^2*y*h^6 - 4924*u_2^2*h^7 + 3957*u_2*v_1*h^7 - 4767*v_1^2*h^7 - 2986*u_1*v_2*h^7 - 4627*u_2*v_2*h^7 + 1846*v_1*v_2*h^7 - 4721*v_2^2*h^7 + 3415*u_2*y*h^7 + 4744*v_1*y*h^7 - 861*v_2*y*h^7 + 2281*u_1*h^8 - 2734*u_2*h^8 + 4358*v_1*h^8 - 3080*v_2*h^8 + 3802*y*h^8 + 23*h^9,
#  u_2^2*v_1*h^5 - 3291*v_1^2*v_2*h^5 - 6*u_1*v_2^2*h^5 + 5*v_1*v_2^2*h^5 + 1604*u_2^2*y*h^5 - 1766*u_2*v_2*y*h^5 + 1122*v_1*v_2*y*h^5 + 3356*v_2^2*y*h^5 + 4978*u_2^2*h^6 - 3296*u_2*v_1*h^6 - 4641*v_1^2*h^6 - 4252*u_1*v_2*h^6 - 1343*u_2*v_2*h^6 - 1371*v_1*v_2*h^6 - 4813*v_2^2*h^6 - 3816*u_2*y*h^6 + 4556*v_1*y*h^6 - 346*v_2*y*h^6 + 908*u_1*h^7 + 2008*u_2*h^7 + 2746*v_1*h^7 - 1463*v_2*h^7 - 4570*y*h^7 + 3835*h^8,
#  u_2*v_1^2*h^5 + 2135*v_1^2*v_2*h^5 - 540*u_2^2*y*h^5 + 1080*u_2*v_2*y*h^5 - 1229*v_1*v_2*y*h^5 - 540*v_2^2*y*h^5 + 4817*u_2^2*h^6 - 2698*u_2*v_1*h^6 - 996*v_1^2*h^6 + 2665*u_1*v_2*h^6 - 2348*u_2*v_2*h^6 - 3490*v_1*v_2*h^6 - 2469*v_2^2*h^6 + 2756*u_2*y*h^6 - 3730*v_1*y*h^6 - 3958*v_2*y*h^6 - 2180*u_1*h^7 - 2328*u_2*h^7 + 4655*v_1*h^7 + 3589*v_2*h^7 + 4835*y*h^7 + 3310*h^8,
#  u_2*v_1*v_2*h^5 - 2811*v_1^2*v_2*h^5 - 3*u_1*v_2^2*h^5 + 2*v_1*v_2^2*h^5 + 3587*u_2^2*y*h^5 - 1925*u_2*v_2*y*h^5 - 3072*v_1*v_2*y*h^5 + 4981*v_2^2*y*h^5 - 4997*u_2^2*h^6 - 3349*u_2*v_1*h^6 + 2078*v_1^2*h^6 - 4713*u_1*v_2*h^6 - 4027*u_2*v_2*h^6 + 2531*v_1*v_2*h^6 - 3076*v_2^2*h^6 - 791*u_2*y*h^6 - 2685*v_1*y*h^6 - 2053*v_2*y*h^6 - 4903*u_1*h^7 + 301*u_2*h^7 - 2825*v_1*h^7 + 4100*v_2*h^7 + 100*y*h^7 - 4097*h^8,
#  u_2*v_1*y*h^4 - v_1*v_2*y*h^4 + 3291*u_2*v_1*h^5 - 4782*v_1^2*h^5 - 1505*u_1*v_2*h^5 + 2611*v_1*v_2*h^5 + 3930*u_2*y*h^5 + 540*v_1*y*h^5 - 1949*v_2*y*h^5 - 240*u_1*h^6 + 4526*u_2*h^6 - 151*v_1*h^6 + 2031*v_2*h^6 - 1953*y*h^6 - 3470*h^7,
#  u_1*u_2*h^5 - 1540*u_2*v_1*h^5 - 1175*v_1^2*h^5 + 4616*u_1*v_2*h^5 - 3077*v_1*v_2*h^5 + 2212*u_2*y*h^5 + 393*v_1*y*h^5 - 1999*v_2*y*h^5 + 2174*u_1*h^6 - 2559*u_2*h^6 + 2702*v_1*h^6 - 901*v_2*h^6 + 1535*y*h^6 - 3276*h^7,
#  u_1*v_1*h^5 + 4115*u_2*v_1*h^5 + 1538*v_1^2*h^5 - 2338*u_1*v_2*h^5 - 1777*v_1*v_2*h^5 + 4529*u_2*y*h^5 + 4944*v_1*y*h^5 + 2299*v_2*y*h^5 - 736*u_1*h^6 + 3040*u_2*h^6 + 685*v_1*h^6 + 292*v_2*h^6 + 2616*y*h^6 + 2316*h^7,
#  u_1*v_1^2*h^3 + 410*u_1*v_1*h^4 + 4373*v_1^2*h^4 - 2477*u_2*y*h^4 - 1880*v_1*y*h^4 + 2477*v_2*y*h^4 - 4566*u_1*h^5 - 4349*u_2*h^5 + 3929*v_1*h^5 + 595*v_2*h^5 + 2686*y*h^5 - 3180*h^6,
#  v_1^2*y*h^3 + 2020*u_1*v_1*h^4 + 1381*v_1^2*h^4 - 69*u_2*y*h^4 - 2877*v_1*y*h^4 + 69*v_2*y*h^4 - 1785*u_1*h^5 - 2331*u_2*h^5 + 1014*v_1*h^5 - 852*v_2*h^5 - 672*y*h^5 - 2181*h^6,
#  u_1^2*h^3 - 2*u_1*v_1*h^3 + v_1^2*h^3 - 4457*v_1*y*h^3 - 4959*u_1*h^4 - 2595*v_1*h^4 - 640*y*h^4 + 3911*h^5,
#  u_1*y*h^2 - v_1*y*h^2 - 2012*u_1*h^3 + 142*v_1*h^3 + 3985*y*h^3 + 1158*h^4,
#  u_1^3 + 3*u_1^2*y + 3*u_1*y^2 - 1578*u_1^2*h - 3156*u_1*y*h + 1514*u_1*h^2 - u_2*h^2 - 2066*v_1*h^2 - 4375*y*h^2 - 1068*h^3,
#  u_2^3 + 3*u_2^2*y + 3*u_2*y^2 + 2657*u_2^2*h - 4693*u_2*y*h + 9*u_1*h^2 + 4907*u_2*h^2 - u_3*h^2 - 8*v_1*h^2 - 3109*y*h^2 + 4611*h^3,
#  u_3^3 + 3*u_3^2*y + 3*u_3*y^2 - 1387*u_3^2*h - 2774*u_3*y*h - 143*u_1*h^2 + 4144*u_3*h^2 + 144*v_1*h^2 + 1450*y*h^2 - 2200*h^3,
#  v_1^3 + 3*v_1^2*y + 3*v_1*y^2 - 1578*v_1^2*h - 3156*v_1*y*h + 2067*u_1*h^2 - 2619*v_1*h^2 - v_2*h^2 - 4375*y*h^2 - 1068*h^3,
#  v_2^3 + 3*v_2^2*y + 3*v_2*y^2 + 2657*v_2^2*h - 4693*v_2*y*h + 9*u_1*h^2 - 8*v_1*h^2 + 4907*v_2*h^2 - v_3*h^2 - 3109*y*h^2 + 4611*h^3,
#  v_3^3 + 3*v_3^2*y + 3*v_3*y^2 - 1387*v_3^2*h - 2774*v_3*y*h - 143*u_1*h^2 + 144*v_1*h^2 + 4144*v_3*h^2 + 1450*y*h^2 - 382*h^3,
#  y^3 - 4294*u_1*h^2 + 4293*v_1*h^2 - 2817*y*h^2 + 1192*h^3,
#  y^2*h - 198*u_1*h^2 + 198*v_1*h^2 - 2154*y*h^2 - 4826*h^3]

# %%
res = ideal(polys_h).graded_free_resolution(algorithm="minimal")
res
# Out:
# S(0) <-- S(-3)⊕S(-3)⊕S(-3)⊕S(-3)⊕S(-3)⊕S(-3)⊕S(-3)⊕S(-3) <-- S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-6)⊕S(-17) <-- S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-9)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18) <-- S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-12)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19)⊕S(-19) <-- S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-15)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20)⊕S(-20) <-- S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-18)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21) <-- S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-21)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22)⊕S(-22) <-- S(-23)⊕S(-23)⊕S(-23)⊕S(-23)⊕S(-23)⊕S(-23)⊕S(-23) <-- 0

# %%
cm_regularity(res)
# Out:
# 16
