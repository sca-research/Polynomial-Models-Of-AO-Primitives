# %% [markdown]
# # GMiMC-erf Sponge Demo

# %%
load("GMiMC_erf_sponge.sage")

# %% [markdown]
# ## Preimage

# %%
field = GF(101)
n = 4
rate = 2
r = 12

gmimc = GMiMC_erf_sponge(field=field, n=n, rate=rate, r=r)
# Out:
# GMiMC Parameters
# Field: Finite Field of size 101
# n: 4
# Rate: 2
# Capacity: 2
# r: 12
# Constants: [9, 57, 7, 63, 0, 22, 33, 63, 79, 97, 39, 98]

# %%
polys = gmimc.generate_preimage_polynomials()

print(70 * "-")

for i in range(0, gmimc.r):
    for j in range(0, gmimc.n):
        print(polys[i * gmimc.n + j])
    print(70 * "-")
# Out:
# IV: [0, 0]
# Message: [43, 26]
# Hash: [31, 97]
# Order: degrevlex
# ----------------------------------------------------------------------
# x_in_1^3 + 27*x_in_1^2 + 41*x_in_1 + x_in_2 - x_1_1 + 22
# x_in_1^3 + 27*x_in_1^2 + 41*x_in_1 - x_2_1 + 22
# x_in_1^3 + 27*x_in_1^2 + 41*x_in_1 - x_3_1 + 22
# x_in_1 - x_4_1
# ----------------------------------------------------------------------
# x_1_1^3 - 31*x_1_1^2 - 50*x_1_1 + x_2_1 - x_1_2 - 41
# x_1_1^3 - 31*x_1_1^2 - 50*x_1_1 + x_3_1 - x_2_2 - 41
# x_1_1^3 - 31*x_1_1^2 - 50*x_1_1 + x_4_1 - x_3_2 - 41
# x_1_1 - x_4_2
# ----------------------------------------------------------------------
# x_1_2^3 + 21*x_1_2^2 + 46*x_1_2 + x_2_2 - x_1_3 + 40
# x_1_2^3 + 21*x_1_2^2 + 46*x_1_2 + x_3_2 - x_2_3 + 40
# x_1_2^3 + 21*x_1_2^2 + 46*x_1_2 + x_4_2 - x_3_3 + 40
# x_1_2 - x_4_3
# ----------------------------------------------------------------------
# x_1_3^3 - 13*x_1_3^2 - 11*x_1_3 + x_2_3 - x_1_4 - 29
# x_1_3^3 - 13*x_1_3^2 - 11*x_1_3 + x_3_3 - x_2_4 - 29
# x_1_3^3 - 13*x_1_3^2 - 11*x_1_3 + x_4_3 - x_3_4 - 29
# x_1_3 - x_4_4
# ----------------------------------------------------------------------
# x_1_4^3 + x_2_4 - x_1_5
# x_1_4^3 + x_3_4 - x_2_5
# x_1_4^3 + x_4_4 - x_3_5
# x_1_4 - x_4_5
# ----------------------------------------------------------------------
# x_1_5^3 - 35*x_1_5^2 + 38*x_1_5 + x_2_5 - x_1_6 + 43
# x_1_5^3 - 35*x_1_5^2 + 38*x_1_5 + x_3_5 - x_2_6 + 43
# x_1_5^3 - 35*x_1_5^2 + 38*x_1_5 + x_4_5 - x_3_6 + 43
# x_1_5 - x_4_6
# ----------------------------------------------------------------------
# x_1_6^3 - 2*x_1_6^2 + 35*x_1_6 + x_2_6 - x_1_7 - 19
# x_1_6^3 - 2*x_1_6^2 + 35*x_1_6 + x_3_6 - x_2_7 - 19
# x_1_6^3 - 2*x_1_6^2 + 35*x_1_6 + x_4_6 - x_3_7 - 19
# x_1_6 - x_4_7
# ----------------------------------------------------------------------
# x_1_7^3 - 13*x_1_7^2 - 11*x_1_7 + x_2_7 - x_1_8 - 29
# x_1_7^3 - 13*x_1_7^2 - 11*x_1_7 + x_3_7 - x_2_8 - 29
# x_1_7^3 - 13*x_1_7^2 - 11*x_1_7 + x_4_7 - x_3_8 - 29
# x_1_7 - x_4_8
# ----------------------------------------------------------------------
# x_1_8^3 + 35*x_1_8^2 + 38*x_1_8 + x_2_8 - x_1_9 - 43
# x_1_8^3 + 35*x_1_8^2 + 38*x_1_8 + x_3_8 - x_2_9 - 43
# x_1_8^3 + 35*x_1_8^2 + 38*x_1_8 + x_4_8 - x_3_9 - 43
# x_1_8 - x_4_9
# ----------------------------------------------------------------------
# x_1_9^3 - 12*x_1_9^2 + 48*x_1_9 + x_2_9 - x_1_10 + 37
# x_1_9^3 - 12*x_1_9^2 + 48*x_1_9 + x_3_9 - x_2_10 + 37
# x_1_9^3 - 12*x_1_9^2 + 48*x_1_9 + x_4_9 - x_3_10 + 37
# x_1_9 - x_4_10
# ----------------------------------------------------------------------
# x_1_10^3 + 16*x_1_10^2 + 18*x_1_10 + x_2_10 - x_1_11 + 32
# x_1_10^3 + 16*x_1_10^2 + 18*x_1_10 + x_3_10 - x_2_11 + 32
# x_1_10^3 + 16*x_1_10^2 + 18*x_1_10 + x_4_10 - x_3_11 + 32
# x_1_10 - x_4_11
# ----------------------------------------------------------------------
# x_1_11^3 - 9*x_1_11^2 + 27*x_1_11 + x_2_11 + 43
# x_1_11^3 - 9*x_1_11^2 + 27*x_1_11 + x_3_11 - 23
# x_1_11^3 - 9*x_1_11^2 + 27*x_1_11 + x_4_11 - x_out_1 - 27
# x_1_11 - x_out_2
# ----------------------------------------------------------------------

# %%
polys_lin, polys_subs, gb_subs = gmimc.compute_preimage_Groebner_basis(polys)

print(70 * "-")
print("Linear polynomials")
print(70 * "-")
for poly in polys_lin:
    print(poly)

print(70 * "-")
print("Substitution polynomials")
print(70 * "-")
for poly in polys_subs:
    print(poly)

print(70 * "-")
print("Gröbner basis")
print(70 * "-")
for poly in gb_subs:
    print(poly)
# Out:
# Ideal of leading terms equal to (x_subs_1^3, ..., x_subs_n^3): True
# All terms of substituted Groebner basis contained in (x_subs_1, ..., x_subs_n): True
# ----------------------------------------------------------------------
# Linear polynomials
# ----------------------------------------------------------------------
# x_in_1 - x_4_1
# x_in_2 + x_4_1 - 3*x_4_3 + 3*x_4_4 - 3*x_4_6 + 3*x_4_7 - 3*x_4_9 + 3*x_4_10 - x_out_1 - x_out_2 - 35
# x_1_1 - 2*x_4_3 + x_4_4 + x_4_5 - 2*x_4_6 + x_4_7 + x_4_8 - 2*x_4_9 + x_4_10 + x_4_11 - x_out_1 - x_out_2 + 31
# x_2_1 - x_4_1 + x_4_3 - 2*x_4_4 + x_4_5 + x_4_6 - 2*x_4_7 + x_4_8 + x_4_9 - 2*x_4_10 + x_4_11 - 35
# x_3_1 - x_4_1 + x_4_3 - 2*x_4_4 + x_4_5 + x_4_6 - 2*x_4_7 + x_4_8 + x_4_9 - 2*x_4_10 + x_4_11 - 35
# x_1_2 - x_4_3
# x_2_2 - x_4_3
# x_3_2 - 2*x_4_3 + 2*x_4_4 - x_4_5 - x_4_6 + 2*x_4_7 - x_4_8 - x_4_9 + 2*x_4_10 - x_4_11 + 35
# x_4_2 - 2*x_4_3 + x_4_4 + x_4_5 - 2*x_4_6 + x_4_7 + x_4_8 - 2*x_4_9 + x_4_10 + x_4_11 - x_out_1 - x_out_2 + 31
# x_1_3 - x_4_4
# x_2_3 - x_4_3 + x_4_4 - x_4_5 - x_4_6 + 2*x_4_7 - x_4_8 - x_4_9 + 2*x_4_10 - x_4_11 + 35
# x_3_3 - x_4_3 + x_4_5 - 2*x_4_6 + x_4_7 + x_4_8 - 2*x_4_9 + x_4_10 + x_4_11 - x_out_1 - x_out_2 + 31
# x_1_4 - x_4_5
# x_2_4 - x_4_4 + x_4_5 - x_4_6 - x_4_7 + 2*x_4_8 - x_4_9 - x_4_10 + 2*x_4_11 - x_out_1 - x_out_2 - 4
# x_3_4 - x_4_4 + x_4_6 - 2*x_4_7 + x_4_8 + x_4_9 - 2*x_4_10 + x_4_11 - 35
# x_1_5 - x_4_6
# x_2_5 - x_4_5 + x_4_6 - x_4_7 - x_4_8 + 2*x_4_9 - x_4_10 - x_4_11 + x_out_1 + x_out_2 - 31
# x_3_5 - x_4_5 + x_4_7 - 2*x_4_8 + x_4_9 + x_4_10 - 2*x_4_11 + x_out_1 + x_out_2 + 4
# x_1_6 - x_4_7
# x_2_6 - x_4_6 + x_4_7 - x_4_8 - x_4_9 + 2*x_4_10 - x_4_11 + 35
# x_3_6 - x_4_6 + x_4_8 - 2*x_4_9 + x_4_10 + x_4_11 - x_out_1 - x_out_2 + 31
# x_1_7 - x_4_8
# x_2_7 - x_4_7 + x_4_8 - x_4_9 - x_4_10 + 2*x_4_11 - x_out_1 - x_out_2 - 4
# x_3_7 - x_4_7 + x_4_9 - 2*x_4_10 + x_4_11 - 35
# x_1_8 - x_4_9
# x_2_8 - x_4_8 + x_4_9 - x_4_10 - x_4_11 + x_out_1 + x_out_2 - 31
# x_3_8 - x_4_8 + x_4_10 - 2*x_4_11 + x_out_1 + x_out_2 + 4
# x_1_9 - x_4_10
# x_2_9 - x_4_9 + x_4_10 - x_4_11 + 35
# x_3_9 - x_4_9 + x_4_11 - x_out_1 - x_out_2 + 31
# x_1_10 - x_4_11
# x_2_10 - x_4_10 + x_4_11 - x_out_1 - x_out_2 - 4
# x_3_10 - x_4_10 - 35
# x_1_11 - x_out_2
# x_2_11 - x_4_11 + x_out_1 - 31
# x_3_11 - x_4_11 + x_out_1 + 4
# ----------------------------------------------------------------------
# Substitution polynomials
# ----------------------------------------------------------------------
# x_4_1 - x_subs_1 + 9
# x_4_3 - x_subs_3 + 7
# x_4_4 - x_subs_4 - 38
# x_4_5 - x_subs_5
# x_4_6 - x_subs_6 + 22
# x_4_7 - x_subs_7 + 33
# x_4_8 - x_subs_8 - 38
# x_4_9 - x_subs_9 - 22
# x_4_10 - x_subs_10 - 4
# x_4_11 - x_subs_11 + 39
# x_out_1 - x_subs_2 + 2*x_subs_3 - x_subs_4 - x_subs_5 + 2*x_subs_6 - x_subs_7 - x_subs_8 + 2*x_subs_9 - x_subs_10 - x_subs_11 + x_subs_12 + 7
# x_out_2 - x_subs_12 - 3
# ----------------------------------------------------------------------
# Gröbner basis
# ----------------------------------------------------------------------
# x_subs_1^3 - x_subs_1 + x_subs_3 - 2*x_subs_4 + x_subs_5 + x_subs_6 - 2*x_subs_7 + x_subs_8 + x_subs_9 - 2*x_subs_10 + x_subs_11 + 49
# x_subs_2^3 + x_subs_1 - 2*x_subs_3 + 2*x_subs_4 - x_subs_5 - x_subs_6 + 2*x_subs_7 - x_subs_8 - x_subs_9 + 2*x_subs_10 - x_subs_11 - 42
# x_subs_3^3 + x_subs_3 - x_subs_4 - 45
# x_subs_4^3 + x_subs_3 - x_subs_4 + x_subs_6 - 2*x_subs_7 + x_subs_8 + x_subs_9 - 2*x_subs_10 + x_subs_11 - 23
# x_subs_5^3 + x_subs_2 - 2*x_subs_3 + 2*x_subs_4 - 2*x_subs_6 + 2*x_subs_7 - x_subs_8 - x_subs_9 + 2*x_subs_10 - x_subs_11 + 33
# x_subs_6^3 - x_subs_2 + 2*x_subs_3 - x_subs_4 + x_subs_6 - x_subs_7 + 16
# x_subs_7^3 + x_subs_6 - x_subs_7 + x_subs_9 - 2*x_subs_10 + x_subs_11 - 49
# x_subs_8^3 + x_subs_2 - 2*x_subs_3 + x_subs_4 + x_subs_5 - 2*x_subs_6 + 2*x_subs_7 - 2*x_subs_9 + 2*x_subs_10 - x_subs_11 + 11
# x_subs_9^3 - x_subs_2 + 2*x_subs_3 - x_subs_4 - x_subs_5 + 2*x_subs_6 - x_subs_7 + x_subs_9 - x_subs_10 + 12
# x_subs_10^3 + x_subs_9 - x_subs_10 - 17
# x_subs_11^3 + x_subs_2 - 2*x_subs_3 + x_subs_4 + x_subs_5 - 2*x_subs_6 + x_subs_7 + x_subs_8 - 2*x_subs_9 + 2*x_subs_10 - x_subs_12 + 40
# x_subs_12^3 - x_subs_2 + 2*x_subs_3 - x_subs_4 - x_subs_5 + 2*x_subs_6 - x_subs_7 - x_subs_8 + 2*x_subs_9 - x_subs_10 + x_subs_12 - 32

# %%
ideal(polys_lin + polys_subs + gb_subs).basis_is_groebner()
# Out:
# True

# %% [markdown]
# ## CICO

# %%
polys = gmimc.generate_CICO_polynomials()

print(70 * "-")

for i in range(0, gmimc.r):
    for j in range(0, gmimc.n):
        print(polys[i * gmimc.n + j])
    print(70 * "-")
# Out:
# IV_in: [0, 0]
# IV_out: [0, 0]
# Order: degrevlex
# ----------------------------------------------------------------------
# x_in_1^3 + 27*x_in_1^2 + 41*x_in_1 + x_in_2 - x_1_1 + 22
# x_in_1^3 + 27*x_in_1^2 + 41*x_in_1 - x_2_1 + 22
# x_in_1^3 + 27*x_in_1^2 + 41*x_in_1 - x_3_1 + 22
# x_in_1 - x_4_1
# ----------------------------------------------------------------------
# x_1_1^3 - 31*x_1_1^2 - 50*x_1_1 + x_2_1 - x_1_2 - 41
# x_1_1^3 - 31*x_1_1^2 - 50*x_1_1 + x_3_1 - x_2_2 - 41
# x_1_1^3 - 31*x_1_1^2 - 50*x_1_1 + x_4_1 - x_3_2 - 41
# x_1_1 - x_4_2
# ----------------------------------------------------------------------
# x_1_2^3 + 21*x_1_2^2 + 46*x_1_2 + x_2_2 - x_1_3 + 40
# x_1_2^3 + 21*x_1_2^2 + 46*x_1_2 + x_3_2 - x_2_3 + 40
# x_1_2^3 + 21*x_1_2^2 + 46*x_1_2 + x_4_2 - x_3_3 + 40
# x_1_2 - x_4_3
# ----------------------------------------------------------------------
# x_1_3^3 - 13*x_1_3^2 - 11*x_1_3 + x_2_3 - x_1_4 - 29
# x_1_3^3 - 13*x_1_3^2 - 11*x_1_3 + x_3_3 - x_2_4 - 29
# x_1_3^3 - 13*x_1_3^2 - 11*x_1_3 + x_4_3 - x_3_4 - 29
# x_1_3 - x_4_4
# ----------------------------------------------------------------------
# x_1_4^3 + x_2_4 - x_1_5
# x_1_4^3 + x_3_4 - x_2_5
# x_1_4^3 + x_4_4 - x_3_5
# x_1_4 - x_4_5
# ----------------------------------------------------------------------
# x_1_5^3 - 35*x_1_5^2 + 38*x_1_5 + x_2_5 - x_1_6 + 43
# x_1_5^3 - 35*x_1_5^2 + 38*x_1_5 + x_3_5 - x_2_6 + 43
# x_1_5^3 - 35*x_1_5^2 + 38*x_1_5 + x_4_5 - x_3_6 + 43
# x_1_5 - x_4_6
# ----------------------------------------------------------------------
# x_1_6^3 - 2*x_1_6^2 + 35*x_1_6 + x_2_6 - x_1_7 - 19
# x_1_6^3 - 2*x_1_6^2 + 35*x_1_6 + x_3_6 - x_2_7 - 19
# x_1_6^3 - 2*x_1_6^2 + 35*x_1_6 + x_4_6 - x_3_7 - 19
# x_1_6 - x_4_7
# ----------------------------------------------------------------------
# x_1_7^3 - 13*x_1_7^2 - 11*x_1_7 + x_2_7 - x_1_8 - 29
# x_1_7^3 - 13*x_1_7^2 - 11*x_1_7 + x_3_7 - x_2_8 - 29
# x_1_7^3 - 13*x_1_7^2 - 11*x_1_7 + x_4_7 - x_3_8 - 29
# x_1_7 - x_4_8
# ----------------------------------------------------------------------
# x_1_8^3 + 35*x_1_8^2 + 38*x_1_8 + x_2_8 - x_1_9 - 43
# x_1_8^3 + 35*x_1_8^2 + 38*x_1_8 + x_3_8 - x_2_9 - 43
# x_1_8^3 + 35*x_1_8^2 + 38*x_1_8 + x_4_8 - x_3_9 - 43
# x_1_8 - x_4_9
# ----------------------------------------------------------------------
# x_1_9^3 - 12*x_1_9^2 + 48*x_1_9 + x_2_9 - x_1_10 + 37
# x_1_9^3 - 12*x_1_9^2 + 48*x_1_9 + x_3_9 - x_2_10 + 37
# x_1_9^3 - 12*x_1_9^2 + 48*x_1_9 + x_4_9 - x_3_10 + 37
# x_1_9 - x_4_10
# ----------------------------------------------------------------------
# x_1_10^3 + 16*x_1_10^2 + 18*x_1_10 + x_2_10 - x_1_11 + 32
# x_1_10^3 + 16*x_1_10^2 + 18*x_1_10 + x_3_10 - x_2_11 + 32
# x_1_10^3 + 16*x_1_10^2 + 18*x_1_10 + x_4_10 - x_3_11 + 32
# x_1_10 - x_4_11
# ----------------------------------------------------------------------
# x_1_11^3 - 9*x_1_11^2 + 27*x_1_11 + x_2_11 - x_out_1 - 27
# x_1_11^3 - 9*x_1_11^2 + 27*x_1_11 + x_3_11 - x_out_2 - 27
# x_1_11^3 - 9*x_1_11^2 + 27*x_1_11 + x_4_11 - 27
# x_1_11
# ----------------------------------------------------------------------

# %%
polys_lin, polys_subs, gb_subs = gmimc.compute_CICO_Groebner_basis(polys)

print(70 * "-")
print("Linear polynomials")
print(70 * "-")
for poly in polys_lin:
    print(poly)

print(70 * "-")
print("Substitution polynomials")
print(70 * "-")
for poly in polys_subs:
    print(poly)

print(70 * "-")
print("Gröbner basis")
print(70 * "-")
for poly in gb_subs:
    print(poly)
# Out:
# Ideal of leading terms equal to (x_subs_1^3, ..., x_subs_n^3): True
# All terms of substituted Groebner basis contained in (x_subs_1, ..., x_subs_n): True
# ----------------------------------------------------------------------
# Linear polynomials
# ----------------------------------------------------------------------
# x_in_1 - x_4_1
# x_in_2 + x_4_1 - 3*x_4_3 + 3*x_4_4 - 3*x_4_6 + 3*x_4_7 - 3*x_4_9 + 2*x_out_1 + 2*x_out_2 + 32
# x_1_1 - 2*x_4_3 + x_4_4 + x_4_5 - 2*x_4_6 + x_4_7 + x_4_8 - 2*x_4_9 + x_out_1 + x_out_2 + 4
# x_2_1 - x_4_1 + x_4_3 - 2*x_4_4 + x_4_5 + x_4_6 - 2*x_4_7 + x_4_8 + x_4_9 - x_out_1 - x_out_2 - 28
# x_3_1 - x_4_1 + x_4_3 - 2*x_4_4 + x_4_5 + x_4_6 - 2*x_4_7 + x_4_8 + x_4_9 - x_out_1 - x_out_2 - 28
# x_1_2 - x_4_3
# x_2_2 - x_4_3
# x_3_2 - 2*x_4_3 + 2*x_4_4 - x_4_5 - x_4_6 + 2*x_4_7 - x_4_8 - x_4_9 + x_out_1 + x_out_2 + 28
# x_4_2 - 2*x_4_3 + x_4_4 + x_4_5 - 2*x_4_6 + x_4_7 + x_4_8 - 2*x_4_9 + x_out_1 + x_out_2 + 4
# x_1_3 - x_4_4
# x_2_3 - x_4_3 + x_4_4 - x_4_5 - x_4_6 + 2*x_4_7 - x_4_8 - x_4_9 + x_out_1 + x_out_2 + 28
# x_3_3 - x_4_3 + x_4_5 - 2*x_4_6 + x_4_7 + x_4_8 - 2*x_4_9 + x_out_1 + x_out_2 + 4
# x_1_4 - x_4_5
# x_2_4 - x_4_4 + x_4_5 - x_4_6 - x_4_7 + 2*x_4_8 - x_4_9 - 24
# x_3_4 - x_4_4 + x_4_6 - 2*x_4_7 + x_4_8 + x_4_9 - x_out_1 - x_out_2 - 28
# x_1_5 - x_4_6
# x_2_5 - x_4_5 + x_4_6 - x_4_7 - x_4_8 + 2*x_4_9 - x_out_1 - x_out_2 - 4
# x_3_5 - x_4_5 + x_4_7 - 2*x_4_8 + x_4_9 + 24
# x_1_6 - x_4_7
# x_2_6 - x_4_6 + x_4_7 - x_4_8 - x_4_9 + x_out_1 + x_out_2 + 28
# x_3_6 - x_4_6 + x_4_8 - 2*x_4_9 + x_out_1 + x_out_2 + 4
# x_1_7 - x_4_8
# x_2_7 - x_4_7 + x_4_8 - x_4_9 - 24
# x_3_7 - x_4_7 + x_4_9 - x_out_1 - x_out_2 - 28
# x_1_8 - x_4_9
# x_2_8 - x_4_8 + x_4_9 - x_out_1 - x_out_2 - 4
# x_3_8 - x_4_8 + 24
# x_1_9 - x_out_2 + 23
# x_2_9 - x_4_9 + x_out_1 - 50
# x_3_9 - x_4_9 + x_out_1 + 27
# x_1_10 - 27
# x_2_10 + 50
# x_3_10 - x_out_1 + 23
# x_4_10 - x_out_2 + 23
# x_1_11
# x_2_11 - x_out_1 - 27
# x_3_11 - x_out_2 - 27
# x_4_11 - 27
# ----------------------------------------------------------------------
# Substitution polynomials
# ----------------------------------------------------------------------
# x_4_1 - x_subs_1 + 9
# x_4_3 - x_subs_3 + 7
# x_4_4 - x_subs_4 - 38
# x_4_5 - x_subs_5
# x_4_6 - x_subs_6 + 22
# x_4_7 - x_subs_7 + 33
# x_4_8 - x_subs_8 - 38
# x_4_9 - x_subs_9 - 22
# x_out_1 + x_subs_2 - 2*x_subs_3 + x_subs_4 + x_subs_5 - 2*x_subs_6 + x_subs_7 + x_subs_8 - 2*x_subs_9 + x_subs_10 + 31
# x_out_2 - x_subs_10 - 27
# ----------------------------------------------------------------------
# Gröbner basis
# ----------------------------------------------------------------------
# x_subs_1^3 - x_subs_1 + x_subs_2 - x_subs_3 - x_subs_4 + 2*x_subs_5 - x_subs_6 - x_subs_7 + 2*x_subs_8 - x_subs_9 + 6
# x_subs_2^3 + x_subs_1 - x_subs_2 + x_subs_4 - 2*x_subs_5 + x_subs_6 + x_subs_7 - 2*x_subs_8 + x_subs_9 + 1
# x_subs_3^3 + x_subs_3 - x_subs_4 - 45
# x_subs_4^3 + x_subs_2 - x_subs_3 + x_subs_5 - x_subs_6 - x_subs_7 + 2*x_subs_8 - x_subs_9 + 35
# x_subs_5^3 + x_subs_4 - x_subs_5 + x_subs_7 - 2*x_subs_8 + x_subs_9 - 25
# x_subs_6^3 - x_subs_2 + 2*x_subs_3 - x_subs_4 + x_subs_6 - x_subs_7 + 16
# x_subs_7^3 + x_subs_2 - 2*x_subs_3 + x_subs_4 + x_subs_5 - x_subs_6 + x_subs_8 - x_subs_9 + 9
# x_subs_8^3 + x_subs_7 - x_subs_8 - 47
# x_subs_9^3 - x_subs_2 + 2*x_subs_3 - x_subs_4 - x_subs_5 + 2*x_subs_6 - x_subs_7 + x_subs_9 - x_subs_10 + 12
# x_subs_10^3 + x_subs_2 - 2*x_subs_3 + x_subs_4 + x_subs_5 - 2*x_subs_6 + x_subs_7 + x_subs_8 - x_subs_9 + x_subs_10 - 25

# %%
ideal(polys_lin + polys_subs + gb_subs).basis_is_groebner()
# Out:
# True
